# %%
pip install voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from voyageai) (3.12.15)
# Collecting aiolimiter (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: langchain-text-splitters>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from voyageai) (0.3.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from voyageai) (11.3.0)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.11.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.32.4)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from voyageai) (8.5.0)
# Requirement already satisfied: tokenizers>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from voyageai) (0.22.0)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain-text-splitters>=0.3.8->voyageai) (0.3.75)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.14.0->voyageai) (0.34.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.1.9)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.4.27)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.24.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.3.1)
# Downloading voyageai-0.3.5-py3-none-any.whl (28 kB)
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Installing collected packages: aiolimiter, voyageai
# Successfully installed aiolimiter-1.2.1 voyageai-0.3.5

# %% [markdown]
# # Resume-to-Job Description Matching: Multi-Model Performance Comparison
#
# This notebook compares the performance of different embedding models for resume-to-job description matching tasks. We evaluate multiple models including:
#
# - **BGE** (BAAI General Embedding with LoRA fine-tuning)
# - **OpenAI** (text-embedding-3-small)
# - **BGE-M3** (Multilingual BGE)
# - **CareerBERT** (Career-specific BERT)
# - **ConFit V2** (Using all-mpnet-base-v2)
# - **Voyage-3-Large** (Voyage AI embedding)
# - **LLaMA-3.1** (Remote Inference via Inference Providers)
#
# The analysis includes similarity score calculations, threshold-based predictions, and comprehensive performance metrics.

# %% [markdown]
# ## 1. Setup Environment and Load Libraries
#
# Import all required libraries for model loading, text processing, similarity calculations, and performance evaluation.

# %%
# Import required libraries
from transformers import AutoModel, AutoTokenizer, LlamaModel, LlamaTokenizer
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel, PeftConfig
from peft import PeftModel
import torch
import torch.nn.functional as F
import openai
import numpy as np
import os
import pandas as pd
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
import voyageai
import requests
import time
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import seaborn as sns
import json

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# ## 2. Initialize API Keys and Environment Variables
#
# Load environment variables from .env file and set up API keys for external services.

# %%
# Load environment variables from .env file
# load_dotenv()

# Get API keys from environment variables
#openai.api_key = os.getenv('OPENAI_API_KEY')
#voyage_api_key = os.getenv('VOYAGE_API_KEY')

from google.colab import userdata
openai.api_key = userdata.get('OPENAI_API_KEY')
voyage_api_key = userdata.get('VOYAGE_API_KEY')

# Validate API keys
if openai.api_key is None:
    print("⚠️  OpenAI API key not found in .env file. Please set OPENAI_API_KEY in your .env file.")
else:
    print("✅ OpenAI API key loaded successfully.")

if voyage_api_key is None:
    print("⚠️  Voyage API key not found in .env file. Please set VOYAGE_API_KEY in your .env file.")
else:
    print("✅ Voyage API key loaded successfully.")
    voyageai.api_key = voyage_api_key
# Out:
# ✅ OpenAI API key loaded successfully.
# ✅ Voyage API key loaded successfully.

# %% [markdown]
# ## 3. Load Embedding Models
#
# Initialize all embedding models with proper error handling. This may take several minutes as models are downloaded and loaded.

# %%
# Load BGE models and tokenizer
print("Loading BGE models...")
try:
    base_model = AutoModel.from_pretrained("BAAI/bge-large-en-v1.5")
    # Load Peft model (LoRA adapter)
    model = PeftModel.from_pretrained(base_model, "shashu2325/resume-job-matcher-lora")
    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-large-en-v1.5")
    print("✅ BGE models and tokenizer loaded successfully.")
except Exception as e:
    print(f"❌ Failed to load BGE models or tokenizer: {e}")
    base_model = None
    model = None
    tokenizer = None
# Out:
# Loading BGE models...
# config.json:   0%|          | 0.00/779 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/4.74M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# ✅ BGE models and tokenizer loaded successfully.

# %%
# Load BGE-M3 model
print("Loading BGE-M3 model...")
try:
    bge_m3_model = SentenceTransformer("BAAI/bge-m3")
    print("✅ BGE-M3 model loaded successfully.")
except Exception as e:
    print(f"❌ Failed to load BGE-M3 model: {e}")
    bge_m3_model = None
# Out:
# Loading BGE-M3 model...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# ✅ BGE-M3 model loaded successfully.

# %%
# Load ConFit V2 model (using all-mpnet-base-v2 as a proxy for ConFit)
print("Loading ConFit V2 model...")
try:
    confit_model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
    print("✅ ConFit V2 model loaded successfully.")
except Exception as e:
    print(f"❌ Failed to load ConFit V2 model: {e}")
    confit_model = None
# Out:
# Loading ConFit V2 model...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ ConFit V2 model loaded successfully.

# %%
# Load LLaMA-3.1 for embeddings
# print("Setting up LLaMA-3.1 model...")
# try:
#     base_model_name = "meta-llama/Llama-3.1-8B-Instruct"
#
#     # Load the base model
#     # base_model = AutoModelForCausalLM.from_pretrained(base_model_name)
#     # llama_tokenizer = AutoTokenizer.from_pretrained(base_model_name)
#
#     # Load the LoRA adapter
#     # peft_model_id = "LlamaFactoryAI/Llama-3.1-8B-Instruct-cv-job-description-matching"
#     # config = PeftConfig.from_pretrained(peft_model_id)
#     # llama_model = PeftModel.from_pretrained(base_model, peft_model_id)
#
#    # print("✅ LLaMA-3.1 model setup complete.")
# except Exception as e:
#    print(f"❌ Failed to load LLaMA-3.1 model: {e}")
#    llama_model = None
#    llama_tokenizer = None

# %%
import os
from openai import OpenAI
from google.colab import userdata

# Get Hugging Face token from Colab secrets
hf_token = userdata.get('HF_TOKEN')

if hf_token is None:
    print("⚠️ Hugging Face token not found in Colab secrets. Please add it as 'HF_TOKEN'.")
else:
    print("✅ Hugging Face token loaded successfully.")
    # Initialize the client with the Hugging Face Inference API base URL
    client = OpenAI(
        base_url="https://router.huggingface.co/v1", # Updated base_url
        api_key=hf_token, # Use the HF token as the API key
    )

    def get_llama_remote_response(resume_text, job_text):
        """Gets a response from the remote LLaMA-3.1 model via Hugging Face Inference API."""
        if client is None:
            print("Hugging Face Inference API client not initialized.")
            return None

        messages = [
            {
                "role": "system",
                "content": """You are an advanced AI model designed to analyze the compatibility between a CV and a job description. You will receive a CV and a job description. Your task is to output a structured JSON format that includes the following:

1. matching_analysis: Analyze the CV against the job description to identify key strengths and gaps.
2. description: Summarize the relevance of the CV to the job description in a few concise sentences.
3. score: Provide a numerical compatibility score (0-100) based on qualifications, skills, and experience.
4. recommendation: Suggest actions for the candidate to improve their match or readiness for the role.

Your output must be in JSON format as follows:
{
  "matching_analysis": "Your detailed analysis here.",
  "description": "A brief summary here.",
  "score": 85,
  "recommendation": "Your suggestions here."
}
""",
            },
            {"role": "user", "content": f"<CV> {resume_text} </CV>\n<job_description> {job_text} </job_description>"},
        ]

        try:
            completion = client.chat.completions.create(
                model="meta-llama/Llama-3.1-8B-Instruct", # Specify the model ID
                messages=messages,
                max_tokens=256, # Set max tokens for the response
                response_format={ "type": "json_object" } # Request JSON object output
            )
            # The response structure might vary slightly, access the message content
            response_content = completion.choices[0].message.content
            return response_content

        except Exception as e:
            print(f"Error calling Hugging Face Inference API: {e}")
            return None

    # Example usage (optional, for testing)
    # example_resume = "Software Engineer with 5 years experience..."
    # example_job = "Looking for a Senior Software Engineer..."
    # remote_response = get_llama_remote_response(example_resume, example_job)
    # print("\nRemote API Response:")
    # print(remote_response)

    print("✅ Hugging Face Inference API client setup complete.")
# Out:
# ✅ Hugging Face token loaded successfully.
# ✅ Hugging Face Inference API client setup complete.

# %%
# Load CareerBERT model
print("Loading CareerBERT model...")
try:
    careerbert_model = SentenceTransformer("lwolfrum2/careerbert-g")
    print("✅ CareerBERT model loaded successfully.")
except Exception as e:
    print(f"❌ Failed to load CareerBERT model: {e}")
    careerbert_model = None
# Out:
# Loading CareerBERT model...
# modules.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/56.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/732 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/305 [00:00<?, ?B/s]
# ✅ CareerBERT model loaded successfully.

# %%
print("\n🎉 Model loading complete!")
# Out:
# 🎉 Model loading complete!

# %% [markdown]
# ## 4. Define Similarity Calculation Functions
#
# Implement functions for calculating similarity scores using different embedding models.

# %%
def cosine_similarity(a, b):
    """Calculate cosine similarity between two vectors"""
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    na = np.linalg.norm(a)
    nb = np.linalg.norm(b)
    if na == 0 or nb == 0:
        return 0.0
    return float(a.dot(b) / (na * nb))

def calculate_bge_similarity(resume_text, job_text):
    """Calculates similarity between resume and job text using BGE embeddings."""
    if model is None or tokenizer is None:
        print("BGE models or tokenizer not loaded. Cannot calculate similarity.")
        return None

    try:
        # Process texts
        resume_inputs = tokenizer(resume_text, return_tensors="pt", max_length=512, padding="max_length", truncation=True)
        job_inputs = tokenizer(job_text, return_tensors="pt", max_length=512, padding="max_length", truncation=True)

        # Get embeddings
        with torch.no_grad():
            # Get embeddings using mean pooling
            resume_outputs = model(**resume_inputs)
            job_outputs = model(**job_inputs)

            # Mean pooling
            resume_emb = resume_outputs.last_hidden_state.mean(dim=1)
            job_emb = job_outputs.last_hidden_state.mean(dim=1)

            # Normalize and calculate similarity
            resume_emb = F.normalize(resume_emb, p=2, dim=1)
            job_emb = F.normalize(job_emb, p=2, dim=1)

            similarity = torch.sum(resume_emb * job_emb, dim=1)
            match_score = torch.sigmoid(similarity).item()

        return match_score
    except Exception as e:
        print(f"Error calculating BGE similarity: {e}")
        return None

print("✅ BGE similarity function defined.")
# Out:
# ✅ BGE similarity function defined.

# %%
def get_openai_embedding(text, model="text-embedding-3-small"):
    """Gets OpenAI embedding for a given text."""
    if openai.api_key is None:
        print("OpenAI API key not set. Cannot get embedding.")
        return None
    try:
        text = text.replace("\n", " ")
        return openai.embeddings.create(input=[text], model=model).data[0].embedding
    except Exception as e:
        print(f"Error getting OpenAI embedding: {e}")
        return None

def calculate_openai_similarity(resume_text, job_text):
    """Calculates cosine similarity between resume and job text using OpenAI embeddings."""
    resume_embedding = get_openai_embedding(resume_text)
    job_embedding = get_openai_embedding(job_text)

    if resume_embedding is None or job_embedding is None:
        print("Failed to get OpenAI embeddings. Cannot calculate similarity.")
        return None

    # Calculate similarity using the cosine function
    similarity_score = cosine_similarity(resume_embedding, job_embedding)
    return similarity_score

print("✅ OpenAI similarity functions defined.")
# Out:
# ✅ OpenAI similarity functions defined.

# %%
def calculate_bge_m3_similarity(resume_text, job_text):
    """Calculates similarity using BGE-M3 model."""
    if bge_m3_model is None:
        print("BGE-M3 model not loaded. Cannot calculate similarity.")
        return None

    try:
        resume_embedding = bge_m3_model.encode(resume_text)
        job_embedding = bge_m3_model.encode(job_text)
        similarity_score = cosine_similarity(resume_embedding, job_embedding)
        return similarity_score
    except Exception as e:
        print(f"Error calculating BGE-M3 similarity: {e}")
        return None

def calculate_careerbert_similarity(resume_text, job_text):
    """Calculates similarity using CareerBERT model."""
    if careerbert_model is None:
        print("CareerBERT model not loaded. Cannot calculate similarity.")
        return None

    try:
        resume_embedding = careerbert_model.encode(resume_text)
        job_embedding = careerbert_model.encode(job_text)
        similarity_score = cosine_similarity(resume_embedding, job_embedding)
        return similarity_score
    except Exception as e:
        print(f"Error calculating CareerBERT similarity: {e}")
        return None

def calculate_confit_similarity(resume_text, job_text):
    """Calculates similarity using ConFit V2 model."""
    if confit_model is None:
        print("ConFit V2 model not loaded. Cannot calculate similarity.")
        return None

    try:
        resume_embedding = confit_model.encode(resume_text)
        job_embedding = confit_model.encode(job_text)
        similarity_score = cosine_similarity(resume_embedding, job_embedding)
        return similarity_score
    except Exception as e:
        print(f"Error calculating ConFit similarity: {e}")
        return None

print("✅ BGE-M3, CareerBERT, and ConFit similarity functions defined.")
# Out:
# ✅ BGE-M3, CareerBERT, and ConFit similarity functions defined.

# %%
def get_voyage_embedding(text, model="voyage-3-large"):
    """Gets Voyage AI embedding for a given text."""
    if voyage_api_key is None:
        print("Voyage API key not set. Cannot get embedding.")
        return None

    try:
        vo = voyageai.Client()
        result = vo.embed([text], model=model)
        return result.embeddings[0]
    except Exception as e:
        print(f"Error getting Voyage embedding: {e}")
        return None

def calculate_voyage_similarity(resume_text, job_text):
    """Calculates similarity using Voyage AI embeddings."""
    resume_embedding = get_voyage_embedding(resume_text)
    job_embedding = get_voyage_embedding(job_text)

    if resume_embedding is None or job_embedding is None:
        print("Failed to get Voyage embeddings. Cannot calculate similarity.")
        return None

    similarity_score = cosine_similarity(resume_embedding, job_embedding)
    return similarity_score

print("✅ Voyage similarity functions defined.")
# Out:
# ✅ Voyage similarity functions defined.

# %%
#def calculate_llama_similarity(resume_text, job_text):
#    """Calculates similarity using LLaMA-3.1 model."""
#    if llama_model is None or llama_tokenizer is None:
#        print("LLaMA-3.1 model or tokenizer not loaded. Cannot calculate similarity.")
#        return None
#
#    try:
#        messages = [
#            {
#                "role": "system",
#                "content": """You are an advanced AI model designed to analyze the compatibility between a CV and a job description. You will receive a CV and a job description. Your task is to output a structured JSON format that includes the following:
#
#1. matching_analysis: Analyze the CV against the job description to identify key strengths and gaps.
#2. description: Summarize the relevance of the CV to the job description in a few concise sentences.
#3. score: Provide a numerical compatibility score (0-100) based on qualifications, skills, and experience.
#4. recommendation: Suggest actions for the candidate to improve their match or readiness for the role.
#
#Your output must be in JSON format as follows:
#{
#  "matching_analysis": "Your detailed analysis here.",
#  "description": "A brief summary here.",
#  "score": 85,
#  "recommendation": "Your suggestions here."
#}
#""",
#            },
#            {"role": "user", "content": f"<CV> {resume_text} </CV>\n<job_description> {job_text} </job_description>"},
#        ]
#        inputs = llama_tokenizer.apply_chat_template(
#            messages, add_generation_prompt=True, return_tensors="pt"
#        )
#        outputs = llama_model.generate(inputs, max_new_tokens=256) # Increased max_new_tokens
#        generated_text = llama_tokenizer.decode(outputs[0], skip_special_tokens=True)
#
#        # Attempt to parse the JSON output and extract the score
#        try:
#            # Find the JSON part of the output
#            start_index = generated_text.find('{')
#            end_index = generated_text.rfind('}') + 1
#            json_string = generated_text[start_index:end_index]
#
#            # Parse the JSON
#            result = json.loads(json_string)
#            score = result.get('score', None) # Get score, default to None if not found
#
#            if score is not None:
#                # Normalize score to 0-1 range
#                return score / 100.0
#            else:
#                print("Warning: 'score' not found in LLaMA-3.1 output JSON.")
#                return None
#
#        except json.JSONDecodeError as e:
#            print(f"Error decoding LLaMA-3.1 output JSON: {e}")
#            print(f"Generated text was: {generated_text}")
#            return None
#        except Exception as e:
#            print(f"Error processing LLaMA-3.1 output: {e}")
#            print(f"Generated text was: {generated_text}")
#            return None
#
#    except Exception as e:
#        print(f"Error calculating LLaMA-3.1 similarity: {e}")
#        return None
#
#
#print("✅ LLaMA similarity functions defined.")

# %%
def calculate_llama_remote_similarity(resume_text, job_text):
    """Calculates similarity using remote LLaMA-3.1 model via Hugging Face Inference API."""
    remote_response_json_string = get_llama_remote_response(resume_text, job_text)

    if remote_response_json_string is None:
        print("Failed to get remote LLaMA-3.1 response.")
        return None

    try:
        # Parse the JSON string
        result = json.loads(remote_response_json_string)
        score = result.get('score', None) # Get score, default to None if not found

        if score is not None:
            # Normalize score to 0-1 range
            # Assuming the remote model returns a score between 0 and 100
            return score / 100.0
        else:
            print("Warning: 'score' not found in remote LLaMA-3.1 output JSON.")
            return None

    except json.JSONDecodeError as e:
        print(f"Error decoding remote LLaMA-3.1 output JSON: {e}")
        print(f"Generated text was: {remote_response_json_string}")
        return None
    except Exception as e:
        print(f"Error processing remote LLaMA-3.1 output: {e}")
        print(f"Generated text was: {remote_response_json_string}")
        return None

print("✅ Remote LLaMA similarity function defined.")
# Out:
# ✅ Remote LLaMA similarity function defined.

# %%
print("🎉 All similarity calculation functions are ready!")
# Out:
# 🎉 All similarity calculation functions are ready!

# %% [markdown]
# ## 5. Load and Sample Dataset
#
# Load the dataset and create a balanced sample for testing.

# %%
from google.colab import drive
drive.mount('/content/drive')
DATASET_PATH='/content/drive/MyDrive/AI-ML Self Learning/next_horizon/resume_job_recommendation/model-shashu2325-resume-job-matcher-lora'
# Out:
# Mounted at /content/drive

# %%
# Load the dataset
print("Loading dataset...")
df = pd.read_csv(f'{DATASET_PATH}/dataset.csv')
print(f"✅ Dataset loaded successfully. Shape: {df.shape}")

# Display basic information about the dataset
print(f"\nDataset Info:")
print(f"Total records: {len(df)}")
print(f"Columns: {list(df.columns)}")
print(f"\nDecision distribution:")
print(df['Decision'].value_counts())

# Split into select and reject categories
select_df = df[df['Decision'] == 'select']
reject_df = df[df['Decision'] == 'reject']

print(f"\nSelect records: {len(select_df)}")
print(f"Reject records: {len(reject_df)}")

# Determine sample sizes for balanced representation
total_samples = 100  # Adjust this number based on your needs
num_select = min(len(select_df), total_samples // 2)
num_reject = min(len(reject_df), total_samples - num_select)

# Adjust if one category is much smaller
if num_select + num_reject < total_samples:
    if len(select_df) > len(reject_df):
        num_select = min(len(select_df), total_samples - num_reject)
    else:
        num_reject = min(len(reject_df), total_samples - num_select)

print(f"\nSampling {num_select} select records and {num_reject} reject records...")

# Sample the data
sampled_select_df = select_df.sample(n=num_select, random_state=42)
sampled_reject_df = reject_df.sample(n=num_reject, random_state=42)

# Combine and shuffle
sampled_df = pd.concat([sampled_select_df, sampled_reject_df])
sampled_df = sampled_df.sample(frac=1, random_state=42).reset_index(drop=True)

print(f"✅ Final sample size: {len(sampled_df)} records")
print(f"Sample distribution: {sampled_df['Decision'].value_counts().to_dict()}")
# Out:
# Loading dataset...
# ✅ Dataset loaded successfully. Shape: (10174, 5)
#
# Dataset Info:
# Total records: 10174
# Columns: ['Role', 'Resume', 'Decision', 'Reason_for_decision', 'Job_Description']
#
# Decision distribution:
# Decision
# reject    5114
# select    5060
# Name: count, dtype: int64
#
# Select records: 5060
# Reject records: 5114
#
# Sampling 50 select records and 50 reject records...
# ✅ Final sample size: 100 records
# Sample distribution: {'reject': 50, 'select': 50}

# %% [markdown]
# ## 6. Calculate Similarity Scores for All Models
#
# Process each resume-job pair through all available embedding models. This may take several minutes depending on the sample size and available models.

# %%
# Initialize score lists for all models
bge_scores = []
openai_scores = []
bge_m3_scores = []
careerbert_scores = []
confit_scores = []
voyage_scores = []
#llama_scores = [] # Commented out as local LLaMA is removed
llama_remote_scores = []

print("🚀 Starting similarity calculation for all models...")
print(f"Processing {len(sampled_df)} resume-job pairs...")

for index, row in sampled_df.iterrows():
    resume_text = str(row['Resume']) if pd.notna(row['Resume']) else ""
    job_text = str(row['Job_Description']) if pd.notna(row['Job_Description']) else ""

    print(f"\n📋 Processing row {index+1}/{len(sampled_df)}")

    # Calculate BGE similarity
    try:
        print(f"  🔍 Calculating BGE similarity...")
        bge_score = calculate_bge_similarity(resume_text, job_text)
        print(f"  ✅ BGE similarity: {bge_score}")
    except Exception as e:
        print(f"  ❌ Error calculating BGE similarity: {e}")
        bge_score = None
    bge_scores.append(bge_score)

    # Calculate OpenAI similarity
    try:
        if openai.api_key is None:
            print(f"  ⏭️  Skipping OpenAI similarity (API key not set)")
            openai_score = None
        else:
            print(f"  🔍 Calculating OpenAI similarity...")
            openai_score = calculate_openai_similarity(resume_text, job_text)
            print(f"  ✅ OpenAI similarity: {openai_score}")
    except Exception as e:
        print(f"  ❌ Error calculating OpenAI similarity: {e}")
        openai_score = None
    openai_scores.append(openai_score)

    # Calculate BGE-M3 similarity
    try:
        print(f"  🔍 Calculating BGE-M3 similarity...")
        bge_m3_score = calculate_bge_m3_similarity(resume_text, job_text)
        print(f"  ✅ BGE-M3 similarity: {bge_m3_score}")
    except Exception as e:
        print(f"  ❌ Error calculating BGE-M3 similarity: {e}")
        bge_m3_score = None
    bge_m3_scores.append(bge_m3_score)

    # Calculate CareerBERT similarity
    try:
        print(f"  🔍 Calculating CareerBERT similarity...")
        careerbert_score = calculate_careerbert_similarity(resume_text, job_text)
        print(f"  ✅ CareerBERT similarity: {careerbert_score}")
    except Exception as e:
        print(f"  ❌ Error calculating CareerBERT similarity: {e}")
        careerbert_score = None
    careerbert_scores.append(careerbert_score)

    # Calculate ConFit similarity
    try:
        print(f"  🔍 Calculating ConFit similarity...")
        confit_score = calculate_confit_similarity(resume_text, job_text)
        print(f"  ✅ ConFit similarity: {confit_score}")
    except Exception as e:
        print(f"  ❌ Error calculating ConFit similarity: {e}")
        confit_score = None
    confit_scores.append(confit_score)

    # Calculate Voyage similarity
    try:
        if voyage_api_key is None:
            print(f"  ⏭️  Skipping Voyage similarity (API key not set)")
            voyage_score = None
        else:
            print(f"  🔍 Calculating Voyage similarity...")
            voyage_score = calculate_voyage_similarity(resume_text, job_text)
            print(f"  ✅ Voyage similarity: {voyage_score}")
    except Exception as e:
        print(f"  ❌ Error calculating Voyage similarity: {e}")
        voyage_score = None
    voyage_scores.append(voyage_score)

    # Calculate LLaMA similarity
    #try: # Commented out as local LLaMA is removed
    #    print(f"  🔍 Calculating LLaMA similarity...")
    #    llama_score = calculate_llama_similarity(resume_text, job_text)
    #    print(f"  ⚠️  LLaMA similarity: {llama_score}")
    #except Exception as e:
    #    print(f"  ❌ Error calculating LLaMA similarity: {e}")
    #    llama_score = None
    #llama_scores.append(llama_score)

    # Calculate LLaMA remote similarity
    try:
        print(f"  🔍 Calculating LLaMA remote similarity...")
        llama_remote_score = calculate_llama_remote_similarity(resume_text, job_text)
        print(f"  ⚠️  LLaMA remote similarity: {llama_remote_score}")
    except Exception as e:
        print(f"  ❌ Error calculating LLaMA remote similarity: {e}")
        llama_remote_score = None
    llama_remote_scores.append(llama_remote_score)

print("\n🎉 Score calculation complete!")
# Out:
# 🚀 Starting similarity calculation for all models...
# Processing 100 resume-job pairs...
#
# 📋 Processing row 1/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6394322514533997
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4729005547348723
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6034197932107234
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.686802714282113
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6205764148937876
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6266660140820024
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.85
#
# 📋 Processing row 2/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6075310111045837
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4892628792201232
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6195751762529121
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6223234141379688
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5046836553098263
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5973615103698398
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1042)
# Generated text was: {
#   "matching_analysis": "Courtney Walsh has a strong background in e-commerce, with over 5 years of experience in managing product listings, inventory, and online advertising. Her expertise in Shopify, Magento, and Amazon is well-suited for the role, and her achievements in increasing sales and improving customer engagement through data-driven strategies are impressive. However, her experience is mostly in commercial e-commerce, and it's unclear how her skills and experience might apply to a more specialized or forward-thinking role. Additionally, while she has a good balance of technical and soft skills, her certifications in Google Analytics and Facebook Blueprint are somewhat outdated, and she could benefit from additional training or certifications in more modern data analysis tools.",
#   "description": "This candidate has significant e-commerce experience, but it's unclear how well her skills and experience align with the requirements of a more innovative and forward-thinking company.",
#   "score": 85,
#   "recommendation": "To improve her match for this role, the candidate could consider highlighting her experience with more modern e-commerce platforms and data analysis tools, and refreshing her certifications in areas such as cloud-based analytics or AI-powered marketing. Additionally, she could benefit from emphasizing her transferable skills, such as project management and problem-solving, to demonstrate
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 3/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6244025230407715
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4567173938958846
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6818227903187443
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7518647525686116
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6227809527227118
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5527665867540841
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1194)
# Generated text was: {
#   "matching_analysis": "The candidate, Amber Nguyen, has a strong background in cloud engineering with 5+ years of experience in designing, deploying, and managing cloud infrastructure on various platforms. Her achievements in cloud cost optimization, migration, and automation are particularly relevant. However, a closer look reveals that her expertise is more focused on AWS, Azure, and Google Cloud, whereas the job description lacks specific details on the required cloud platforms. Additionally, the job's emphasis on driving strategic initiatives and innovation in finance is not explicitly mentioned in Amber's CV. Therefore, Amber's expertise in cloud engineering does match the job requirements, but her ability to adapt to the specific needs of the finance industry and the required cloud platforms remains a concern.",
#   "description": "Amber Nguyen's extensive experience as a Cloud Engineer, with achievements in cloud cost optimization, migration, and automation, makes her a strong candidate for the role. However, her expertise is more geared towards cloud engineering rather than driving strategic initiatives and innovation in finance.",
#   "score": 75,
#   "recommendation": "To improve her match, Amber may want to consider acquiring additional experience or certifications in cloud platforms relevant to the finance industry, such as IBM Cloud. She should also highlight her transferable skills,
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 4/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6045463681221008
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4685794133776665
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6151281671127874
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6144640554415993
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5092538411225866
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.633896929034167
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 17 column 30 (char 1311)
# Generated text was: {
#   "matching_analysis": {
#     "key_strengths": [
#       "5+ years of experience in driving online sales growth through optimized product listings, SEO strategies, and data-driven insights",
#       "Proven track record of improving website visibility, increasing conversions, and enhancing customer experience",
#       "Technical skills in e-commerce platforms, SEO tools, analytics, and content management systems"
#     ],
#     "gaps": [
#       "Limited experience in data analysis and shaping the future (job description's focus)",
#       "No explicit mention of working at the forefront of data analysis or in a team that shapes the future"
#     ]
#   },
#   "description": "Scott Hernandez, an experienced E-commerce Specialist, is a good fit for the role, given his strong background in driving online sales growth, improving website visibility, and enhancing customer experience. However, he may need to supplement his experience in data analysis and working in a team that shapes the future.",
#   "score": 87,
#   "recommendation": {
#     "for_self_employment": "Consider taking courses or earning certifications that focus on advanced data analysis and working at the forefront of data analysis, such as Google Data Analytics Certification or Stanford University's Data Analytics course.",
#     "for_skill_improvement": "
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 5/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6954824328422546
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.6539377722471719
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.8147501086987556
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.9536242850409697
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.7713218208428938
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.7422197048160973
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 3 column 18 (char 1142)
# Generated text was: {
#   "matching_analysis": "Aparna's CV matches the job description for a Network Engineer at 85%. She has relevant technical skills, experience, and education to support the role, including routing protocols, LAN/WAN setup, network troubleshooting, and network security best practices. However, she may be considered underqualified for the position, as her experience and certifications are limited to 1 year. She may need to enhance her skills and certification to match the level of complexity of the job. Her strong understanding of network protocols, network operating systems, and network management tools also aligns with the job requirements. However, she may lack experience with network automation tools, DevOps practices, and network data analytics tools, which are desirable attributes for the role. Aparna's ability to collaborate with cross-functional teams, provide technical support, and stay up-to-date with the latest network technologies also fits well with the job responsibilities. Her personal attributes, such as being highly motivated and detail-oriented, are beneficial for success in this position.",
#   "description": "Aparna's resume is relevant to the job description for a Network Engineer, with a focus on design, implementation, and maintenance of network infrastructure. Her experience in routing protocols, network security, and network troubleshooting aligns
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 6/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6409376859664917
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5737853806606735
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6734048807563199
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7482936350950549
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5840313968245228
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.7984721858829333
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.9
#
# 📋 Processing row 7/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6402173638343811
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4125673967826307
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6014008213828811
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6896498658409282
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5358645940494076
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6512551884003644
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.95
#
# 📋 Processing row 8/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5846679210662842
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.3905786499510855
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5517365478554799
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.5259004774259649
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.4561566624083383
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5977607731547372
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1040)
# Generated text was: {
#   "matching_analysis": "Olivia Ortiz's IT experience and skills align well with the IT Support Specialist role. Her strong background in troubleshooting, hardware, and software knowledge, combined with excellent customer service skills, make her a strong candidate for this position. Additionally, her experience in implementing a knowledge base system and reducing mean time to resolve (MTTR) demonstrate her ability to drive business success. However, her experience is mainly in a corporate setting, and it would be beneficial for her to highlight experience in the healthcare industry. Olivia's certifications, including CompTIA A+ and Cisco CCNA, also demonstrate her expertise in technical areas relevant to the role.",
#   "description": "Olivia Ortiz is a highly motivated and detail-oriented IT professional with 5+ years of experience in troubleshooting, hardware, and software maintenance. She has a proven track record of delivering exceptional customer service and improving system uptime.",
#   "score": 85,
#   "recommendation": "To enhance her match for the IT Support Specialist role in the healthcare industry, Olivia should consider highlighting experience or education related to the healthcare field. Additionally, she could emphasize transferable skills, such as her knowledge of operating systems, networking protocols, and help desk software, which would be valuable in a healthcare setting
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 9/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6343711614608765
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.3825783532386778
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5664944683316686
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7299626647668634
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.4658668617127669
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5422938941520441
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1268)
# Generated text was: {
#   "matching_analysis": "Jennifer Allen's CV demonstrates a strong background in mobile app development, with 5+ years of experience in designing and developing cross-platform mobile applications using Swift, Kotlin, and React Native. She has a proven track record of delivering high-quality, scalable, and user-friendly apps with seamless API integrations. Her technical skills align with the requirements for the Mobile App Developer role, and her experience with Agile development methodologies, API integration, and mobile UI/UX design will be valuable assets in driving innovation at the organization. However, there is a slight gap in her direct experience with AI-related technologies, which may require additional learning or development. Overall, Jennifer's skills and experience are a good match for the role, with the potential for growth and development in the AI research environment.",
#   "description": "Jennifer Allen is a highly motivated and detail-oriented Mobile App Developer with a strong background in designing and developing cross-platform mobile applications. Her experience and technical skills are relevant to the role, but she may require additional learning or development in AI-related technologies.",
#   "score": 87,
#   "recommendation": "Based on Jennifer Allen's CV, she is a strong candidate for the Mobile App Developer role. However, to further improve her match and readiness
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 10/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6521521210670471
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4703100695155098
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6114994078235707
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6011314569613009
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5440765129864192
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5482150843231721
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.85
#
# 📋 Processing row 11/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6119042634963989
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.42502433475018514
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6146523557155654
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6742214006042073
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.588262206907731
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5578079603544172
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 920)
# Generated text was: {
#   "matching_analysis": "Courtney Benitez's extensive experience in CI/CD, containerization, and infrastructure as code aligns well with the job requirements. Her skills in Agile methodologies, cloud platforms (AWS, Azure), and operating systems (Linux, Windows) are also relevant. However, there is a slight gap in her experience with e-commerce platforms, which is not explicitly mentioned in her CV. The CV highlights her leadership skills as a Senior Systems Administrator, but her current role as a DevOps Engineer emphasizes collaborative work, which might not be directly related to e-commerce strategic initiatives.",
#   "description": "Courtney Benitez's CV demonstrates a strong background in DevOps engineering, with a focus on scalable and efficient solutions. Her experience spans CI/CD, containerization, and infrastructure as code, making her a good fit for the role.",
#   "score": 87,
#   "recommendation": "To improve her match for the e-commerce DevOps Engineer role, Courtney Benitez may want to highlight her experience with e-commerce platforms and tools, such as Carteggando or Citrix. She can also expand on her Agile methodologies experience, particularly with e-commerce-related projects. Additionally, preparing examples of how she has applied DevOps principles in e-commerce
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 12/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6267775893211365
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4089199329988824
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5967783687488651
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.618137724112765
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.519306495194267
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.547968657789739
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 8 column 5 (char 985)
# Generated text was: {
#   "matching_analysis":
#     "Sarah Smith's CV shows strong relevance to the Human Resources Specialist role, with 5+ years of experience in talent management, training and development, and conflict resolution. Her experience with HR software (Workday, BambooHR) and training design and delivery are key strengths. Sarah also has excellent communication and interpersonal skills, demonstrated by her ability to build relationships with stakeholders across various levels of the organization. However, there is a gap in direct experience within the healthcare sector, which could be an obstacle.",
#   "description":
#     "Sarah Smith's CV demonstrates a strong background in HR, with a focus on talent management, training, and conflict resolution. Her experience with HR software and training design and delivery would be valuable assets in an HR Specialist role. She also brings excellent communication and interpersonal skills to the table.",
#   "score": 85,
#   "recommendation":
#     "While Sarah Smith's CV shows strong compatibility with the Human Resources Specialist role, she may need to address the gap in direct experience within the healthcare sector. Recommendations for improvement include:\n1. Highlighting relevant experiences or projects from her current role at XYZ Corporation that demonstrate her ability to apply HR principles in a healthcare context.\n2. Exploring coursework
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 13/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.7051777243614197
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5926436889472693
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.7543152206148334
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.9191406564114237
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.7175238367036156
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6854814201034692
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1038)
# Generated text was: {
#   "matching_analysis": "The provided CV aligns with the job description for the Product Manager position. Yash, the candidate, has relevant experience in product development, stakeholder management, and market research, which are key qualifications for the role. Additionally, Yash's skills in Analytics, Risk Management, and Product Development are directly applicable to the job requirements. However, some areas for improvement include technical skills, such as experience with project management tools and cloud-based product development platforms, which are not explicitly mentioned in the CV but are mentioned as preferred attributes in the job description.",
#   "description": "This candidate, Yash, has a strong background in product management, with relevant experience in driving product development, stakeholder management, and market research. The provided CV showcases Yash's analytical, problem-solving, and leadership skills, making them a strong fit for the Product Manager position.",
#   "score": 85,
#   "recommendation": "To further strengthen their application, Yash could consider obtaining certifications in product management, such as Product Management Certification, to demonstrate their expertise. Additionally, highlighting experience with project management tools, such as Jira or Asana, and cloud-based product development platforms would be beneficial. Finally, highlighting relevant communication, interpersonal, and leadership
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 14/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6494547128677368
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4178194478473313
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5836621386521367
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7425087906309493
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6273913557459659
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5868442920752303
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.9
#
# 📋 Processing row 15/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6483739018440247
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4882033449150841
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6333749096956126
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7596717658723502
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5760104364376963
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.7144014787812297
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.85
#
# 📋 Processing row 16/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5800116658210754
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.39728038054468184
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5714845728227059
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7830523670324595
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5907305934735152
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6141013155755745
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 7 column 5 (char 1232)
# Generated text was: {
#   "matching_analysis": "Kathleen Young has a strong background in data analysis, visualization, and statistical modeling, with 5+ years of experience in data-driven roles. Her skills in Python, Power BI, SQL, and statistical software make her a good fit for the company's needs. Her achievements, such as winning a data analytics competition and publishing research, demonstrate her expertise and capabilities. However, there is no explicit mention of working on next-generation products, which might be a slightly different domain compared to her previous experience. Nonetheless, she has a solid foundation in data analysis and visualization, and her passion for using data to drive business growth suggests a high potential for adapting to new challenges.",
#   "description": "Kathleen Young is a highly motivated and detail-oriented Data Analyst with a proven track record of delivering accurate and actionable insights. She has the right mix of technical skills and business acumen to excel in the role.",
#   "score": 92,
#   "recommendation": [
#     "Emphasize Kathleen's adaptability and passion for using data to drive business growth during the interview, highlighting her ability to pivot and learn new skills quickly.",
#     "Provide Kathleen with training or resources to help her bridge the gap between her current experience and the company
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 17/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.656749427318573
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5294558751138378
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6236710174610681
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7521072566007232
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6584350794193511
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6593694116551216
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 8 column 21 (char 1184)
# Generated text was: {
#   "matching_analysis": "Lucas possesses a strong background in UI design with 7+ years of lead experience, a high rating in design competitions, and a passion for creating seamless user experiences. His expertise in wireframing, Figma, and UI/UX design aligns well with the job description. However, his experience closely matches the required 8 years of experience mentioned in the job description. Furthermore, his portfolio and certifications demonstrate his proficiency in the field, but it is unclear if he has experience working with the specific collaboration tools and managing virtual teams mentioned in the job description. Nevertheless, his personal projects and design blog show his commitment to staying up-to-date with industry trends and best practices.",
#
#   "description": "Lucas is a highly accomplished UI Designer with a strong track record of delivering engaging digital experiences. His experience and certifications make him a competitive candidate for the role, but he may need to address gaps in his application, particularly regarding his experience with specific collaboration tools and managing virtual teams.",
#
#   "score": 92,
#
#   "recommendation": "Consider acquiring or highlighting experience with collaboration tools and managing virtual teams. Emphasize his ability to work with Figma and Adobe Creative Suite. Showcase any recent user research projects and analytical
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 18/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6060774922370911
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4079225416723639
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6183883998319748
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6219823079071606
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5395776442086605
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5441852276924527
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1021)
# Generated text was: {
#   "matching_analysis": "Taylor Cunningham's CV demonstrates strong alignment with the requirements of the Product Manager role, with 5+ years of experience in leading cross-functional teams, developing and executing product roadmaps, and leveraging Agile methodologies. The CV highlights specific achievements, such as a 25% revenue increase and 30% customer satisfaction improvement. However, there is a slight gap in direct experience in data science, but the candidate's experience in market research, analysis, and stakeholder communication could be transferable. Additionally, the certification in Agile Scrum Master could be valuable in this role.",
#   "description": "Taylor Cunningham's CV is highly relevant to the Product Manager role, with a strong background in product development, team leadership, and market research. Although there is some indirect experience in data science, the candidate's transferable skills and achievements make them a strong fit for the role.",
#   "score": 87,
#   "recommendation": "To further strengthen their application, Taylor Cunningham may want to consider 1) obtaining relevant certifications in data science or related fields, 2) highlighting any direct experience in data science, even if it's not explicitly mentioned, and 3) preparing to discuss transferable skills and how they can be applied to the role
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 19/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.566074550151825
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.37785799634877604
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.4818428635527828
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7337375890848427
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.392000478045726
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5416884841856754
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1145)
# Generated text was: {
#   "matching_analysis": "Matthew Martinez's extensive experience in Human Resources, particularly in Recruitment, Onboarding, Training and Development, and Conflict Resolution, matches most of the key responsibilities outlined in the job description. His certification in SHRM-CP and HRCI, as well as his proficiency in HRIS systems, further strengthen his qualifications. However, there is a slight gap in highlighting specific financial industry knowledge, which could be addressed by emphasizing relevant coursework, training, or experience.",
#   "description": "As a highly motivated and detail-oriented HR professional with 5+ years of experience, Matthew Martinez is well-suited for a Human Resources Specialist role, particularly with his expertise in Recruitment, Onboarding, Training and Development, and Conflict Resolution. His excellent communication, interpersonal, and problem-solving skills make him a strong candidate. Tailoring his application process to accentuate his transferable skills from the non-profit sector to the finance industry could make him an even more compelling candidate.",
#   "score": 85,
#   "recommendation": "Matthew Martinez should consider tailoring his application materials to highlight his relevant skills and experience in a manner that resonates with the finance industry's specific needs. This could include emphasizing his knowledge of employment laws and regulations in the financial sector, showcasing
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 20/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5519551634788513
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.2824802373959997
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.4904729525329298
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.5155196582012697
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.33404620892070247
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.3831891343501301
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.6
#
# 📋 Processing row 21/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6290376782417297
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.49625234040621846
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6257068805999438
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.8078441119540207
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6451875408329575
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6525983290683657
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1245)
# Generated text was: {
#   "matching_analysis": "Andrea Rose's extensive experience as a Data Architect in designing, implementing, and maintaining large-scale data systems aligns well with our requirements. Her proficiency in data modeling, data integration, cloud data solutions, ETL tools, and database design matches our needs. Her experience with Agile methodologies, programming languages (Java, Python, SQL), and certifications (DASCA Certified Data Architect, Informatica PowerCenter Developer) demonstrate a strong foundation in data architecture and implementation. However, there's limited evidence of direct experience with specific technologies mentioned in the job description, such as Azure and data governance frameworks. To further align, Andrea could highlight her ability to work with Azure and focus on building expertise in designing and implementing data governance frameworks.",
#   "description": "Andrea Rose is a seasoned Data Architect with a strong background in designing, implementing, and maintaining large-scale data systems. Her experience aligns well with the requirements of the job, but she may need to emphasize her ability to work with Azure and develop expertise in data governance frameworks.",
#   "score": 85,
#   "recommendation": "Based on Andrea Rose's profile, we recommend that she highlight her ability to work with Azure and invest in developing her skills in designing and implementing data governance
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 22/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5323512554168701
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4759108299205789
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5820636135262947
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.44359453780828745
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.4225797764055196
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6275823726596679
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1013)
# Generated text was: {
#   "matching_analysis": "Oshee Mehta demonstrated a strong foundation in data collection and organization but showed significant skill gaps in data visualization, SQL and database management, statistics and modeling, Excel/spreadsheet analysis, business intelligence (BI) tools, and machine learning (ML) and artificial intelligence (AI). The interview raised concerns about complex data manipulation and analysis tasks, lack of familiarity with specific tools, and limited understanding of statistical concepts and modeling techniques. However, Oshee showed a strong willingness to learn and grow. To bridge the skill gaps, recommendations were made to take online courses or certification programs, practice working with ML and AI libraries, and participate in data analysis competitions or open-source projects.",
#   "description": "Oshee Mehta's CV shows potential for a data analyst role, but significant skill gaps need to be addressed through training and development.",
#   "score": 60,
#   "recommendation": "Oshee Mehta should focus on developing skills in data visualization, SQL and database management, statistics and modeling, Excel/spreadsheet analysis, BI tools, and ML and AI. They should take online courses or certification programs, practice working with ML and AI libraries, and participate in data analysis competitions or open-source projects to build a portfolio of work and
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 23/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6242309808731079
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5313966527718409
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6581278148814186
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6547974746495745
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6601967550102799
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.7854090853932225
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 937)
# Generated text was: {
#   "matching_analysis": "The candidate, Ishaan Kapoor, has 5+ years of experience as a product manager with expertise in product strategy, agile, a/b testing, user stories, and market analysis. His achievements, such as being a product manager of the year award winner and published author, demonstrate his capabilities. However, there are some potential gaps, as his experience is primarily in technology industry whereas the job description does not specify an industry bias. Additionally, lack of details on recent contributions or innovations are not explicitly mentioned.",
#   "description": "Ishaan Kapoor's extensive experience and skills in product management make him a strong candidate for the position. His achievements demonstrate his capabilities and potential to drive growth and innovation. However, potential gaps in industry experience and recent contributions need to be addressed.",
#   "score": 90,
#   "recommendation": "Based on the job description, Ishaan Kapoor seems like a strong fit for the position, with some areas to improve. To better match the requirements, I suggest considering related experience or projects in other industries, highlighting recent contributions or innovations, and tailoring the cover letter to specifically address the job description's requirements. A deeper dive into the certification details and mentioning any relevant hackathons, product launches
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 24/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5878657698631287
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4545031418104537
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5739422521895912
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.5381066932748706
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5434622825175582
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.48847388146657
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1028)
# Generated text was: {
#   "matching_analysis": "The CV clearly demonstrates Robert Peters' expertise in AI research, particularly in NLP and Reinforcement Learning. He has a strong technical skills background, including proficiency in PyTorch and TensorFlow, and experience with large-scale AI systems. However, his professional experience is largely focused on academia and research, which may impact his ability to adapt to a commercial setting. Additionally, there is no direct mention of experience in the healthcare industry, although his experience with research and innovation may still be relevant. Some areas for improvement include gaining additional experience in product development and software engineering, as well as expanding his expertise to other areas of AI, such as computer vision or robotics.",
#   "description": "Robert Peters is a highly qualified AI researcher with a strong background in NLP and Reinforcement Learning, making him a good fit for a role driving innovation in AI research.",
#   "score": 85,
#   "recommendation": "To strengthen his application, Robert Peters could consider highlighting his transferable skills and experience in a commercial setting, such as internships or projects in industry. Additionally, he may want to consider expanding his technical skills to other areas of AI and gaining more experience in product development and software engineering. He should also be prepared to highlight examples of
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 25/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6616750955581665
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5443111502149962
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6479089063322745
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7426877788755997
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5339907793461568
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6064200361978122
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1138)
# Generated text was: {
#   "matching_analysis": "The candidate has a strong background in NLP and deep learning, with experience in developing and applying cutting-edge AI models using PyTorch and Transformers. The candidate has also demonstrated expertise in text classification, sentiment analysis, and machine translation. The CV highlights relevant technical skills such as PyTorch, TensorFlow, and cloud platforms. However, there is a gap in the requirement for expertise in GANs, which is not explicitly mentioned in the CV. Additionally, the candidate's research experience and publications focus more on NLP and deep learning, with limited experience in production environments and business value. Overall, the candidate's technical skills and research experience align with the job description, but there is room for improvement in terms of production experience and business value.",
#   "description": "The candidate is a capable AI researcher with a strong background in NLP and deep learning, but needs to demonstrate more experience in production environments and business value to be a strong fit for the role.",
#   "score": 85,
#   "recommendation": "To improve the match, the candidate should focus on highlighting their experience in production environments, business value, and applications of AI models. This can be achieved by providing more details about their projects, research experience, and publications
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 26/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6237642168998718
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.39436241549428386
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5795380365499573
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7164439222976308
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.45737887322381826
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5767683562970195
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.85
#
# 📋 Processing row 27/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6048814654350281
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.36905613369465584
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5016706975838664
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7343635766885195
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.47030817938274144
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.4981145586791906
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1007)
# Generated text was: {
#   "matching_analysis": "Sharon Waters' CV demonstrates strong technical skills in data analysis, visualization, and interpretation, with expertise in programming languages, data tools, and operating systems. Her 5+ years of experience in data analysis, particularly in predictive modeling, data validation, and cleaning, aligns well with the job description. Her achievements in improving data quality, reducing reporting time, and increasing user engagement also showcase her ability to drive business decisions with data. However, Sharon's CV could benefit from more emphasis on machine learning skills and experience, which is a key area of focus for the job description. Additionally, her professional summary could be more tailored to highlight her data analysis and interpretation skills.",
#   "description": "Sharon Waters' CV is highly relevant to the Data Analyst position, showcasing strong technical skills and experience in data analysis and visualization.",
#   "score": 85,
#   "recommendation": "To improve her match for the role, Sharon should consider highlighting her machine learning skills and experience, potentially through additional training or certifications. She should also refine her professional summary to more explicitly mention her data analysis and interpretation skills. Finally, Sharon could prepare more examples of how her data-driven solutions have driven business outcomes in her previous roles to further demonstrate her value as
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 28/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5699135065078735
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4190774616592176
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5178348209709239
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7451931107954036
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.45647111302256654
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5640417080419182
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1196)
# Generated text was: {
#   "matching_analysis": "Maria Murphy's resume strongly matches the job description for a Data Analyst position. She has over 5 years of experience in data analysis and visualization, with a strong background in statistical software and database management. Her technical skills, including proficiency in Tableau, Power BI, R, Python, and SQL, align well with the job requirements. Additionally, her achievements in developing predictive models and improving sales forecasting demonstrate her ability to drive business growth and efficiency. However, the job description emphasizes cloud computing, and Maria's resume does not explicitly mention experience in this area. Therefore, a gap exists in this area.",
#   "description": "Maria Murphy's resume showcases her expertise as a data analyst with a strong background in data visualization, statistical analysis, and business intelligence. Her achievements demonstrate her ability to drive business growth and improve operational efficiency. Although she does not have explicit experience in cloud computing, her technical skills and experience in data analysis make her a strong candidate for the position.",
#   "score": 85,
#   "recommendation": "To improve her match for the Data Analyst position, Maria Murphy should consider acquiring experience or certifications in cloud computing, such as AWS or Azure. Additionally, she may want to highlight her transferable skills in project management,
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 29/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5421893000602722
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.2628569202014251
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.44847868557127446
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.49779226180283853
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.3178234223505093
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.3795660492212483
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1158)
# Generated text was: {
# ...
#   "description": "Frank Williams is a highly motivated and detail-oriented Data Engineer with 8+ years of experience in designing, building, and maintaining large-scale data systems. He has strong proficiency in a range of programming languages, data platforms, and ETL tools, and has experience mentoring junior data engineers and
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 91/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6931665539741516
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.7094035993457334
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.786809105255505
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.9508734873741972
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.7010482131250744
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.8388831956744988
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 3 column 18 (char 1204)
# Generated text was: {
#   "matching_analysis": "The CV of Bob Johnson aligns well with the job description for a Data Engineer. Key strengths include experience in designing, building, and maintaining large-scale data systems, data warehousing, ETL, and data visualization using various technologies such as Amazon Redshift, Apache NiFi, Tableau, and Power BI. However, gaps in the CV include a lack of explicit experience with cloud platforms such as GCP and Azure, and also a need for more emphasis on agile methodologies like Scrum and Kanban. Additionally, Bob's experience with NoSQL databases and data governance frameworks is not highlighted in the CV.\n\nThe projects section of the CV is a strength, showcasing Bob's skills in data engineering. However, the certifications section is missing, which is a must-have for a Data Engineer role. Overall, the CV is very relevant to the job description, but with some minor gaps and omissions.\n\nThe candidate's summary clearly states the skills and experience relevant to the role, but could be more concise. The professional experience section provides clear examples of the candidate's skills in action, but could emphasize more quantitative results.",
#   "description": "Bob Johnson's CV is highly relevant to the job description for a Data Engineer, with
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 92/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6196497678756714
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5952101883995998
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.7226931255161093
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6889977102626803
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.713510038729956
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.7252199960298064
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1102)
# Generated text was: {
#   "matching_analysis": "Tyler Frazier's CV is highly relevant to the data engineer role, with strengths in MLOPs, Airflow, ETL, and Spark. His experience in designing and implementing scalable data pipelines, deploying machine learning models, and collaborating with cross-functional teams is particularly aligned with the job requirements. However, there is some room for improvement in terms of Big Data expertise, as his skills are more focused on Spark and Hadoop-related technologies. Additionally, his experience as a Data Analyst could be seen as a potential gap, as a Data Engineer typically requires more technical expertise in data processing and engineering.",
#   "description": "Tyler Frazier's CV is a strong match for the data engineer role, with a proven track record of designing, developing, and deploying scalable data pipelines and machine learning models. His technical skills in MLOPs, Airflow, ETL, and Spark are highly relevant to the position, and his experience working with cloud platforms such as AWS and GCP is a significant advantage.",
#   "score": 92,
#   "recommendation": "To further improve his readiness for the role, Tyler Frazier could consider obtaining additional certifications or training in Big Data technologies, such as Hadoop and Hive, to bridge the gap in
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 93/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6364143490791321
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5139748618065012
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6763928837857587
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7500990406418871
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5507187936564792
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6217388584222647
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.85
#
# 📋 Processing row 94/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6075687408447266
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.3360606455792388
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5300620991239537
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.5089787795020863
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.4941958984986899
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5694108821807593
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1037)
# Generated text was: {
#   "matching_analysis": "Tracy's background in veterinary medicine and experience in product development and management provide a strong foundation for a Product Manager role. She leverages her analytical and problem-solving skills to drive business growth and customer satisfaction. Tracy has experience working with cross-functional teams and has a proven track record of driving product roadmaps. She has also demonstrated effective stakeholder communication and agile methodology skills. However, there may be a gap in domain-specific knowledge in e-commerce. Further development in this area may enhance her readiness for the role.",
#   "description": "Tracy is a results-driven Product Manager with a strong background in product development and management, stakeholder communication, and agile methodologies. Her experience and skills are highly relevant to the Product Manager role, and she demonstrates a strong potential for the position with further domain-specific knowledge development.",
#   "score": 85,
#   "recommendation": "To improve her match and readiness for the role, Tracy should consider developing her domain-specific knowledge in e-commerce by taking online courses or attending industry conferences. Additionally, networking with professionals in the e-commerce industry could help her build relationships and stay up-to-date on industry trends. Lastly, highlighting experiences or skills gained from her previous roles that demonstrate adaptation to new areas, such as
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 95/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6166478395462036
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4259388228261719
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5796884666320872
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7569990950923927
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.5080609042427217
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6195270336151106
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1231)
# Generated text was: {
#   "matching_analysis": "Nicole Brooks' CV demonstrates strong technical skills in mobile app development, with 5+ years of experience in Swift, Mobile UI/UX, and API integration. Her professional experience as a Senior Mobile App Developer at TechCorp showcases her ability to lead projects, collaborate with teams, and prioritize tasks. However, her CV is somewhat lacking in specific data analysis skills, despite mentioning proficiency in Agile development methodologies. Her certifications in iOS and Mobile UI/UX design are relevant but may not align with the job's emphasis on data analysis. Her experience as a Mobile App Developer at AppDev demonstrates her ability to integrate APIs and databases, but may not have prepared her for the data analysis aspect of the job.",
#   "description": "Nicole Brooks' CV shows strong technical skills and experience in mobile app development, but may lack specific data analysis skills and experience that are emphasized in the job description. Her track record of delivering high-quality apps on time and on budget demonstrates her ability to meet deadlines and lead projects, but may not directly translate to the role's focus on data analysis.",
#   "score": 65,
#   "recommendation": "Nicole Brooks should consider taking courses or obtaining certifications in data analysis, machine learning, or data visualization to
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 96/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.5983526110649109
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.3773886015119541
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5609845974279363
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6544798320206747
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.420823838711172
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.5734260041393054
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.85
#
# 📋 Processing row 97/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.688313364982605
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.6665256834471471
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.7415749240956369
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.9440207977860023
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.700806125874685
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.8046329171499519
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1011)
# Generated text was: {
#   "matching_analysis": "Diana Johnson's CV shows strong technical skills, experience, and achievements in data engineering, which aligns with the key responsibilities and requirements of the Data Engineer role. She has a solid background in designing, building, and maintaining large-scale data systems, developing ETL processes, and collaborating with cross-functional teams. Her experience with data storage solutions, including Apache Cassandra and Apache Kafka, and her skills in programming languages such as Python, Java, and SQL are particularly relevant to the role. However, there are some areas where her CV could be improved, such as her lack of experience with cloud-based platforms, such as AWS, Azure, or Google Cloud Platform, which is mentioned as a requirement in the job description.",
#   "description": "Diana Johnson's CV is highly relevant to the Data Engineer role, given her strong technical skills, experience, and achievements in data engineering.",
#   "score": 85,
#   "recommendation": "To improve her match for the role, Diana Johnson may want to gain more experience with cloud-based platforms, such as AWS, Azure, or Google Cloud Platform, and consider obtaining certifications in data engineering or related fields. Additionally, she could highlight her transferable skills, such as her experience with agile methodologies
#   ⚠️  LLaMA remote similarity: None
#
# 📋 Processing row 98/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.6323258280754089
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.5073067369487583
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.6053635127775007
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.7822983118996119
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6280772054742548
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6325786357250226
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.8
#
# 📋 Processing row 99/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.62285315990448
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.4761082793361463
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.5408177489351607
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.6350503374882741
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.44042168615146654
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.6171693322138471
#   🔍 Calculating LLaMA remote similarity...
#   ⚠️  LLaMA remote similarity: 0.85
#
# 📋 Processing row 100/100
#   🔍 Calculating BGE similarity...
#   ✅ BGE similarity: 0.70082688331604
#   🔍 Calculating OpenAI similarity...
#   ✅ OpenAI similarity: 0.7284125826546463
#   🔍 Calculating BGE-M3 similarity...
#   ✅ BGE-M3 similarity: 0.7315709626961919
#   🔍 Calculating CareerBERT similarity...
#   ✅ CareerBERT similarity: 0.9117316441560216
#   🔍 Calculating ConFit similarity...
#   ✅ ConFit similarity: 0.6642613933728289
#   🔍 Calculating Voyage similarity...
#   ✅ Voyage similarity: 0.8149558437060165
#   🔍 Calculating LLaMA remote similarity...
# Error decoding remote LLaMA-3.1 output JSON: Unterminated string starting at: line 5 column 21 (char 1226)
# Generated text was: {
#   "matching_analysis": "The CV of Alice Wilson is highly relevant to the UI Engineer job description, with over 5 years of experience in designing and developing intuitive and user-friendly interfaces. Alice's technical skills, including HTML, CSS, JavaScript, and React, align well with the job's requirements. However, her experience and skills are more extensive than the job description's minimum requirements, indicating a strong potential for growth and contribution to the company. Some gaps identified include lack of specific experience with UI component libraries and front-end build tools, which the job description considers 'nice to have' skills. Her certifications, including Certified Scrum Master (CSM) and Certified Web Developer (CWD), demonstrate her commitment to professional development and adherence to industry standards.",
#   "description": "Alice's CV demonstrates a high level of relevance to the UI Engineer role, showcasing extensive experience and skills aligned with the job description's requirements. Her certifications and experience in leading teams and delivering high-profile projects demonstrate potential for growth and contribution to the company.",
#   "score": 92,
#   "recommendation": "Based on the matched analysis, it is recommended that Alice tailor her application to highlight her extensive experience and skills, while also addressing the job description's specific requirements, such as UI
#   ⚠️  LLaMA remote similarity: None
#
# 🎉 Score calculation complete!

# %% [markdown]
# ## 7. Generate Predictions and Classification
#
# Convert similarity scores to binary predictions using a threshold and create a comprehensive comparison table.

# %%
# Add the scores as new columns to the sampled DataFrame
sampled_df['bge_similarity'] = bge_scores
sampled_df['openai_similarity'] = openai_scores
sampled_df['bge_m3_similarity'] = bge_m3_scores
sampled_df['careerbert_similarity'] = careerbert_scores
sampled_df['confit_similarity'] = confit_scores
sampled_df['voyage_similarity'] = voyage_scores
#sampled_df['llama_similarity'] = llama_scores
sampled_df['llama_remote_similarity'] = llama_remote_scores

# Define threshold for classification
threshold = 0.5
print(f"Using threshold: {threshold} for classification")

# Create predictions for all models
def make_prediction(score, threshold=0.5):
    if score is None or pd.isna(score):
        return 'unknown'
    return 'select' if score > threshold else 'reject'

sampled_df['bge_prediction'] = sampled_df['bge_similarity'].apply(lambda x: make_prediction(x, threshold))
sampled_df['openai_prediction'] = sampled_df['openai_similarity'].apply(lambda x: make_prediction(x, threshold))
sampled_df['bge_m3_prediction'] = sampled_df['bge_m3_similarity'].apply(lambda x: make_prediction(x, threshold))
sampled_df['careerbert_prediction'] = sampled_df['careerbert_similarity'].apply(lambda x: make_prediction(x, threshold))
sampled_df['confit_prediction'] = sampled_df['confit_similarity'].apply(lambda x: make_prediction(x, threshold))
sampled_df['voyage_prediction'] = sampled_df['voyage_similarity'].apply(lambda x: make_prediction(x, threshold))
#sampled_df['llama_prediction'] = sampled_df['llama_similarity'].apply(lambda x: make_prediction(x, threshold))
sampled_df['llama_remote_prediction'] = sampled_df['llama_remote_similarity'].apply(lambda x: make_prediction(x, threshold))

print("✅ Predictions generated for all models!")

# Display the comparative table
print("\n📊 Comparative Table of Similarity Scores and Predictions:")
display_columns = ['Role', 'Decision',
                  'bge_similarity', 'bge_prediction',
                  'openai_similarity', 'openai_prediction',
                  'bge_m3_similarity', 'bge_m3_prediction',
                  'careerbert_similarity', 'careerbert_prediction',
                  'confit_similarity', 'confit_prediction',
                  'voyage_similarity', 'voyage_prediction',
                  #'llama_similarity', 'llama_prediction',
                  'llama_remote_similarity', 'llama_remote_prediction']

comparison_table = sampled_df[display_columns]
print(comparison_table.to_string(index=False, float_format='%.4f'))
# Out:
# Using threshold: 0.5 for classification
# ✅ Predictions generated for all models!
#
# 📊 Comparative Table of Similarity Scores and Predictions:
#                       Role Decision  bge_similarity bge_prediction  openai_similarity openai_prediction  bge_m3_similarity bge_m3_prediction  careerbert_similarity careerbert_prediction  confit_similarity confit_prediction  voyage_similarity voyage_prediction  llama_remote_similarity llama_remote_prediction
#          Robotics Engineer   reject          0.6394         select             0.4729            reject             0.6034            select                 0.6868                select             0.6206            select             0.6267            select                   0.8500                  select
#      E-commerce Specialist   reject          0.6075         select             0.4893            reject             0.6196            select                 0.6223                select             0.5047            select             0.5974            select                      NaN                 unknown
#             Cloud Engineer   reject          0.6244         select             0.4567            reject             0.6818            select                 0.7519                select             0.6228            select             0.5528            select                      NaN                 unknown
#      E-commerce Specialist   select          0.6045         select             0.4686            reject             0.6151            select                 0.6145                select             0.5093            select             0.6339            select                      NaN                 unknown
#           Network Engineer   select          0.6955         select             0.6539            select             0.8148            select                 0.9536                select             0.7713            select             0.7422            select                      NaN                 unknown
#            Product Manager   select          0.6409         select             0.5738            select             0.6734            select                 0.7483                select             0.5840            select             0.7985            select                   0.9000                  select
#     Database Administrator   select          0.6402         select             0.4126            reject             0.6014            select                 0.6896                select             0.5359            select             0.6513            select                   0.9500                  select
#      IT Support Specialist   reject          0.5847         select             0.3906            reject             0.5517            select                 0.5259                select             0.4562            reject             0.5978            select                      NaN                 unknown
#       Mobile App Developer   select          0.6344         select             0.3826            reject             0.5665            select                 0.7300                select             0.4659            reject             0.5423            select                      NaN                 unknown
#                QA Engineer   select          0.6522         select             0.4703            reject             0.6115            select                 0.6011                select             0.5441            select             0.5482            select                   0.8500                  select
#            DevOps Engineer   select          0.6119         select             0.4250            reject             0.6147            select                 0.6742                select             0.5883            select             0.5578            select                      NaN                 unknown
# Human Resources Specialist   select          0.6268         select             0.4089            reject             0.5968            select                 0.6181                select             0.5193            select             0.5480            select                      NaN                 unknown
#            Product Manager   reject          0.7052         select             0.5926            select             0.7543            select                 0.9191                select             0.7175            select             0.6855            select                      NaN                 unknown
#       Mobile App Developer   select          0.6495         select             0.4178            reject             0.5837            select                 0.7425                select             0.6274            select             0.5868            select                   0.9000                  select
#              Data Engineer   reject          0.6484         select             0.4882            reject             0.6334            select                 0.7597                select             0.5760            select             0.7144            select                   0.8500                  select
#               Data Analyst   select          0.5800         select             0.3973            reject             0.5715            select                 0.7831                select             0.5907            select             0.6141            select                      NaN                 unknown
#                UI Designer   reject          0.6567         select             0.5295            select             0.6237            select                 0.7521                select             0.6584            select             0.6594            select                      NaN                 unknown
#            Product Manager   reject          0.6061         select             0.4079            reject             0.6184            select                 0.6220                select             0.5396            select             0.5442            select                      NaN                 unknown
# Human Resources Specialist   select          0.5661         select             0.3779            reject             0.4818            reject                 0.7337                select             0.3920            reject             0.5417            select                      NaN                 unknown
#             Content Writer   select          0.5520         select             0.2825            reject             0.4905            reject                 0.5155                select             0.3340            reject             0.3832            reject                   0.6000                  select
#             Data Architect   reject          0.6290         select             0.4963            reject             0.6257            select                 0.8078                select             0.6452            select             0.6526            select                      NaN                 unknown
#               data analyst   reject          0.5324         select             0.4759            reject             0.5821            select                 0.4436                reject             0.4226            reject             0.6276            select                      NaN                 unknown
#            product manager   select          0.6242         select             0.5314            select             0.6581            select                 0.6548                select             0.6602            select             0.7854            select                      NaN                 unknown
#              AI Researcher   select          0.5879         select             0.4545            reject             0.5739            select                 0.5381                select             0.5435            select             0.4885            reject                      NaN                 unknown
#              AI Researcher   reject          0.6617         select             0.5443            select             0.6479            select                 0.7427                select             0.5340            select             0.6064            select                      NaN                 unknown
#             Game Developer   select          0.6238         select             0.3944            reject             0.5795            select                 0.7164                select             0.4574            reject             0.5768            select                   0.8500                  select
#               Data Analyst   select          0.6049         select             0.3691            reject             0.5017            select                 0.7344                select             0.4703            reject             0.4981            reject                      NaN                 unknown
#               Data Analyst   reject          0.5699         select             0.4191            reject             0.5178            select                 0.7452                select             0.4565            reject             0.5640            select                      NaN                 unknown
#             Data Scientist   select          0.5422         select             0.2629            reject             0.4485            reject                 0.4978                reject             0.3178            reject             0.3796            reject                      NaN                 unknown
#            AR/VR Developer   reject          0.6349         select             0.4675            reject             0.5565            select                 0.7173                select             0.4697            reject             0.6442            select                      NaN                 unknown
#       System Administrator   select          0.6214         select             0.3863            reject             0.6398            select                 0.7721                select             0.5995            select             0.6242            select                   0.9200                  select
#       Blockchain Developer   select          0.6610         select             0.5643            select             0.6643            select                 0.7887                select             0.5109            select             0.6592            select                   0.8500                  select
#               data analyst   reject          0.5612         select             0.4658            reject             0.5652            select                 0.4223                reject             0.3662            reject             0.5778            select                   0.3000                  reject
#          Software Engineer   select          0.6214         select             0.3522            reject             0.5942            select                 0.7468                select             0.5132            select             0.5269            select                      NaN                 unknown
#             Data Scientist   reject          0.6079         select             0.4478            reject             0.5150            select                 0.7780                select             0.5198            select             0.5015            select                   0.8500                  select
#                UI Engineer   select          0.6474         select             0.4516            reject             0.5723            select                 0.7272                select             0.5224            select             0.6160            select                   0.8500                  select
#             Cloud Engineer   reject          0.6589         select             0.4678            reject             0.6622            select                 0.7684                select             0.6098            select             0.5869            select                      NaN                 unknown
#      E-commerce Specialist   reject          0.6295         select             0.4776            reject             0.5968            select                 0.6606                select             0.3458            reject             0.6045            select                   0.8500                  select
#      E-commerce Specialist   select          0.6263         select             0.3719            reject             0.5220            select                 0.5734                select             0.4651            reject             0.6023            select                   0.4200                  reject
#       Blockchain Developer   select          0.6391         select             0.3917            reject             0.6076            select                 0.7309                select             0.4058            reject             0.5413            select                      NaN                 unknown
#             Game Developer   select          0.6232         select             0.3008            reject             0.6339            select                 0.5778                select             0.4947            reject             0.5763            select                   0.7000                  select
#              AI Researcher   select          0.6013         select             0.4463            reject             0.5742            select                 0.6261                select             0.5828            select             0.5307            select                   0.9200                  select
#      E-commerce Specialist   select          0.6105         select             0.3607            reject             0.5900            select                 0.5631                select             0.5252            select             0.5940            select                   0.7000                  select
#     Database Administrator   reject          0.6454         select             0.4830            reject             0.6408            select                 0.8474                select             0.5739            select             0.6293            select                   0.8500                  select
#               Data Analyst   select          0.6298         select             0.4829            reject             0.6135            select                 0.7984                select             0.6730            select             0.6027            select                      NaN                 unknown
#             Cloud Engineer   select          0.6256         select             0.4292            reject             0.6297            select                 0.7135                select             0.4916            reject             0.5203            select                      NaN                 unknown
#            Product Manager   reject          0.6231         select             0.4667            reject             0.6068            select                 0.6971                select             0.5534            select             0.5591            select                   0.9200                  select
#             Data Architect   select          0.6627         select             0.5508            select             0.6719            select                 0.8162                select             0.7548            select             0.6028            select                      NaN                 unknown
#             Data Scientist   reject          0.6299         select             0.6572            select             0.6849            select                 0.9113                select             0.6631            select             0.7987            select                      NaN                 unknown
#          software engineer   select          0.5637         select             0.4543            reject             0.5292            select                 0.4332                reject             0.3971            reject             0.5896            select                      NaN                 unknown
#             Data Scientist   select          0.5804         select             0.3899            reject             0.5061            select                 0.7417                select             0.4550            reject             0.5915            select                   0.8500                  select
#              Data Engineer   select          0.6019         select             0.4021            reject             0.5210            select                 0.5296                select             0.5080            select             0.6316            select                      NaN                 unknown
#       Full Stack Developer   select          0.6137         select             0.3655            reject             0.5550            select                 0.5631                select             0.3694            reject             0.5293            select                      NaN                 unknown
#       Blockchain Developer   select          0.6526         select             0.4990            reject             0.6815            select                 0.7525                select             0.5710            select             0.6705            select                   0.9200                  select
#               data analyst   select          0.5620         select             0.3698            reject             0.5253            select                 0.4910                reject             0.3754            reject             0.5962            select                      NaN                 unknown
#                ui engineer   reject          0.6500         select             0.6131            select             0.6938            select                 0.7155                select             0.6676            select             0.7772            select                   0.9200                  select
#            Product Manager   select          0.6990         select             0.6873            select             0.7756            select                 0.9323                select             0.7902            select             0.8593            select                      NaN                 unknown
#             data scientist   reject          0.5441         select             0.3681            reject             0.5187            select                 0.5960                select             0.4232            reject             0.5790            select                   0.4500                  reject
#             Game Developer   select          0.6300         select             0.4293            reject             0.6219            select                 0.6786                select             0.6029            select             0.6765            select                      NaN                 unknown
#               data analyst   reject          0.5574         select             0.4811            reject             0.6398            select                 0.5509                select             0.4177            reject             0.6443            select                      NaN                 unknown
#                QA Engineer   reject          0.6052         select             0.4881            reject             0.6416            select                 0.6503                select             0.6128            select             0.6449            select                   0.8800                  select
#           Business Analyst   reject          0.6116         select             0.4711            reject             0.6025            select                 0.7157                select             0.6156            select             0.6169            select                   0.9200                  select
#          software engineer   reject          0.6411         select             0.5138            select             0.7206            select                 0.7694                select             0.5953            select             0.6230            select                      NaN                 unknown
#                QA Engineer   select          0.6109         select             0.4339            reject             0.6184            select                 0.5749                select             0.5838            select             0.5354            select                      NaN                 unknown
#                UX Designer   reject          0.6332         select             0.4856            reject             0.5825            select                 0.7268                select             0.6079            select             0.5456            select                      NaN                 unknown
#            Cloud Architect   reject          0.6695         select             0.5174            select             0.6317            select                 0.8192                select             0.6718            select             0.6546            select                   0.9200                  select
#                QA Engineer   select          0.5694         select             0.2810            reject             0.4622            reject                 0.5374                select             0.3544            reject             0.3749            reject                   0.4500                  reject
#       Mobile App Developer   reject          0.5818         select             0.2946            reject             0.4663            reject                 0.5423                select             0.3476            reject             0.4315            reject                   0.4000                  reject
#             Data Scientist   reject          0.6136         select             0.4329            reject             0.5438            select                 0.7698                select             0.5786            select             0.5948            select                   0.8500                  select
# Human Resources Specialist   reject          0.6225         select             0.4328            reject             0.6149            select                 0.7757                select             0.5227            select             0.5448            select                      NaN                 unknown
#               data analyst   reject          0.5556         select             0.4898            reject             0.6169            select                 0.5246                select             0.4650            reject             0.6513            select                      NaN                 unknown
#          Robotics Engineer   select          0.6527         select             0.5460            select             0.6769            select                 0.7942                select             0.6594            select             0.6625            select                      NaN                 unknown
#       Blockchain Developer   reject          0.6465         select             0.4834            reject             0.6766            select                 0.8208                select             0.5529            select             0.6672            select                      NaN                 unknown
#            product manager   select          0.6689         select             0.5848            select             0.7450            select                 0.6777                select             0.6862            select             0.6056            select                   0.9200                  select
#             Cloud Engineer   reject          0.5568         select             0.2674            reject             0.4440            reject                 0.4676                reject             0.3599            reject             0.3656            reject                      NaN                 unknown
#          Software Engineer   reject          0.6563         select             0.4572            reject             0.6833            select                 0.7513                select             0.4613            reject             0.5566            select                      NaN                 unknown
#               Data Analyst   reject          0.6286         select             0.4941            reject             0.5869            select                 0.7537                select             0.7424            select             0.6239            select                      NaN                 unknown
#          Software Engineer   select          0.6420         select             0.5140            select             0.7133            select                 0.6721                select             0.6053            select             0.5785            select                      NaN                 unknown
#            product manager   reject          0.6366         select             0.5448            select             0.6347            select                 0.6416                select             0.6744            select             0.7664            select                   0.9200                  select
#            Product Manager   reject          0.6519         select             0.4310            reject             0.6214            select                 0.6822                select             0.6596            select             0.5219            select                      NaN                 unknown
#             data scientist   reject          0.5591         select             0.3885            reject             0.5907            select                 0.5722                select             0.3070            reject             0.6176            select                   0.6000                  select
#            Cloud Architect   reject          0.6475         select             0.4742            reject             0.6193            select                 0.7967                select             0.5551            select             0.5673            select                      NaN                 unknown
#            Product Manager   select          0.6324         select             0.4268            reject             0.6056            select                 0.5941                select             0.4430            reject             0.5319            select                      NaN                 unknown
#              Data Engineer   select          0.6487         select             0.4547            reject             0.5742            select                 0.7979                select             0.6905            select             0.5836            select                   0.9200                  select
#             Content Writer   select          0.6311         select             0.3706            reject             0.5856            select                 0.7241                select             0.5271            select             0.5787            select                      NaN                 unknown
# Human Resources Specialist   reject          0.6030         select             0.4741            reject             0.6765            select                 0.7685                select             0.5810            select             0.5912            select                   0.8500                  select
#            product manager   select          0.6690         select             0.5272            select             0.7087            select                 0.6453                select             0.7037            select             0.6302            select                      NaN                 unknown
#          software engineer   select          0.5670         select             0.3517            reject             0.4898            reject                 0.5054                select             0.2114            reject             0.5604            select                      NaN                 unknown
#             Data Scientist   select          0.6393         select             0.5625            select             0.6396            select                 0.7890                select             0.6668            select             0.6395            select                   0.9200                  select
#              Data Engineer   reject          0.6724         select             0.6747            select             0.6790            select                 0.9199                select             0.6688            select             0.8191            select                      NaN                 unknown
#              Data Engineer   reject          0.6932         select             0.7094            select             0.7868            select                 0.9509                select             0.7010            select             0.8389            select                      NaN                 unknown
#              data engineer   reject          0.6196         select             0.5952            select             0.7227            select                 0.6890                select             0.7135            select             0.7252            select                      NaN                 unknown
#      Cybersecurity Analyst   reject          0.6364         select             0.5140            select             0.6764            select                 0.7501                select             0.5507            select             0.6217            select                   0.8500                  select
#            Product Manager   reject          0.6076         select             0.3361            reject             0.5301            select                 0.5090                select             0.4942            reject             0.5694            select                      NaN                 unknown
#       Mobile App Developer   select          0.6166         select             0.4259            reject             0.5797            select                 0.7570                select             0.5081            select             0.6195            select                      NaN                 unknown
#            DevOps Engineer   reject          0.5984         select             0.3774            reject             0.5610            select                 0.6545                select             0.4208            reject             0.5734            select                   0.8500                  select
#              Data Engineer   reject          0.6883         select             0.6665            select             0.7416            select                 0.9440                select             0.7008            select             0.8046            select                      NaN                 unknown
#               Data Analyst   select          0.6323         select             0.5073            select             0.6054            select                 0.7823                select             0.6281            select             0.6326            select                   0.8000                  select
#           Business Analyst   reject          0.6229         select             0.4761            reject             0.5408            select                 0.6351                select             0.4404            reject             0.6172            select                   0.8500                  select
#                UI Engineer   reject          0.7008         select             0.7284            select             0.7316            select                 0.9117                select             0.6643            select             0.8150            select                      NaN                 unknown

# %% [markdown]
# ## 8. Evaluate Model Performance
#
# Calculate comprehensive performance metrics for each embedding model including accuracy, precision, recall, and F1-score.

# %%
# Define models to evaluate
models = {
    'BGE': ('bge_prediction', 'bge_similarity'),
    'OpenAI': ('openai_prediction', 'openai_similarity'),
    'BGE-M3': ('bge_m3_prediction', 'bge_m3_similarity'),
    'CareerBERT': ('careerbert_prediction', 'careerbert_similarity'),
    'ConFit V2': ('confit_prediction', 'confit_similarity'),
    'Voyage-3-Large': ('voyage_prediction', 'voyage_similarity'),
    #'LLaMA-3.1': ('llama_prediction', 'llama_similarity'),
    'LLaMA-3.1-Remote': ('llama_remote_prediction', 'llama_remote_similarity')
}

# Store results for comparison
results_summary = []

print("📊 COMPREHENSIVE MODEL PERFORMANCE EVALUATION")
print("=" * 80)

for model_name, (pred_col, sim_col) in models.items():
    print(f"\n🔍 {model_name} Model Performance:")
    print("-" * 50)

    # Filter out rows with unknown predictions
    valid_mask = sampled_df[pred_col] != 'unknown'
    valid_df = sampled_df[valid_mask]

    if len(valid_df) == 0:
        print(f"❌ No valid predictions for {model_name}")
        results_summary.append({
            'Model': model_name,
            'Accuracy': None,
            'Precision': None,
            'Recall': None,
            'F1': None,
            'Valid_Samples': 0
        })
        continue

    try:
        # Calculate metrics
        accuracy = accuracy_score(valid_df['Decision'], valid_df[pred_col])
        precision, recall, f1, _ = precision_recall_fscore_support(
            valid_df['Decision'], valid_df[pred_col], average='weighted'
        )

        print(f"✅ Accuracy: {accuracy:.4f}")
        print(f"✅ Precision: {precision:.4f}")
        print(f"✅ Recall: {recall:.4f}")
        print(f"✅ F1-Score: {f1:.4f}")
        print(f"📈 Valid Samples: {len(valid_df)}/{len(sampled_df)}")

        # Detailed classification report
        print(f"\n📋 Detailed Classification Report:")
        print(classification_report(valid_df['Decision'], valid_df[pred_col]))

        # Store results
        results_summary.append({
            'Model': model_name,
            'Accuracy': accuracy,
            'Precision': precision,
            'Recall': recall,
            'F1': f1,
            'Valid_Samples': len(valid_df)
        })

    except Exception as e:
        print(f"❌ Error calculating metrics for {model_name}: {e}")
        results_summary.append({
            'Model': model_name,
            'Accuracy': None,
            'Precision': None,
            'Recall': None,
            'F1': None,
            'Valid_Samples': len(valid_df)
        })

print("\n🎉 Performance evaluation complete!")
# Out:
# 📊 COMPREHENSIVE MODEL PERFORMANCE EVALUATION
# ================================================================================
#
# 🔍 BGE Model Performance:
# --------------------------------------------------
# ✅ Accuracy: 0.5000
# ✅ Precision: 0.2500
# ✅ Recall: 0.5000
# ✅ F1-Score: 0.3333
# 📈 Valid Samples: 100/100
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.00      0.00      0.00        50
#       select       0.50      1.00      0.67        50
#
#     accuracy                           0.50       100
#    macro avg       0.25      0.50      0.33       100
# weighted avg       0.25      0.50      0.33       100
#
#
# 🔍 OpenAI Model Performance:
# --------------------------------------------------
# ✅ Accuracy: 0.4800
# ✅ Precision: 0.4740
# ✅ Recall: 0.4800
# ✅ F1-Score: 0.4482
# 📈 Valid Samples: 100/100
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.49      0.72      0.58        50
#       select       0.46      0.24      0.32        50
#
#     accuracy                           0.48       100
#    macro avg       0.47      0.48      0.45       100
# weighted avg       0.47      0.48      0.45       100
#
#
# 🔍 BGE-M3 Model Performance:
# --------------------------------------------------
# ✅ Accuracy: 0.4700
# ✅ Precision: 0.3848
# ✅ Recall: 0.4700
# ✅ F1-Score: 0.3498
# 📈 Valid Samples: 100/100
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.29      0.04      0.07        50
#       select       0.48      0.90      0.63        50
#
#     accuracy                           0.47       100
#    macro avg       0.38      0.47      0.35       100
# weighted avg       0.38      0.47      0.35       100
#
#
# 🔍 CareerBERT Model Performance:
# --------------------------------------------------
# ✅ Accuracy: 0.5000
# ✅ Precision: 0.5000
# ✅ Recall: 0.5000
# ✅ F1-Score: 0.3800
# 📈 Valid Samples: 100/100
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.50      0.06      0.11        50
#       select       0.50      0.94      0.65        50
#
#     accuracy                           0.50       100
#    macro avg       0.50      0.50      0.38       100
# weighted avg       0.50      0.50      0.38       100
#
#
# 🔍 ConFit V2 Model Performance:
# --------------------------------------------------
# ✅ Accuracy: 0.4900
# ✅ Precision: 0.4887
# ✅ Recall: 0.4900
# ✅ F1-Score: 0.4748
# 📈 Valid Samples: 100/100
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.48      0.32      0.39        50
#       select       0.49      0.66      0.56        50
#
#     accuracy                           0.49       100
#    macro avg       0.49      0.49      0.47       100
# weighted avg       0.49      0.49      0.47       100
#
#
# 🔍 Voyage-3-Large Model Performance:
# --------------------------------------------------
# ✅ Accuracy: 0.4700
# ✅ Precision: 0.3848
# ✅ Recall: 0.4700
# ✅ F1-Score: 0.3498
# 📈 Valid Samples: 100/100
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.29      0.04      0.07        50
#       select       0.48      0.90      0.63        50
#
#     accuracy                           0.47       100
#    macro avg       0.38      0.47      0.35       100
# weighted avg       0.38      0.47      0.35       100
#
#
# 🔍 LLaMA-3.1-Remote Model Performance:
# --------------------------------------------------
# ✅ Accuracy: 0.5250
# ✅ Precision: 0.5571
# ✅ Recall: 0.5250
# ✅ F1-Score: 0.4473
# 📈 Valid Samples: 40/100
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.60      0.15      0.24        20
#       select       0.51      0.90      0.65        20
#
#     accuracy                           0.53        40
#    macro avg       0.56      0.53      0.45        40
# weighted avg       0.56      0.53      0.45        40
#
#
# 🎉 Performance evaluation complete!
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## 9. Create Summary Comparison Table
#
# Generate a comprehensive summary table ranking all models by performance metrics.

# %%
# Create summary comparison table
print("🏆 SUMMARY COMPARISON TABLE")
print("=" * 80)

results_df = pd.DataFrame(results_summary)
print(results_df.to_string(index=False, float_format='%.4f'))

# Find best performing model
valid_results = results_df[results_df['Accuracy'].notna()]
if len(valid_results) > 0:
    best_model = valid_results.loc[valid_results['Accuracy'].idxmax()]
    print(f"\n🥇 Best Performing Model: {best_model['Model']} (Accuracy: {best_model['Accuracy']:.4f})")

    # Sort by accuracy for ranking
    sorted_results = valid_results.sort_values('Accuracy', ascending=False)
    print(f"\n📊 Model Ranking by Accuracy:")
    for i, (_, row) in enumerate(sorted_results.iterrows(), 1):
        medal = "🥇" if i == 1 else "🥈" if i == 2 else "🥉" if i == 3 else f"{i}."
        print(f"{medal} {row['Model']}: {row['Accuracy']:.4f}")
else:
    print("\n⚠️  No valid results found for comparison.")

print("\n" + "=" * 80)
# Out:
# 🏆 SUMMARY COMPARISON TABLE
# ================================================================================
#            Model  Accuracy  Precision  Recall     F1  Valid_Samples
#              BGE    0.5000     0.2500  0.5000 0.3333            100
#           OpenAI    0.4800     0.4740  0.4800 0.4482            100
#           BGE-M3    0.4700     0.3848  0.4700 0.3498            100
#       CareerBERT    0.5000     0.5000  0.5000 0.3800            100
#        ConFit V2    0.4900     0.4887  0.4900 0.4748            100
#   Voyage-3-Large    0.4700     0.3848  0.4700 0.3498            100
# LLaMA-3.1-Remote    0.5250     0.5571  0.5250 0.4473             40
#
# 🥇 Best Performing Model: LLaMA-3.1-Remote (Accuracy: 0.5250)
#
# 📊 Model Ranking by Accuracy:
# 🥇 LLaMA-3.1-Remote: 0.5250
# 🥈 CareerBERT: 0.5000
# 🥉 BGE: 0.5000
# 4. ConFit V2: 0.4900
# 5. OpenAI: 0.4800
# 6. BGE-M3: 0.4700
# 7. Voyage-3-Large: 0.4700
#
# ================================================================================
