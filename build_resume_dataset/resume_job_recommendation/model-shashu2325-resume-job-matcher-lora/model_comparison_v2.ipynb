# %% [markdown]
# ## 1. Setup Environment

# %%
# %pip install voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from voyageai) (3.12.15)
# Collecting aiolimiter (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: langchain-text-splitters>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from voyageai) (0.3.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from voyageai) (11.3.0)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.11.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.32.4)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from voyageai) (8.5.0)
# Requirement already satisfied: tokenizers>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from voyageai) (0.22.0)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain-text-splitters>=0.3.8->voyageai) (0.3.76)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.14.0->voyageai) (0.35.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.1.10)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.4.28)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.3.1)
# Downloading voyageai-0.3.5-py3-none-any.whl (28 kB)
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Installing collected packages: aiolimiter, voyageai
# Successfully installed aiolimiter-1.2.1 voyageai-0.3.5

# %%
# Import required libraries
from transformers import AutoModel, AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import torch
import torch.nn.functional as F
import openai
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
import voyageai
import json
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
# Configure API keys
from google.colab import userdata

# Get API keys from environment variables
openai.api_key = userdata.get('OPENAI_API_KEY')
voyage_api_key = userdata.get('VOYAGE_API_KEY')

# Set up Voyage API client if key exists
if voyage_api_key:
    voyageai.api_key = voyage_api_key
    print("✅ Voyage API key configured.")
else:
    print("⚠️  Voyage API key not found.")

# Configure Hugging Face token for remote LLaMA inference
hf_token = userdata.get('HF_TOKEN')
if hf_token:
    print("✅ Hugging Face token configured.")
else:
    print("⚠️  Hugging Face token not found.")
# Out:
# ✅ Voyage API key configured.
# ✅ Hugging Face token configured.

# %% [markdown]
# ## 2. Data Preparation
#
# Load the dataset and prepare a balanced sample for testing. We'll also set up model configuration flags.

# %%
# Define model configuration
model_config = {
    'bge': {'enabled': True},
    'openai': {'enabled': False},
    'bge_m3': {'enabled': False},
    'careerbert': {'enabled': False},
    'confit': {'enabled': False},
    'voyage': {'enabled': False},
    'llama_remote': {'enabled': False}
}

print("Model configuration initialized.")
# Out:
# Model configuration initialized.

# %%
# Load the dataset
from google.colab import drive
drive.mount('/content/drive')
DATASET_PATH='/content/drive/MyDrive/AI-ML Self Learning/next_horizon/resume_job_recommendation/model-shashu2325-resume-job-matcher-lora'

# Load and sample the dataset
print("Loading dataset...")
df = pd.read_csv(f'{DATASET_PATH}/dataset.csv')

# Display dataset info
print(f"\nDataset Info:")
print(f"Total records: {len(df)}")
print(f"Columns: {list(df.columns)}")

# Create balanced sample
select_df = df[df['Decision'] == 'select']
reject_df = df[df['Decision'] == 'reject']

total_samples = 100
num_select = min(len(select_df), total_samples // 2)
num_reject = min(len(reject_df), total_samples - num_select)

# Adjust if needed
if num_select + num_reject < total_samples:
    if len(select_df) > len(reject_df):
        num_select = min(len(select_df), total_samples - num_reject)
    else:
        num_reject = min(len(reject_df), total_samples - num_select)

# Sample and combine, preserving original indices
sampled_select_df = select_df.sample(n=num_select, random_state=42)
sampled_reject_df = reject_df.sample(n=num_reject, random_state=42)
sampled_df = pd.concat([sampled_select_df, sampled_reject_df])
sampled_df = sampled_df.sample(frac=1, random_state=42)  # Shuffle but keep original index

print(f"\n✅ Final sample size: {len(sampled_df)} records")
print(f"Sample distribution: {sampled_df['Decision'].value_counts().to_dict()}")
# Out:
# Mounted at /content/drive
# Loading dataset...
#
# Dataset Info:
# Total records: 10174
# Columns: ['Role', 'Resume', 'Decision', 'Reason_for_decision', 'Job_Description']
#
# ✅ Final sample size: 100 records
# Sample distribution: {'reject': 50, 'select': 50}

# %% [markdown]
# ## 3. Model-Specific Operations

# %%
# Utility function for cosine similarity
def cosine_similarity(a, b):
    """Calculate cosine similarity between two vectors"""
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    na = np.linalg.norm(a)
    nb = np.linalg.norm(b)
    if na == 0 or nb == 0:
        return 0.0
    return float(a.dot(b) / (na * nb))

# %%
# BGE Model
if model_config['bge']['enabled']:
    print("Loading BGE model...")
    try:
        model = SentenceTransformer("BAAI/bge-large-en-v1.5")
        # Load and apply LoRA adapter
        # Note: Since we're using SentenceTransformer, we'll handle the embedding differently

        def calculate_bge_similarity(resume_text, job_text):
            resume_embedding = model.encode(resume_text, normalize_embeddings=True)
            job_embedding = model.encode(job_text, normalize_embeddings=True)
            return cosine_similarity(resume_embedding, job_embedding)

        print("✅ BGE model loaded and similarity function defined.")
    except Exception as e:
        print(f"❌ Error loading BGE model: {e}")
        model_config['bge']['enabled'] = False
# Out:
# Loading BGE model...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/779 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# ✅ BGE model loaded and similarity function defined.

# %%
# OpenAI Model
if model_config['openai']['enabled'] and openai.api_key:
    print("Setting up OpenAI model...")
    try:
        def get_openai_embedding(text, model="text-embedding-3-small"):
            text = text.replace("\n", " ")
            return openai.embeddings.create(input=[text], model=model).data[0].embedding

        def calculate_openai_similarity(resume_text, job_text):
            resume_embedding = get_openai_embedding(resume_text)
            job_embedding = get_openai_embedding(job_text)
            return cosine_similarity(resume_embedding, job_embedding)

        print("✅ OpenAI embedding function defined.")
    except Exception as e:
        print(f"❌ Error setting up OpenAI: {e}")
        model_config['openai']['enabled'] = False
else:
    print("⚠️ OpenAI model disabled (no API key)")
    model_config['openai']['enabled'] = False
# Out:
# ⚠️ OpenAI model disabled (no API key)

# %%
# Voyage Model
if model_config['voyage']['enabled'] and voyage_api_key:
    print("Setting up Voyage model...")
    try:
        voyageai.api_key = voyage_api_key

        def calculate_voyage_similarity(resume_text, job_text, model="voyage-3-large"):
            try:
                # Create a new client instance for each request
                vo = voyageai.Client()
                # Clean and normalize texts
                resume_text = ' '.join(resume_text.split())  # Normalize whitespace
                job_text = ' '.join(job_text.split())
                # Get embeddings
                resume_embedding = vo.embed([resume_text], model=model).embeddings[0]
                job_embedding = vo.embed([job_text], model=model).embeddings[0]
                return cosine_similarity(resume_embedding, job_embedding)
            except Exception as e:
                print(f"Error in Voyage embedding calculation: {str(e)}")
                return None

        print("✅ Voyage embedding function defined.")
    except Exception as e:
        print(f"❌ Error setting up Voyage: {e}")
        model_config['voyage']['enabled'] = False
else:
    print("⚠️ Voyage model disabled (no API key)")
    model_config['voyage']['enabled'] = False
# Out:
# ⚠️ Voyage model disabled (no API key)

# %%
# Remote LLaMA Model
if model_config['llama_remote']['enabled'] and hf_token:
    print("Setting up remote LLaMA inference...")
    try:
        from openai import OpenAI
        client = OpenAI(
            base_url="https://router.huggingface.co/v1",
            api_key=hf_token,
        )

        def clean_text(text):
            """Clean and prepare text for LLaMA processing"""
            # Remove any problematic characters and normalize whitespace
            text = text.replace('\n', ' ').replace('\r', ' ')
            text = ' '.join(text.split())  # Normalize whitespace
            # Truncate long texts to prevent context overflow
            max_chars = 1000
            if len(text) > max_chars:
                text = text[:max_chars] + "..."
            return text

        def calculate_llama_remote_similarity(resume_text, job_text):
            # Clean and prepare the texts
            resume_text = clean_text(resume_text)
            job_text = clean_text(job_text)

            messages = [
                {
                    "role": "system",
                    "content": """You are a CV-job matcher. Analyze the match and return ONLY a JSON with {score: <number>}.
The score should be between 0-100, indicating compatibility. Do not include any other fields or explanations."""
                },
                {
                    "role": "user",
                    "content": f"CV: {resume_text}\nJob: {job_text}"
                }
            ]

            try:
                completion = client.chat.completions.create(
                    model="meta-llama/Llama-3.1-8B-Instruct",
                    messages=messages,
                    max_tokens=32,  # Very short response needed
                    response_format={ "type": "json_object" },
                    temperature=0.1  # Lower temperature for more consistent outputs
                )
                response_text = completion.choices[0].message.content.strip()

                try:
                    # Try to parse the JSON response
                    response = json.loads(response_text)
                    score = response.get('score', 0)
                except json.JSONDecodeError:
                    # If JSON parsing fails, try to extract just the score using regex
                    import re
                    # Look for any number pattern after "score"
                    score_match = re.search(r'"score"\s*:\s*(\d+)', response_text)
                    if score_match:
                        score = int(score_match.group(1))
                    else:
                        # Try to find any number between 0-100 in the response
                        number_match = re.search(r'\b([0-9]{1,2}|100)\b', response_text)
                        if number_match:
                            score = int(number_match.group(1))
                        else:
                            print(f"Could not find score in response: {response_text}")
                            return None

                # Ensure score is within valid range
                score = max(0, min(100, int(score)))
                return score / 100.0  # Normalize to 0-1

            except Exception as e:
                print(f"Error in LLaMA remote inference: {str(e)}")
                return None

        print("✅ Remote LLaMA inference function defined.")
    except Exception as e:
        print(f"❌ Error setting up remote LLaMA: {e}")
        model_config['llama_remote']['enabled'] = False
else:
    print("⚠️ Remote LLaMA model disabled (no HF token)")
    model_config['llama_remote']['enabled'] = False
# Out:
# Setting up remote LLaMA inference...
# ✅ Remote LLaMA inference function defined.

# %%
# BGE-M3 Model
if model_config['bge_m3']['enabled']:
    print("Loading BGE-M3 model...")
    try:
        bge_m3_model = SentenceTransformer("BAAI/bge-m3")

        def calculate_bge_m3_similarity(resume_text, job_text):
            # Clean and normalize texts
            resume_text = ' '.join(resume_text.split())
            job_text = ' '.join(job_text.split())

            # Get embeddings with BGE-M3
            resume_embedding = bge_m3_model.encode(resume_text, normalize_embeddings=True)
            job_embedding = bge_m3_model.encode(job_text, normalize_embeddings=True)
            return cosine_similarity(resume_embedding, job_embedding)

        print("✅ BGE-M3 model loaded and similarity function defined.")
    except Exception as e:
        print(f"❌ Error loading BGE-M3 model: {e}")
        model_config['bge_m3']['enabled'] = False
else:
    print("⚠️ BGE-M3 model disabled")
# Out:
# ⚠️ BGE-M3 model disabled

# %%
# CareerBERT Model
if model_config['careerbert']['enabled']:
    print("Loading CareerBERT model...")
    try:
        careerbert_model = SentenceTransformer("yxchar/career-bert-base")

        def calculate_careerbert_similarity(resume_text, job_text):
            # Clean and normalize texts
            resume_text = ' '.join(resume_text.split())
            job_text = ' '.join(job_text.split())

            # Get embeddings with CareerBERT
            resume_embedding = careerbert_model.encode(resume_text, normalize_embeddings=True)
            job_embedding = careerbert_model.encode(job_text, normalize_embeddings=True)
            return cosine_similarity(resume_embedding, job_embedding)

        print("✅ CareerBERT model loaded and similarity function defined.")
    except Exception as e:
        print(f"❌ Error loading CareerBERT model: {e}")
        model_config['careerbert']['enabled'] = False
else:
    print("⚠️ CareerBERT model disabled")
# Out:
# ⚠️ CareerBERT model disabled

# %%
# ConFit Model
if model_config['confit']['enabled']:
    print("Loading ConFit model...")
    try:
        confit_model = SentenceTransformer("jamescalam/resume-job-confit-base")

        def calculate_confit_similarity(resume_text, job_text):
            # Clean and normalize texts
            resume_text = ' '.join(resume_text.split())
            job_text = ' '.join(job_text.split())

            # Get embeddings with ConFit
            resume_embedding = confit_model.encode(resume_text, normalize_embeddings=True)
            job_embedding = confit_model.encode(job_text, normalize_embeddings=True)
            return cosine_similarity(resume_embedding, job_embedding)

        print("✅ ConFit model loaded and similarity function defined.")
    except Exception as e:
        print(f"❌ Error loading ConFit model: {e}")
        model_config['confit']['enabled'] = False
else:
    print("⚠️ ConFit model disabled")
# Out:
# ⚠️ ConFit model disabled

# %% [markdown]
# ## 4. Generate Predictions and Classifications
#
# Process the dataset through all enabled models and create a comparative table with role indices.

# %%
# Initialize score dictionary for each model
scores = {
    'bge': [],
    'openai': [],
    'bge_m3': [],
    'careerbert': [],
    'confit': [],
    'voyage': [],
    'llama_remote': []
}

# Process each resume-job pair
print("🚀 Calculating similarity scores for all enabled models...")
for index, row in sampled_df.iterrows():
    resume_text = str(row['Resume']) if pd.notna(row['Resume']) else ""
    job_text = str(row['Job_Description']) if pd.notna(row['Job_Description']) else ""

    print(f"\n📋 Processing pair {index+1}/{len(sampled_df)}")

    # Calculate scores for each enabled model
    if model_config['bge']['enabled']:
        try:
            scores['bge'].append(calculate_bge_similarity(resume_text, job_text))
        except Exception as e:
            scores['bge'].append(None)
            print(f"❌ BGE error: {e}")
    else:
        scores['bge'].append(None)

    if model_config['openai']['enabled']:
        try:
            scores['openai'].append(calculate_openai_similarity(resume_text, job_text))
        except Exception as e:
            scores['openai'].append(None)
            print(f"❌ OpenAI error: {e}")
    else:
        scores['openai'].append(None)

    if model_config['bge_m3']['enabled']:
        try:
            scores['bge_m3'].append(calculate_bge_m3_similarity(resume_text, job_text))
        except Exception as e:
            scores['bge_m3'].append(None)
            print(f"❌ BGE-M3 error: {e}")
    else:
        scores['bge_m3'].append(None)

    if model_config['careerbert']['enabled']:
        try:
            scores['careerbert'].append(calculate_careerbert_similarity(resume_text, job_text))
        except Exception as e:
            scores['careerbert'].append(None)
            print(f"❌ CareerBERT error: {e}")
    else:
        scores['careerbert'].append(None)

    if model_config['confit']['enabled']:
        try:
            scores['confit'].append(calculate_confit_similarity(resume_text, job_text))
        except Exception as e:
            scores['confit'].append(None)
            print(f"❌ ConFit error: {e}")
    else:
        scores['confit'].append(None)

    if model_config['voyage']['enabled']:
        try:
            scores['voyage'].append(calculate_voyage_similarity(resume_text, job_text))
        except Exception as e:
            scores['voyage'].append(None)
            print(f"❌ Voyage error: {e}")
    else:
        scores['voyage'].append(None)

    if model_config['llama_remote']['enabled']:
        try:
            scores['llama_remote'].append(calculate_llama_remote_similarity(resume_text, job_text))
        except Exception as e:
            scores['llama_remote'].append(None)
            print(f"❌ LLaMA Remote error: {e}")
    else:
        scores['llama_remote'].append(None)

print("\n✅ Score calculation complete!")
# Out:
# 🚀 Calculating similarity scores for all enabled models...
#
# 📋 Processing pair 7548/100
#
# 📋 Processing pair 2644/100
#
# 📋 Processing pair 4814/100
#
# 📋 Processing pair 2877/100
#
# 📋 Processing pair 1746/100
#
# 📋 Processing pair 1176/100
#
# 📋 Processing pair 6368/100
#
# 📋 Processing pair 4668/100
#
# 📋 Processing pair 3673/100
#
# 📋 Processing pair 6143/100
#
# 📋 Processing pair 7891/100
#
# 📋 Processing pair 5265/100
#
# 📋 Processing pair 1774/100
#
# 📋 Processing pair 4468/100
#
# 📋 Processing pair 1524/100
#
# 📋 Processing pair 4507/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 1458/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2815/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6717/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2858/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 5058/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8698/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9656/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2812/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 5435/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 4140/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2751/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6016/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 188/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 3052/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 5246/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7154/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8559/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 989/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 5595/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7361/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7600/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7662/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 4478/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 3717/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7961/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6881/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6996/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 5526/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 1592/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 3073/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2649/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7306/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 10080/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9325/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6875/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2557/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 154/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 840/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8604/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9606/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9943/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8674/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 4872/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8700/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 4557/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 3474/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8136/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6452/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 999/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6749/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6798/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 4337/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2470/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2021/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8806/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 56/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7928/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8171/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 5110/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2129/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 1457/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 1240/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9627/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6880/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9359/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 4929/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 3868/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 2349/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7550/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6189/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8326/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8678/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 1433/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 10141/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9975/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 8029/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6745/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 7005/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 77/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 6177/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 10047/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 508/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 136/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# 📋 Processing pair 9937/100
# Error in LLaMA remote inference: Error code: 402 - {'error': 'You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.'}
#
# ✅ Score calculation complete!

# %%
# Add scores to DataFrame and generate predictions
threshold = 0.5
print(f"Using classification threshold: {threshold}")

# Function to make predictions
def make_prediction(score, threshold=0.5):
    if score is None or pd.isna(score):
        return 'unknown'
    return 'select' if score > threshold else 'reject'

# Add scores and predictions to DataFrame
for model in scores.keys():
    if model_config[model]['enabled']:
        sampled_df[f'{model}_similarity'] = scores[model]
        sampled_df[f'{model}_prediction'] = [make_prediction(s, threshold) for s in scores[model]]

# Create display columns, moving Reason_for_decision to the end
display_columns = ['Role', 'Decision']
for model in scores.keys():
    if model_config[model]['enabled']:
        display_columns.extend([f'{model}_similarity', f'{model}_prediction'])
display_columns.append('Reason_for_decision')  # Add Reason_for_decision at the end

# Create comparative table with original index
comparison_table = sampled_df[display_columns]

print("\n📊 Comparative Table of Similarity Scores and Predictions (with original dataset indices):")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)
print(comparison_table.to_string())
# Out:
# Using classification threshold: 0.5
#
# 📊 Comparative Table of Similarity Scores and Predictions (with original dataset indices):
#                              Role Decision  bge_similarity bge_prediction  llama_remote_similarity llama_remote_prediction                                                                                                                                                                                Reason_for_decision
# 7547            Robotics Engineer   reject          0.5283         select                   0.9200                  select                                                                                                                                                    Lacked leadership skills for a senior position.
# 2643        E-commerce Specialist   reject          0.6009         select                   0.8500                  select                                                                                                                                                             No experience in back-end development.
# 4813               Cloud Engineer   reject          0.6842         select                   0.9200                  select                                                                                                                                                             No experience in back-end development.
# 2876        E-commerce Specialist   select          0.5917         select                   0.8500                  select                                                                                                                                                              Strong technical skills in AI and ML.
# 1745             Network Engineer   select          0.8035         select                   0.9200                  select                                                                                                                                                        Proven track record of successful projects.
# 1175              Product Manager   select          0.6900         select                   0.9200                  select                                                   Displayed excellent collaboration and teamwork mindset, Demonstrated a strong understanding of the company’s goals and how they could contribute
# 6367       Database Administrator   select          0.5870         select                   0.9200                  select                                                                                                                                                     Perfectly aligned with data engineering needs.
# 4667        IT Support Specialist   reject          0.4563         reject                   0.8500                  select                                                                                                                                                             No experience in back-end development.
# 3672         Mobile App Developer   select          0.5765         select                   0.8500                  select                                                                                                                                                       Excellent full-stack development experience.
# 6142                  QA Engineer   select          0.5643         select                   0.8500                  select                                                                                                                                                       Solid experience in machine learning and AI.
# 7890              DevOps Engineer   select          0.6648         select                   0.9200                  select                                                                                                                                                       Solid experience in machine learning and AI.
# 5264   Human Resources Specialist   select          0.5208         select                   0.8500                  select                                                                                                                                                              Strong technical skills in AI and ML.
# 1773              Product Manager   reject          0.8270         select                   0.9200                  select                                                                                                                                                        Inability to adapt to remote work settings.
# 4467         Mobile App Developer   select          0.5953         select                   0.9200                  select                                                                                                                                                       Solid experience in machine learning and AI.
# 1523                Data Engineer   reject          0.6605         select                   0.9500                  select                                            Insufficient mastery of SQL optimization, Cloud data tools, Python/Scala made it challenging to consider this candidate for the Data Engineer position.
# 4506                 Data Analyst   select          0.5440         select                      NaN                 unknown                                                                                                                                                       Excellent full-stack development experience.
# 1457                  UI Designer   reject          0.6151         select                      NaN                 unknown                                                                               With only 8 years of experience and gaps in Wireframing, Figma, this candidate is not yet ready for the UI Designer.
# 2814              Product Manager   reject          0.6563         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 6716   Human Resources Specialist   select          0.4374         reject                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 2857               Content Writer   select          0.4428         reject                      NaN                 unknown                                                                                                                                                       Excellent full-stack development experience.
# 5057               Data Architect   reject          0.6129         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 8697                 data analyst   reject          0.5913         select                      NaN                 unknown                                                                                                                           expected_experience : 0-2 years, domains: marketing, finance, healthcare
# 9655              product manager   select          0.6712         select                      NaN                 unknown                                                                                                                                                                                technical knowledge
# 2811                AI Researcher   select          0.5944         select                      NaN                 unknown                                                                                                                                                       Solid experience in machine learning and AI.
# 5434                AI Researcher   reject          0.6737         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 4139               Game Developer   select          0.5075         select                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 2750                 Data Analyst   select          0.5263         select                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 6015                 Data Analyst   reject          0.5212         select                      NaN                 unknown                                                                                                                                              Insufficient system design expertise for senior role.
# 187                Data Scientist   select          0.4131         reject                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 3051              AR/VR Developer   reject          0.5800         select                      NaN                 unknown                                                                                                                                              Insufficient system design expertise for senior role.
# 5245         System Administrator   select          0.5711         select                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 7153         Blockchain Developer   select          0.6468         select                      NaN                 unknown                                                                                                                                                       Excellent full-stack development experience.
# 8558                 data analyst   reject          0.5950         select                      NaN                 unknown                                                                                                                           expected_experience : 3-5 years, domains: marketing, finance, healthcare
# 988             Software Engineer   select          0.5487         select                      NaN                 unknown                                                                                                                                                       Excellent full-stack development experience.
# 5594               Data Scientist   reject          0.5653         select                      NaN                 unknown                                                                                                                                                    Lacked leadership skills for a senior position.
# 7360                  UI Engineer   select          0.6297         select                      NaN                 unknown                                                                                                                                                       Excellent full-stack development experience.
# 7599               Cloud Engineer   reject          0.6521         select                      NaN                 unknown                                                                                                                                                  Needs improvement in machine learning algorithms.
# 7661        E-commerce Specialist   reject          0.5859         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 4477        E-commerce Specialist   select          0.4983         reject                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 3716         Blockchain Developer   select          0.5862         select                      NaN                 unknown                                                                                                                                                 Impressive leadership and communication abilities.
# 7960               Game Developer   select          0.4960         reject                      NaN                 unknown                                                                                                                                                       Solid experience in machine learning and AI.
# 6880                AI Researcher   select          0.5791         select                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 6995        E-commerce Specialist   select          0.5903         select                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 5525       Database Administrator   reject          0.5823         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 1591                 Data Analyst   select          0.6068         select                      NaN                 unknown  The candidate's 2 years of experience combined with proficiency in Excel/Google Sheets, Statistical analysis, A/B testing positions them well to contribute effectively to the Data Analyst role.
# 3072               Cloud Engineer   select          0.6108         select                      NaN                 unknown                                                                                                                                                 Impressive leadership and communication abilities.
# 2648              Product Manager   reject          0.6406         select                      NaN                 unknown                                                                                                                                              Insufficient system design expertise for senior role.
# 7305               Data Architect   select          0.7045         select                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 10079              Data Scientist   reject          0.7165         select                      NaN                 unknown                                                                                                                                                             Lack of relevant skills or experience.
# 9324            software engineer   select          0.5606         select                      NaN                 unknown                                                                                                                           expected_experience : 6-8 years, domains: e-commerce, banking, education
# 6874               Data Scientist   select          0.4997         reject                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 2556                Data Engineer   select          0.5153         select                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 153          Full Stack Developer   select          0.5750         select                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 839          Blockchain Developer   select          0.6556         select                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 8603                 data analyst   select          0.4894         reject                      NaN                 unknown                                                                                                                            expected_experience : 9+ years, domains: marketing, finance, healthcare
# 9605                  ui engineer   reject          0.7027         select                      NaN                 unknown                                                                                                                                                                                     experience gap
# 9942              Product Manager   select          0.7768         select                      NaN                 unknown                                                                                                                                                                    Relevant skills and experience.
# 8673               data scientist   reject          0.5332         select                      NaN                 unknown                                                                                                                              expected_experience : 3-5 years, domains: healthcare, finance, retail
# 4871               Game Developer   select          0.5497         select                      NaN                 unknown                                                                                                                                                 Impressive leadership and communication abilities.
# 8699                 data analyst   reject          0.6174         select                      NaN                 unknown                                                                                                                           expected_experience : 0-2 years, domains: marketing, finance, healthcare
# 4556                  QA Engineer   reject          0.6272         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 3473             Business Analyst   reject          0.5974         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 8135            software engineer   reject          0.6865         select                      NaN                 unknown                                                                                                                                                                                technical knowledge
# 6451                  QA Engineer   select          0.5898         select                      NaN                 unknown                                                                                                                                                 Impressive leadership and communication abilities.
# 998                   UX Designer   reject          0.5783         select                      NaN                 unknown                                                                                                                                              Insufficient system design expertise for senior role.
# 6748              Cloud Architect   reject          0.6926         select                      NaN                 unknown                                                                                                                                                  Needs improvement in machine learning algorithms.
# 6797                  QA Engineer   select          0.4277         reject                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 4336         Mobile App Developer   reject          0.4600         reject                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 2469               Data Scientist   reject          0.5815         select                      NaN                 unknown                                                                                                                                                  Needs improvement in machine learning algorithms.
# 2020   Human Resources Specialist   reject          0.5583         select                      NaN                 unknown                                                                                                                                                    Lacked leadership skills for a senior position.
# 8805                 data analyst   reject          0.6077         select                      NaN                 unknown                                                                                                                           expected_experience : 0-2 years, domains: marketing, finance, healthcare
# 55              Robotics Engineer   select          0.6762         select                      NaN                 unknown                                                                                                                                                 Impressive leadership and communication abilities.
# 7927         Blockchain Developer   reject          0.6182         select                      NaN                 unknown                                                                                                                                                  Needs improvement in machine learning algorithms.
# 8170              product manager   select          0.7130         select                      NaN                 unknown                                                                                                                                                                                    business acumen
# 5109               Cloud Engineer   reject          0.4061         reject                      NaN                 unknown                                                                                                                                                    Lacks hands-on experience with cloud platforms.
# 2128            Software Engineer   reject          0.6123         select                      NaN                 unknown                                                                                                                                                             No experience in back-end development.
# 1456                 Data Analyst   reject          0.6017         select                      NaN                 unknown                     Insufficient mastery of Data-driven decision making, Trend analysis, Business intelligence tools made it challenging to consider this candidate for the Data Analyst position.
# 1239            Software Engineer   select          0.6492         select                      NaN                 unknown                                                 Strong expertise in System design, Data structures and solid 7-year background in Software Engineer-related tasks make this candidate a great fit.
# 9626              product manager   reject          0.6913         select                      NaN                 unknown                                                                                                                                                                                    business acumen
# 6879              Product Manager   reject          0.6353         select                      NaN                 unknown                                                                                                                                                    Lacked leadership skills for a senior position.
# 9358               data scientist   reject          0.5577         select                      NaN                 unknown                                                                                                                              expected_experience : 3-5 years, domains: healthcare, finance, retail
# 4928              Cloud Architect   reject          0.5977         select                      NaN                 unknown                                                                                                                                                    Lacked leadership skills for a senior position.
# 3867              Product Manager   select          0.5642         select                      NaN                 unknown                                                                                                                                                     Perfectly aligned with data engineering needs.
# 2348                Data Engineer   select          0.6314         select                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 7549               Content Writer   select          0.5245         select                      NaN                 unknown                                                                                                                                                       Solid experience in machine learning and AI.
# 6188   Human Resources Specialist   reject          0.5097         select                      NaN                 unknown                                                                                                                                              Insufficient system design expertise for senior role.
# 8325              product manager   select          0.6760         select                      NaN                 unknown                                                                                                                                                                                         experience
# 8677            software engineer   select          0.5284         select                      NaN                 unknown                                                                                                                           expected_experience : 6-8 years, domains: e-commerce, banking, education
# 1432               Data Scientist   select          0.6943         select                      NaN                 unknown  Proven expertise in Machine learning algorithms, Python/Pandas along with 7 years of hands-on experience in Data Scientist-specific tasks makes this candidate an excellent fit for the position.
# 10140               Data Engineer   reject          0.7440         select                      NaN                 unknown                                                                                                                                                             Lack of relevant skills or experience.
# 9974                Data Engineer   reject          0.7761         select                      NaN                 unknown                                                                                                                                                  Inadequate communication or interpersonal skills.
# 8028                data engineer   reject          0.7219         select                      NaN                 unknown                                                                                                                                                                                         experience
# 6744        Cybersecurity Analyst   reject          0.6254         select                      NaN                 unknown                                                                                                                                                    Lacks hands-on experience with cloud platforms.
# 7004              Product Manager   reject          0.5564         select                      NaN                 unknown                                                                                                                                              Insufficient system design expertise for senior role.
# 76           Mobile App Developer   select          0.5553         select                      NaN                 unknown                                                                                                                                                              Strong technical skills in AI and ML.
# 6176              DevOps Engineer   reject          0.5599         select                      NaN                 unknown                                                                                                                                                    Lacks hands-on experience with cloud platforms.
# 10046               Data Engineer   reject          0.7659         select                      NaN                 unknown                                                                                                                                                                  Lack of enthusiasm or motivation.
# 507                  Data Analyst   select          0.5954         select                      NaN                 unknown                                                                                                                                                       Excellent full-stack development experience.
# 135              Business Analyst   reject          0.5332         select                      NaN                 unknown                                                                                                                                                    Lacked leadership skills for a senior position.
# 9936                  UI Engineer   reject          0.8149         select                      NaN                 unknown                                                                                                                                                                  Lack of enthusiasm or motivation.

# %%
# Calculate performance metrics for each enabled model
print("\n📈 Model Performance Metrics:")
print("=" * 80)

for model in scores.keys():
    if model_config[model]['enabled']:
        print(f"\n🔍 {model.upper()} Model Performance:")
        print("-" * 50)

        # Filter out unknown predictions
        valid_mask = sampled_df[f'{model}_prediction'] != 'unknown'
        valid_df = sampled_df[valid_mask]

        if len(valid_df) > 0:
            accuracy = accuracy_score(valid_df['Decision'], valid_df[f'{model}_prediction'])
            precision, recall, f1, _ = precision_recall_fscore_support(
                valid_df['Decision'],
                valid_df[f'{model}_prediction'],
                average='weighted'
            )

            print(f"Accuracy: {accuracy:.4f}")
            print(f"Precision: {precision:.4f}")
            print(f"Recall: {recall:.4f}")
            print(f"F1-Score: {f1:.4f}")
            print(f"Valid predictions: {len(valid_df)}/{len(sampled_df)}")

            print("\nDetailed Classification Report:")
            print(classification_report(valid_df['Decision'], valid_df[f'{model}_prediction']))
        else:
            print("No valid predictions available")
# Out:
# 📈 Model Performance Metrics:
# ================================================================================
#
# 🔍 BGE Model Performance:
# --------------------------------------------------
# Accuracy: 0.4500
# Precision: 0.3723
# Recall: 0.4500
# F1-Score: 0.3513
# Valid predictions: 100/100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.27      0.06      0.10        50
#       select       0.47      0.84      0.60        50
#
#     accuracy                           0.45       100
#    macro avg       0.37      0.45      0.35       100
# weighted avg       0.37      0.45      0.35       100
#
#
# 🔍 LLAMA_REMOTE Model Performance:
# --------------------------------------------------
# Accuracy: 0.6000
# Precision: 0.3600
# Recall: 0.6000
# F1-Score: 0.4500
# Valid predictions: 15/100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.00      0.00      0.00         6
#       select       0.60      1.00      0.75         9
#
#     accuracy                           0.60        15
#    macro avg       0.30      0.50      0.38        15
# weighted avg       0.36      0.60      0.45        15
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
