# %% [markdown]
# # Resume-to-Job Description Matching: Model Performance Comparison
#
# This notebook compares different embedding models for resume-job description matching. It includes:
# 1. Model configuration and loading
# 2. Dataset preparation
# 3. Similarity calculations
# 4. Comparative performance analysis

# %% [markdown]
# ## 1. Setup Environment
#
# First, we'll import all required libraries and configure API keys.

# %%
# %pip install voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from voyageai) (3.12.15)
# Collecting aiolimiter (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: langchain-text-splitters>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from voyageai) (0.3.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from voyageai) (11.3.0)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.11.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from voyageai) (2.32.4)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from voyageai) (8.5.0)
# Requirement already satisfied: tokenizers>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from voyageai) (0.22.0)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in /usr/local/lib/python3.12/dist-packages (from langchain-text-splitters>=0.3.8->voyageai) (0.3.76)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.8->voyageai) (0.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.14.0->voyageai) (0.35.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->voyageai) (1.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->voyageai) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (1.1.10)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.4.28)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters>=0.3.8->voyageai) (1.3.1)
# Downloading voyageai-0.3.5-py3-none-any.whl (28 kB)
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Installing collected packages: aiolimiter, voyageai
# Successfully installed aiolimiter-1.2.1 voyageai-0.3.5

# %%
# Import required libraries
from transformers import AutoModel, AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import torch
import torch.nn.functional as F
import openai
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
import voyageai
import json
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
# Configure API keys
from google.colab import userdata

# Get API keys from environment variables
openai.api_key = userdata.get('OPENAI_API_KEY')
voyage_api_key = userdata.get('VOYAGE_API_KEY')

# Set up Voyage API client if key exists
if voyage_api_key:
    voyageai.api_key = voyage_api_key
    print("✅ Voyage API key configured.")
else:
    print("⚠️  Voyage API key not found.")

# Configure Hugging Face token for remote LLaMA inference
hf_token = userdata.get('HF_TOKEN')
if hf_token:
    print("✅ Hugging Face token configured.")
else:
    print("⚠️  Hugging Face token not found.")
# Out:
# ✅ Voyage API key configured.
# ✅ Hugging Face token configured.

# %% [markdown]
# ## 2. Data Preparation
#
# Load the dataset and prepare a balanced sample for testing. We'll also set up model configuration flags.

# %%
# Define model configuration
model_config = {
    'bge': {'enabled': True},
    'openai': {'enabled': True},
    'bge_m3': {'enabled': True},
    'careerbert': {'enabled': True},
    'confit': {'enabled': True},
    'voyage': {'enabled': True},
    'llama_remote': {'enabled': True}
}

print("Model configuration initialized.")
# Out:
# Model configuration initialized.

# %%
# Load the dataset
from google.colab import drive
drive.mount('/content/drive')
DATASET_PATH='/content/drive/MyDrive/AI-ML Self Learning/next_horizon/resume_job_recommendation/model-shashu2325-resume-job-matcher-lora'

# Load and sample the dataset
print("Loading dataset...")
df = pd.read_csv(f'{DATASET_PATH}/dataset.csv')

# Display dataset info
print(f"\nDataset Info:")
print(f"Total records: {len(df)}")
print(f"Columns: {list(df.columns)}")

# Create balanced sample
select_df = df[df['Decision'] == 'select']
reject_df = df[df['Decision'] == 'reject']

total_samples = 100
num_select = min(len(select_df), total_samples // 2)
num_reject = min(len(reject_df), total_samples - num_select)

# Adjust if needed
if num_select + num_reject < total_samples:
    if len(select_df) > len(reject_df):
        num_select = min(len(select_df), total_samples - num_reject)
    else:
        num_reject = min(len(reject_df), total_samples - num_select)

# Sample and combine
sampled_select_df = select_df.sample(n=num_select, random_state=42)
sampled_reject_df = reject_df.sample(n=num_reject, random_state=42)
sampled_df = pd.concat([sampled_select_df, sampled_reject_df])
sampled_df = sampled_df.sample(frac=1, random_state=42).reset_index(drop=True)

print(f"\n✅ Final sample size: {len(sampled_df)} records")
print(f"Sample distribution: {sampled_df['Decision'].value_counts().to_dict()}")
# Out:
# Mounted at /content/drive
# Loading dataset...
#
# Dataset Info:
# Total records: 10174
# Columns: ['Role', 'Resume', 'Decision', 'Reason_for_decision', 'Job_Description']
#
# ✅ Final sample size: 100 records
# Sample distribution: {'reject': 50, 'select': 50}

# %% [markdown]
# ## 3. Model-Specific Operations
#
# For each model, we'll define a class that handles:
# 1. Model loading
# 2. Similarity calculation
# 3. Prediction generation
#
# Models will only be loaded if enabled in the configuration.

# %%
# Utility function for cosine similarity
def cosine_similarity(a, b):
    """Calculate cosine similarity between two vectors"""
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    na = np.linalg.norm(a)
    nb = np.linalg.norm(b)
    if na == 0 or nb == 0:
        return 0.0
    return float(a.dot(b) / (na * nb))

# BGE Model
if model_config['bge']['enabled']:
    print("Loading BGE model...")
    try:
        base_model = AutoModel.from_pretrained("BAAI/bge-large-en-v1.5")
        model = PeftModel.from_pretrained(base_model, "shashu2325/resume-job-matcher-lora")
        tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-large-en-v1.5")

        def calculate_bge_similarity(resume_text, job_text):
            resume_inputs = tokenizer(resume_text, return_tensors="pt", max_length=512, padding="max_length", truncation=True)
            job_inputs = tokenizer(job_text, return_tensors="pt", max_length=512, padding="max_length", truncation=True)

            with torch.no_grad():
                resume_outputs = model(**resume_inputs)
                job_outputs = model(**job_inputs)

                resume_emb = resume_outputs.last_hidden_state.mean(dim=1)
                job_emb = job_outputs.last_hidden_state.mean(dim=1)

                resume_emb = F.normalize(resume_emb, p=2, dim=1)
                job_emb = F.normalize(job_emb, p=2, dim=1)

                similarity = torch.sum(resume_emb * job_emb, dim=1)
                match_score = torch.sigmoid(similarity).item()

            return match_score

        print("✅ BGE model loaded and similarity function defined.")
    except Exception as e:
        print(f"❌ Error loading BGE model: {e}")
        model_config['bge']['enabled'] = False
# Out:
# Loading BGE model...
# config.json:   0%|          | 0.00/779 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/4.74M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# ✅ BGE model loaded and similarity function defined.

# %%
# OpenAI Model
if model_config['openai']['enabled'] and openai.api_key:
    print("Setting up OpenAI model...")
    try:
        def get_openai_embedding(text, model="text-embedding-3-small"):
            text = text.replace("\n", " ")
            return openai.embeddings.create(input=[text], model=model).data[0].embedding

        def calculate_openai_similarity(resume_text, job_text):
            resume_embedding = get_openai_embedding(resume_text)
            job_embedding = get_openai_embedding(job_text)
            return cosine_similarity(resume_embedding, job_embedding)

        print("✅ OpenAI embedding function defined.")
    except Exception as e:
        print(f"❌ Error setting up OpenAI: {e}")
        model_config['openai']['enabled'] = False
else:
    print("⚠️ OpenAI model disabled (no API key)")
    model_config['openai']['enabled'] = False
# Out:
# Setting up OpenAI model...
# ✅ OpenAI embedding function defined.

# %%
# Other Transformer Models (BGE-M3, CareerBERT, ConFit)
for model_name, model_details in [
    ('bge_m3', ('BAAI/bge-m3', 'BGE-M3')),
    ('careerbert', ('lwolfrum2/careerbert-g', 'CareerBERT')),
    ('confit', ('sentence-transformers/all-mpnet-base-v2', 'ConFit'))
]:
    if model_config[model_name]['enabled']:
        print(f"Loading {model_details[1]}...")
        try:
            model = SentenceTransformer(model_details[0])

            def make_calculate_similarity(loaded_model):
                def calculate_similarity(resume_text, job_text):
                    resume_embedding = loaded_model.encode(resume_text)
                    job_embedding = loaded_model.encode(job_text)
                    return cosine_similarity(resume_embedding, job_embedding)
                return calculate_similarity

            if model_name == 'bge_m3':
                calculate_bge_m3_similarity = make_calculate_similarity(model)
            elif model_name == 'careerbert':
                calculate_careerbert_similarity = make_calculate_similarity(model)
            else:  # confit
                calculate_confit_similarity = make_calculate_similarity(model)

            print(f"✅ {model_details[1]} model loaded and similarity function defined.")
        except Exception as e:
            print(f"❌ Error loading {model_details[1]}: {e}")
            model_config[model_name]['enabled'] = False
# Out:
# Loading BGE-M3...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# ✅ BGE-M3 model loaded and similarity function defined.
# Loading CareerBERT...
# modules.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/56.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/732 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/305 [00:00<?, ?B/s]
# ✅ CareerBERT model loaded and similarity function defined.
# Loading ConFit...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ ConFit model loaded and similarity function defined.

# %%
# Voyage Model
if model_config['voyage']['enabled'] and voyage_api_key:
    print("Setting up Voyage model...")
    try:
        def calculate_voyage_similarity(resume_text, job_text, model="voyage-3-large"):
            vo = voyageai.Client()
            resume_embedding = vo.embed([resume_text], model=model).embeddings[0]
            job_embedding = vo.embed([job_text], model=model).embeddings[0]
            return cosine_similarity(resume_embedding, job_embedding)

        print("✅ Voyage embedding function defined.")
    except Exception as e:
        print(f"❌ Error setting up Voyage: {e}")
        model_config['voyage']['enabled'] = False
else:
    print("⚠️ Voyage model disabled (no API key)")
    model_config['voyage']['enabled'] = False
# Out:
# Setting up Voyage model...
# ✅ Voyage embedding function defined.

# %% [markdown]
# ## 4. Generate Predictions and Classifications
#
# Process the dataset through all enabled models and create a comparative table with role indices.

# %%
# Initialize score dictionary for each model
scores = {
    'bge': [],
    'openai': [],
    'bge_m3': [],
    'careerbert': [],
    'confit': [],
    'voyage': [],
    'llama_remote': []
}

# Process each resume-job pair
print("🚀 Calculating similarity scores for all enabled models...")
for index, row in sampled_df.iterrows():
    resume_text = str(row['Resume']) if pd.notna(row['Resume']) else ""
    job_text = str(row['Job_Description']) if pd.notna(row['Job_Description']) else ""

    print(f"\n📋 Processing pair {index+1}/{len(sampled_df)}")

    # Calculate scores for each enabled model
    if model_config['bge']['enabled']:
        try:
            scores['bge'].append(calculate_bge_similarity(resume_text, job_text))
        except Exception as e:
            scores['bge'].append(None)
            print(f"❌ BGE error: {e}")
    else:
        scores['bge'].append(None)

    if model_config['openai']['enabled']:
        try:
            scores['openai'].append(calculate_openai_similarity(resume_text, job_text))
        except Exception as e:
            scores['openai'].append(None)
            print(f"❌ OpenAI error: {e}")
    else:
        scores['openai'].append(None)

    if model_config['bge_m3']['enabled']:
        try:
            scores['bge_m3'].append(calculate_bge_m3_similarity(resume_text, job_text))
        except Exception as e:
            scores['bge_m3'].append(None)
            print(f"❌ BGE-M3 error: {e}")
    else:
        scores['bge_m3'].append(None)

    if model_config['careerbert']['enabled']:
        try:
            scores['careerbert'].append(calculate_careerbert_similarity(resume_text, job_text))
        except Exception as e:
            scores['careerbert'].append(None)
            print(f"❌ CareerBERT error: {e}")
    else:
        scores['careerbert'].append(None)

    if model_config['confit']['enabled']:
        try:
            scores['confit'].append(calculate_confit_similarity(resume_text, job_text))
        except Exception as e:
            scores['confit'].append(None)
            print(f"❌ ConFit error: {e}")
    else:
        scores['confit'].append(None)

    if model_config['voyage']['enabled']:
        try:
            scores['voyage'].append(calculate_voyage_similarity(resume_text, job_text))
        except Exception as e:
            scores['voyage'].append(None)
            print(f"❌ Voyage error: {e}")
    else:
        scores['voyage'].append(None)

    if model_config['llama_remote']['enabled']:
        try:
            scores['llama_remote'].append(calculate_llama_remote_similarity(resume_text, job_text))
        except Exception as e:
            scores['llama_remote'].append(None)
            print(f"❌ LLaMA Remote error: {e}")
    else:
        scores['llama_remote'].append(None)

print("\n✅ Score calculation complete!")
# Out:
# 🚀 Calculating similarity scores for all enabled models...
#
# 📋 Processing pair 1/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 2/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 3/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 4/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 5/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 6/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 7/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 8/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 9/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 10/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 11/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 12/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 13/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 14/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 15/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 16/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 17/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 18/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 19/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 20/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 21/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 22/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 23/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 24/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 25/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 26/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 27/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 28/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 29/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 30/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 31/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 32/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 33/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 34/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 35/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 36/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 37/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 38/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 39/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 40/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 41/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 42/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 43/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 44/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 45/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 46/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 47/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 48/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 49/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 50/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 51/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 52/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 53/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 54/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 55/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 56/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 57/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 58/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 59/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 60/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 61/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 62/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 63/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 64/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 65/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 66/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 67/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 68/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 69/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 70/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 71/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 72/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 73/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 74/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 75/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 76/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 77/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 78/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 79/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 80/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 81/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 82/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 83/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 84/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 85/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 86/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 87/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 88/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 89/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 90/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 91/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 92/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 93/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 94/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 95/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 96/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 97/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 98/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 99/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# 📋 Processing pair 100/100
# ❌ BGE error: SentenceTransformer.forward() missing 1 required positional argument: 'input'
# ❌ LLaMA Remote error: name 'calculate_llama_remote_similarity' is not defined
#
# ✅ Score calculation complete!

# %%
# Add scores to DataFrame and generate predictions
threshold = 0.5
print(f"Using classification threshold: {threshold}")

# Function to make predictions
def make_prediction(score, threshold=0.5):
    if score is None or pd.isna(score):
        return 'unknown'
    return 'select' if score > threshold else 'reject'

# Add scores and predictions to DataFrame
for model in scores.keys():
    if model_config[model]['enabled']:
        sampled_df[f'{model}_similarity'] = scores[model]
        sampled_df[f'{model}_prediction'] = [make_prediction(s, threshold) for s in scores[model]]

# Create display columns including Role and Reason_for_decision
display_columns = ['Role', 'Decision', 'Reason_for_decision']
for model in scores.keys():
    if model_config[model]['enabled']:
        display_columns.extend([f'{model}_similarity', f'{model}_prediction'])

# Create comparative table with original index
comparison_table = sampled_df[display_columns]

print("\n📊 Comparative Table of Similarity Scores and Predictions:")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)
print(comparison_table.to_string())
# Out:
# Using classification threshold: 0.5
#
# 📊 Comparative Table of Similarity Scores and Predictions:
#                           Role Decision                                                                                                                                                                                Reason_for_decision bge_similarity bge_prediction  openai_similarity openai_prediction  bge_m3_similarity bge_m3_prediction  careerbert_similarity careerbert_prediction  confit_similarity confit_prediction  voyage_similarity voyage_prediction llama_remote_similarity llama_remote_prediction
# 0            Robotics Engineer   reject                                                                                                                                                    Lacked leadership skills for a senior position.           None        unknown             0.4729            reject             0.6034            select                 0.6868                select             0.6206            select             0.6256            select                    None                 unknown
# 1        E-commerce Specialist   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4893            reject             0.6196            select                 0.6223                select             0.5047            select             0.5974            select                    None                 unknown
# 2               Cloud Engineer   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4568            reject             0.6818            select                 0.7519                select             0.6228            select             0.5528            select                    None                 unknown
# 3        E-commerce Specialist   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.4686            reject             0.6151            select                 0.6145                select             0.5093            select             0.6339            select                    None                 unknown
# 4             Network Engineer   select                                                                                                                                                        Proven track record of successful projects.           None        unknown             0.6539            select             0.8148            select                 0.9536                select             0.7713            select             0.7422            select                    None                 unknown
# 5              Product Manager   select                                                   Displayed excellent collaboration and teamwork mindset, Demonstrated a strong understanding of the company’s goals and how they could contribute           None        unknown             0.5738            select             0.6734            select                 0.7483                select             0.5840            select             0.7985            select                    None                 unknown
# 6       Database Administrator   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.4126            reject             0.6014            select                 0.6896                select             0.5359            select             0.6513            select                    None                 unknown
# 7        IT Support Specialist   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.3906            reject             0.5517            select                 0.5259                select             0.4562            reject             0.5978            select                    None                 unknown
# 8         Mobile App Developer   select                                                                                                                                                       Excellent full-stack development experience.           None        unknown             0.3826            reject             0.5665            select                 0.7300                select             0.4659            reject             0.5423            select                    None                 unknown
# 9                  QA Engineer   select                                                                                                                                                       Solid experience in machine learning and AI.           None        unknown             0.4703            reject             0.6115            select                 0.6011                select             0.5441            select             0.5482            select                    None                 unknown
# 10             DevOps Engineer   select                                                                                                                                                       Solid experience in machine learning and AI.           None        unknown             0.4250            reject             0.6147            select                 0.6742                select             0.5883            select             0.5578            select                    None                 unknown
# 11  Human Resources Specialist   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.4089            reject             0.5968            select                 0.6181                select             0.5193            select             0.5480            select                    None                 unknown
# 12             Product Manager   reject                                                                                                                                                        Inability to adapt to remote work settings.           None        unknown             0.5926            select             0.7543            select                 0.9191                select             0.7175            select             0.6855            select                    None                 unknown
# 13        Mobile App Developer   select                                                                                                                                                       Solid experience in machine learning and AI.           None        unknown             0.4178            reject             0.5837            select                 0.7425                select             0.6274            select             0.5868            select                    None                 unknown
# 14               Data Engineer   reject                                            Insufficient mastery of SQL optimization, Cloud data tools, Python/Scala made it challenging to consider this candidate for the Data Engineer position.           None        unknown             0.4882            reject             0.6334            select                 0.7597                select             0.5760            select             0.7144            select                    None                 unknown
# 15                Data Analyst   select                                                                                                                                                       Excellent full-stack development experience.           None        unknown             0.3973            reject             0.5715            select                 0.7831                select             0.5907            select             0.6141            select                    None                 unknown
# 16                 UI Designer   reject                                                                               With only 8 years of experience and gaps in Wireframing, Figma, this candidate is not yet ready for the UI Designer.           None        unknown             0.5295            select             0.6237            select                 0.7521                select             0.6584            select             0.6602            select                    None                 unknown
# 17             Product Manager   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4079            reject             0.6184            select                 0.6220                select             0.5396            select             0.5442            select                    None                 unknown
# 18  Human Resources Specialist   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.3779            reject             0.4818            reject                 0.7337                select             0.3920            reject             0.5417            select                    None                 unknown
# 19              Content Writer   select                                                                                                                                                       Excellent full-stack development experience.           None        unknown             0.2824            reject             0.4905            reject                 0.5155                select             0.3340            reject             0.3832            reject                    None                 unknown
# 20              Data Architect   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4963            reject             0.6257            select                 0.8078                select             0.6452            select             0.6526            select                    None                 unknown
# 21                data analyst   reject                                                                                                                           expected_experience : 0-2 years, domains: marketing, finance, healthcare           None        unknown             0.4757            reject             0.5821            select                 0.4436                reject             0.4226            reject             0.6276            select                    None                 unknown
# 22             product manager   select                                                                                                                                                                                technical knowledge           None        unknown             0.5314            select             0.6581            select                 0.6548                select             0.6602            select             0.7858            select                    None                 unknown
# 23               AI Researcher   select                                                                                                                                                       Solid experience in machine learning and AI.           None        unknown             0.4545            reject             0.5739            select                 0.5381                select             0.5435            select             0.4885            reject                    None                 unknown
# 24               AI Researcher   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.5443            select             0.6479            select                 0.7427                select             0.5340            select             0.6064            select                    None                 unknown
# 25              Game Developer   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.3944            reject             0.5795            select                 0.7164                select             0.4574            reject             0.5768            select                    None                 unknown
# 26                Data Analyst   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.3690            reject             0.5017            select                 0.7344                select             0.4703            reject             0.4981            reject                    None                 unknown
# 27                Data Analyst   reject                                                                                                                                              Insufficient system design expertise for senior role.           None        unknown             0.4191            reject             0.5178            select                 0.7452                select             0.4565            reject             0.5640            select                    None                 unknown
# 28              Data Scientist   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.2629            reject             0.4485            reject                 0.4978                reject             0.3178            reject             0.3796            reject                    None                 unknown
# 29             AR/VR Developer   reject                                                                                                                                              Insufficient system design expertise for senior role.           None        unknown             0.4667            reject             0.5565            select                 0.7173                select             0.4697            reject             0.6442            select                    None                 unknown
# 30        System Administrator   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.3863            reject             0.6398            select                 0.7721                select             0.5995            select             0.6242            select                    None                 unknown
# 31        Blockchain Developer   select                                                                                                                                                       Excellent full-stack development experience.           None        unknown             0.5643            select             0.6643            select                 0.7887                select             0.5109            select             0.6592            select                    None                 unknown
# 32                data analyst   reject                                                                                                                           expected_experience : 3-5 years, domains: marketing, finance, healthcare           None        unknown             0.4658            reject             0.5652            select                 0.4223                reject             0.3662            reject             0.5778            select                    None                 unknown
# 33           Software Engineer   select                                                                                                                                                       Excellent full-stack development experience.           None        unknown             0.3535            reject             0.5942            select                 0.7468                select             0.5132            select             0.5269            select                    None                 unknown
# 34              Data Scientist   reject                                                                                                                                                    Lacked leadership skills for a senior position.           None        unknown             0.4477            reject             0.5150            select                 0.7780                select             0.5198            select             0.5012            select                    None                 unknown
# 35                 UI Engineer   select                                                                                                                                                       Excellent full-stack development experience.           None        unknown             0.4516            reject             0.5723            select                 0.7272                select             0.5224            select             0.6160            select                    None                 unknown
# 36              Cloud Engineer   reject                                                                                                                                                  Needs improvement in machine learning algorithms.           None        unknown             0.4678            reject             0.6622            select                 0.7684                select             0.6098            select             0.5869            select                    None                 unknown
# 37       E-commerce Specialist   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4776            reject             0.5968            select                 0.6606                select             0.3458            reject             0.6045            select                    None                 unknown
# 38       E-commerce Specialist   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.3719            reject             0.5220            select                 0.5734                select             0.4651            reject             0.6011            select                    None                 unknown
# 39        Blockchain Developer   select                                                                                                                                                 Impressive leadership and communication abilities.           None        unknown             0.3917            reject             0.6076            select                 0.7309                select             0.4058            reject             0.5413            select                    None                 unknown
# 40              Game Developer   select                                                                                                                                                       Solid experience in machine learning and AI.           None        unknown             0.3008            reject             0.6339            select                 0.5778                select             0.4947            reject             0.5763            select                    None                 unknown
# 41               AI Researcher   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.4463            reject             0.5742            select                 0.6261                select             0.5828            select             0.5307            select                    None                 unknown
# 42       E-commerce Specialist   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.3607            reject             0.5900            select                 0.5631                select             0.5252            select             0.5939            select                    None                 unknown
# 43      Database Administrator   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4828            reject             0.6408            select                 0.8474                select             0.5739            select             0.6293            select                    None                 unknown
# 44                Data Analyst   select  The candidate's 2 years of experience combined with proficiency in Excel/Google Sheets, Statistical analysis, A/B testing positions them well to contribute effectively to the Data Analyst role.           None        unknown             0.4830            reject             0.6135            select                 0.7984                select             0.6730            select             0.6027            select                    None                 unknown
# 45              Cloud Engineer   select                                                                                                                                                 Impressive leadership and communication abilities.           None        unknown             0.4291            reject             0.6297            select                 0.7135                select             0.4916            reject             0.5203            select                    None                 unknown
# 46             Product Manager   reject                                                                                                                                              Insufficient system design expertise for senior role.           None        unknown             0.4667            reject             0.6068            select                 0.6971                select             0.5534            select             0.5591            select                    None                 unknown
# 47              Data Architect   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.5507            select             0.6719            select                 0.8162                select             0.7548            select             0.6028            select                    None                 unknown
# 48              Data Scientist   reject                                                                                                                                                             Lack of relevant skills or experience.           None        unknown             0.6572            select             0.6849            select                 0.9113                select             0.6631            select             0.7987            select                    None                 unknown
# 49           software engineer   select                                                                                                                           expected_experience : 6-8 years, domains: e-commerce, banking, education           None        unknown             0.4543            reject             0.5292            select                 0.4332                reject             0.3971            reject             0.5890            select                    None                 unknown
# 50              Data Scientist   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.3899            reject             0.5061            select                 0.7417                select             0.4550            reject             0.5915            select                    None                 unknown
# 51               Data Engineer   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.4021            reject             0.5210            select                 0.5296                select             0.5080            select             0.6316            select                    None                 unknown
# 52        Full Stack Developer   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.3655            reject             0.5550            select                 0.5631                select             0.3694            reject             0.5293            select                    None                 unknown
# 53        Blockchain Developer   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.4990            reject             0.6815            select                 0.7525                select             0.5710            select             0.6705            select                    None                 unknown
# 54                data analyst   select                                                                                                                            expected_experience : 9+ years, domains: marketing, finance, healthcare           None        unknown             0.3698            reject             0.5253            select                 0.4910                reject             0.3754            reject             0.5962            select                    None                 unknown
# 55                 ui engineer   reject                                                                                                                                                                                     experience gap           None        unknown             0.6131            select             0.6938            select                 0.7155                select             0.6676            select             0.7772            select                    None                 unknown
# 56             Product Manager   select                                                                                                                                                                    Relevant skills and experience.           None        unknown             0.6873            select             0.7756            select                 0.9323                select             0.7902            select             0.8593            select                    None                 unknown
# 57              data scientist   reject                                                                                                                              expected_experience : 3-5 years, domains: healthcare, finance, retail           None        unknown             0.3681            reject             0.5187            select                 0.5960                select             0.4232            reject             0.5790            select                    None                 unknown
# 58              Game Developer   select                                                                                                                                                 Impressive leadership and communication abilities.           None        unknown             0.4293            reject             0.6219            select                 0.6786                select             0.6029            select             0.6765            select                    None                 unknown
# 59                data analyst   reject                                                                                                                           expected_experience : 0-2 years, domains: marketing, finance, healthcare           None        unknown             0.4811            reject             0.6398            select                 0.5509                select             0.4177            reject             0.6443            select                    None                 unknown
# 60                 QA Engineer   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4884            reject             0.6416            select                 0.6503                select             0.6128            select             0.6446            select                    None                 unknown
# 61            Business Analyst   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4712            reject             0.6025            select                 0.7157                select             0.6156            select             0.6169            select                    None                 unknown
# 62           software engineer   reject                                                                                                                                                                                technical knowledge           None        unknown             0.5138            select             0.7206            select                 0.7694                select             0.5953            select             0.6230            select                    None                 unknown
# 63                 QA Engineer   select                                                                                                                                                 Impressive leadership and communication abilities.           None        unknown             0.4338            reject             0.6184            select                 0.5749                select             0.5838            select             0.5354            select                    None                 unknown
# 64                 UX Designer   reject                                                                                                                                              Insufficient system design expertise for senior role.           None        unknown             0.4856            reject             0.5825            select                 0.7268                select             0.6079            select             0.5456            select                    None                 unknown
# 65             Cloud Architect   reject                                                                                                                                                  Needs improvement in machine learning algorithms.           None        unknown             0.5174            select             0.6317            select                 0.8192                select             0.6718            select             0.6546            select                    None                 unknown
# 66                 QA Engineer   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.2810            reject             0.4622            reject                 0.5374                select             0.3544            reject             0.3749            reject                    None                 unknown
# 67        Mobile App Developer   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.2946            reject             0.4663            reject                 0.5423                select             0.3476            reject             0.4321            reject                    None                 unknown
# 68              Data Scientist   reject                                                                                                                                                  Needs improvement in machine learning algorithms.           None        unknown             0.4329            reject             0.5438            select                 0.7698                select             0.5786            select             0.5948            select                    None                 unknown
# 69  Human Resources Specialist   reject                                                                                                                                                    Lacked leadership skills for a senior position.           None        unknown             0.4328            reject             0.6149            select                 0.7757                select             0.5227            select             0.5448            select                    None                 unknown
# 70                data analyst   reject                                                                                                                           expected_experience : 0-2 years, domains: marketing, finance, healthcare           None        unknown             0.4898            reject             0.6169            select                 0.5246                select             0.4650            reject             0.6513            select                    None                 unknown
# 71           Robotics Engineer   select                                                                                                                                                 Impressive leadership and communication abilities.           None        unknown             0.5460            select             0.6769            select                 0.7942                select             0.6594            select             0.6625            select                    None                 unknown
# 72        Blockchain Developer   reject                                                                                                                                                  Needs improvement in machine learning algorithms.           None        unknown             0.4834            reject             0.6766            select                 0.8208                select             0.5529            select             0.6675            select                    None                 unknown
# 73             product manager   select                                                                                                                                                                                    business acumen           None        unknown             0.5849            select             0.7450            select                 0.6777                select             0.6862            select             0.6056            select                    None                 unknown
# 74              Cloud Engineer   reject                                                                                                                                                    Lacks hands-on experience with cloud platforms.           None        unknown             0.2674            reject             0.4440            reject                 0.4676                reject             0.3599            reject             0.3656            reject                    None                 unknown
# 75           Software Engineer   reject                                                                                                                                                             No experience in back-end development.           None        unknown             0.4572            reject             0.6833            select                 0.7513                select             0.4613            reject             0.5559            select                    None                 unknown
# 76                Data Analyst   reject                     Insufficient mastery of Data-driven decision making, Trend analysis, Business intelligence tools made it challenging to consider this candidate for the Data Analyst position.           None        unknown             0.4917            reject             0.5869            select                 0.7537                select             0.7424            select             0.6239            select                    None                 unknown
# 77           Software Engineer   select                                                 Strong expertise in System design, Data structures and solid 7-year background in Software Engineer-related tasks make this candidate a great fit.           None        unknown             0.5140            select             0.7133            select                 0.6721                select             0.6053            select             0.5785            select                    None                 unknown
# 78             product manager   reject                                                                                                                                                                                    business acumen           None        unknown             0.5448            select             0.6347            select                 0.6416                select             0.6744            select             0.7664            select                    None                 unknown
# 79             Product Manager   reject                                                                                                                                                    Lacked leadership skills for a senior position.           None        unknown             0.4310            reject             0.6214            select                 0.6822                select             0.6596            select             0.5219            select                    None                 unknown
# 80              data scientist   reject                                                                                                                              expected_experience : 3-5 years, domains: healthcare, finance, retail           None        unknown             0.3885            reject             0.5907            select                 0.5722                select             0.3070            reject             0.6176            select                    None                 unknown
# 81             Cloud Architect   reject                                                                                                                                                    Lacked leadership skills for a senior position.           None        unknown             0.4742            reject             0.6193            select                 0.7967                select             0.5551            select             0.5673            select                    None                 unknown
# 82             Product Manager   select                                                                                                                                                     Perfectly aligned with data engineering needs.           None        unknown             0.4268            reject             0.6056            select                 0.5941                select             0.4430            reject             0.5319            select                    None                 unknown
# 83               Data Engineer   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.4547            reject             0.5742            select                 0.7979                select             0.6905            select             0.5836            select                    None                 unknown
# 84              Content Writer   select                                                                                                                                                       Solid experience in machine learning and AI.           None        unknown             0.3706            reject             0.5856            select                 0.7241                select             0.5271            select             0.5797            select                    None                 unknown
# 85  Human Resources Specialist   reject                                                                                                                                              Insufficient system design expertise for senior role.           None        unknown             0.4741            reject             0.6765            select                 0.7685                select             0.5810            select             0.5912            select                    None                 unknown
# 86             product manager   select                                                                                                                                                                                         experience           None        unknown             0.5272            select             0.7087            select                 0.6453                select             0.7037            select             0.6302            select                    None                 unknown
# 87           software engineer   select                                                                                                                           expected_experience : 6-8 years, domains: e-commerce, banking, education           None        unknown             0.3517            reject             0.4898            reject                 0.5054                select             0.2114            reject             0.5597            select                    None                 unknown
# 88              Data Scientist   select  Proven expertise in Machine learning algorithms, Python/Pandas along with 7 years of hands-on experience in Data Scientist-specific tasks makes this candidate an excellent fit for the position.           None        unknown             0.5625            select             0.6396            select                 0.7890                select             0.6668            select             0.6395            select                    None                 unknown
# 89               Data Engineer   reject                                                                                                                                                             Lack of relevant skills or experience.           None        unknown             0.6747            select             0.6790            select                 0.9199                select             0.6688            select             0.8191            select                    None                 unknown
# 90               Data Engineer   reject                                                                                                                                                  Inadequate communication or interpersonal skills.           None        unknown             0.7094            select             0.7868            select                 0.9509                select             0.7010            select             0.8389            select                    None                 unknown
# 91               data engineer   reject                                                                                                                                                                                         experience           None        unknown             0.5952            select             0.7227            select                 0.6890                select             0.7135            select             0.7245            select                    None                 unknown
# 92       Cybersecurity Analyst   reject                                                                                                                                                    Lacks hands-on experience with cloud platforms.           None        unknown             0.5141            select             0.6764            select                 0.7501                select             0.5507            select             0.6217            select                    None                 unknown
# 93             Product Manager   reject                                                                                                                                              Insufficient system design expertise for senior role.           None        unknown             0.3361            reject             0.5301            select                 0.5090                select             0.4942            reject             0.5694            select                    None                 unknown
# 94        Mobile App Developer   select                                                                                                                                                              Strong technical skills in AI and ML.           None        unknown             0.4259            reject             0.5797            select                 0.7570                select             0.5081            select             0.6195            select                    None                 unknown
# 95             DevOps Engineer   reject                                                                                                                                                    Lacks hands-on experience with cloud platforms.           None        unknown             0.3774            reject             0.5610            select                 0.6545                select             0.4208            reject             0.5734            select                    None                 unknown
# 96               Data Engineer   reject                                                                                                                                                                  Lack of enthusiasm or motivation.           None        unknown             0.6665            select             0.7416            select                 0.9440                select             0.7008            select             0.8046            select                    None                 unknown
# 97                Data Analyst   select                                                                                                                                                       Excellent full-stack development experience.           None        unknown             0.5073            select             0.6054            select                 0.7823                select             0.6281            select             0.6326            select                    None                 unknown
# 98            Business Analyst   reject                                                                                                                                                    Lacked leadership skills for a senior position.           None        unknown             0.4761            reject             0.5408            select                 0.6351                select             0.4404            reject             0.6172            select                    None                 unknown
# 99                 UI Engineer   reject                                                                                                                                                                  Lack of enthusiasm or motivation.           None        unknown             0.7285            select             0.7316            select                 0.9117                select             0.6643            select             0.8150            select                    None                 unknown

# %%
# Calculate performance metrics for each enabled model
print("\n📈 Model Performance Metrics:")
print("=" * 80)

for model in scores.keys():
    if model_config[model]['enabled']:
        print(f"\n🔍 {model.upper()} Model Performance:")
        print("-" * 50)

        # Filter out unknown predictions
        valid_mask = sampled_df[f'{model}_prediction'] != 'unknown'
        valid_df = sampled_df[valid_mask]

        if len(valid_df) > 0:
            accuracy = accuracy_score(valid_df['Decision'], valid_df[f'{model}_prediction'])
            precision, recall, f1, _ = precision_recall_fscore_support(
                valid_df['Decision'],
                valid_df[f'{model}_prediction'],
                average='weighted'
            )

            print(f"Accuracy: {accuracy:.4f}")
            print(f"Precision: {precision:.4f}")
            print(f"Recall: {recall:.4f}")
            print(f"F1-Score: {f1:.4f}")
            print(f"Valid predictions: {len(valid_df)}/{len(sampled_df)}")

            print("\nDetailed Classification Report:")
            print(classification_report(valid_df['Decision'], valid_df[f'{model}_prediction']))
        else:
            print("No valid predictions available")
# Out:
# 📈 Model Performance Metrics:
# ================================================================================
#
# 🔍 BGE Model Performance:
# --------------------------------------------------
# No valid predictions available
#
# 🔍 OPENAI Model Performance:
# --------------------------------------------------
# Accuracy: 0.4800
# Precision: 0.4740
# Recall: 0.4800
# F1-Score: 0.4482
# Valid predictions: 100/100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.49      0.72      0.58        50
#       select       0.46      0.24      0.32        50
#
#     accuracy                           0.48       100
#    macro avg       0.47      0.48      0.45       100
# weighted avg       0.47      0.48      0.45       100
#
#
# 🔍 BGE_M3 Model Performance:
# --------------------------------------------------
# Accuracy: 0.4700
# Precision: 0.3848
# Recall: 0.4700
# F1-Score: 0.3498
# Valid predictions: 100/100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.29      0.04      0.07        50
#       select       0.48      0.90      0.63        50
#
#     accuracy                           0.47       100
#    macro avg       0.38      0.47      0.35       100
# weighted avg       0.38      0.47      0.35       100
#
#
# 🔍 CAREERBERT Model Performance:
# --------------------------------------------------
# Accuracy: 0.5000
# Precision: 0.5000
# Recall: 0.5000
# F1-Score: 0.3800
# Valid predictions: 100/100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.50      0.06      0.11        50
#       select       0.50      0.94      0.65        50
#
#     accuracy                           0.50       100
#    macro avg       0.50      0.50      0.38       100
# weighted avg       0.50      0.50      0.38       100
#
#
# 🔍 CONFIT Model Performance:
# --------------------------------------------------
# Accuracy: 0.4900
# Precision: 0.4887
# Recall: 0.4900
# F1-Score: 0.4748
# Valid predictions: 100/100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.48      0.32      0.39        50
#       select       0.49      0.66      0.56        50
#
#     accuracy                           0.49       100
#    macro avg       0.49      0.49      0.47       100
# weighted avg       0.49      0.49      0.47       100
#
#
# 🔍 VOYAGE Model Performance:
# --------------------------------------------------
# Accuracy: 0.4700
# Precision: 0.3848
# Recall: 0.4700
# F1-Score: 0.3498
# Valid predictions: 100/100
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       reject       0.29      0.04      0.07        50
#       select       0.48      0.90      0.63        50
#
#     accuracy                           0.47       100
#    macro avg       0.38      0.47      0.35       100
# weighted avg       0.38      0.47      0.35       100
#
#
# 🔍 LLAMA_REMOTE Model Performance:
# --------------------------------------------------
# No valid predictions available
