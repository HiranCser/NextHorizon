# %% [markdown]
# https://huggingface.co/shashu2325/resume-job-matcher-lora
#
# Uses dataset: https://huggingface.co/datasets/cnamuangtoun/resume-job-description-fit

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/drive/MyDrive/AI-ML Self Learning/next_horizon/resume_job_recommendation/model-shashu2325-resume-job-matcher-lora/dataset.csv')
df

# %%
from transformers import AutoModel, AutoTokenizer
from peft import PeftModel
import torch
import torch.nn.functional as F
import openai
import numpy as np
import os
from google.colab import userdata

# Ensure OpenAI API key is set as a Colab secret named 'OPENAI_API_KEY'
try:
    openai.api_key = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("OpenAI API key not found in Colab secrets. Please set it as a secret named 'OPENAI_API_KEY'.")
    openai.api_key = None


# Load BGE models and tokenizer
# Load base model
try:
    base_model = AutoModel.from_pretrained("BAAI/bge-large-en-v1.5")
    # Load Peft model
    model = PeftModel.from_pretrained(base_model, "shashu2325/resume-job-matcher-lora")
    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-large-en-v1.5")
    print("BGE models and tokenizer loaded successfully.")
except Exception as e:
    print(f"Failed to load BGE models or tokenizer: {e}")
    base_model = None
    model = None
    tokenizer = None


def calculate_bge_similarity(resume_text, job_text):
    """Calculates similarity between resume and job text using BGE embeddings."""
    if model is None or tokenizer is None:
        print("BGE models or tokenizer not loaded. Cannot calculate similarity.")
        return None

    try:
        # Process texts
        resume_inputs = tokenizer(resume_text, return_tensors="pt", max_length=512, padding="max_length", truncation=True)
        job_inputs = tokenizer(job_text, return_tensors="pt", max_length=512, padding="max_length", truncation=True)

        # Get embeddings
        with torch.no_grad():
            # Get embeddings using mean pooling
            resume_outputs = model(**resume_inputs)
            job_outputs = model(**job_inputs)

            # Mean pooling
            resume_emb = resume_outputs.last_hidden_state.mean(dim=1)
            job_emb = job_outputs.last_hidden_state.mean(dim=1)

            # Normalize and calculate similarity
            resume_emb = F.normalize(resume_emb, p=2, dim=1)
            job_emb = F.normalize(job_emb, p=2, dim=1)

            similarity = torch.sum(resume_emb * job_emb, dim=1)
            match_score = torch.sigmoid(similarity).item()

        return match_score
    except Exception as e:
        print(f"Error calculating BGE similarity: {e}")
        return None

def get_openai_embedding(text, model="text-embedding-3-small"):
    """Gets OpenAI embedding for a given text."""
    if openai.api_key is None:
        print("OpenAI API key not set. Cannot get embedding.")
        return None
    try:
        text = text.replace("\n", " ")
        return openai.embeddings.create(input=[text], model=model).data[0].embedding
    except Exception as e:
        print(f"Error getting OpenAI embedding: {e}")
        return None

def cosine_similarity(a, b):
    """Calculate cosine similarity between two vectors"""
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    na = np.linalg.norm(a)
    nb = np.linalg.norm(b)
    if na == 0 or nb == 0:
        return 0.0
    return float(a.dot(b) / (na * nb))


def calculate_openai_similarity(resume_text, job_text):
    """Calculates cosine similarity between resume and job text using OpenAI embeddings."""
    resume_embedding = get_openai_embedding(resume_text)
    job_embedding = get_openai_embedding(job_text)

    if resume_embedding is None or job_embedding is None:
        print("Failed to get OpenAI embeddings. Cannot calculate similarity.")
        return None

    # Calculate similarity using the cosine function
    similarity_score = cosine_similarity(resume_embedding, job_embedding)

    return similarity_score

# Example usage to verify functions (optional)
# resume_text = "Software engineer with Python experience"
# job_text = "Looking for Python developer"

# bge_score = calculate_bge_similarity(resume_text, job_text)
# openai_score = calculate_openai_similarity(resume_text, job_text)

# print(f"BGE Match score: {bge_score:.4f}")
# print(f"OpenAI Match score: {openai_score:.4f}")
# Out:
# BGE models and tokenizer loaded successfully.

# %%
select_df = df[df['Decision'] == 'select']
reject_df = df[df['Decision'] == 'reject']

# Determine sample sizes. Aim for equal representation if possible, or adjust if one category is much smaller.
total_samples = 1000
num_select = min(len(select_df), total_samples // 2)
num_reject = min(len(reject_df), total_samples - num_select)

# Adjust if one category is much smaller and we couldn't get 50 total with the initial split
if num_select + num_reject < total_samples:
    if len(select_df) > len(reject_df):
        num_select = min(len(select_df), total_samples - num_reject)
    else:
        num_reject = min(len(reject_df), total_samples - num_select)

sampled_select_df = select_df.sample(n=num_select, random_state=42) # Use random_state for reproducibility
sampled_reject_df = reject_df.sample(n=num_reject, random_state=42)

sampled_df = pd.concat([sampled_select_df, sampled_reject_df])

# Shuffle the combined sample to mix the select and reject rows
sampled_df = sampled_df.sample(frac=1, random_state=42).reset_index(drop=True)

display(sampled_df.head())
display(sampled_df.info())
# Out:
#                      Role                                             Resume  \
# 0           Data Engineer  Here's a sample resume for Diana Johnson, a Da...
# 1  Database Administrator  Here's a sample resume for Carrie Smith:\n\nCa...
# 2   E-commerce Specialist  Here's a professional resume for Sarah Myers, ...
# 3       Software Engineer  **Meera**\n**Software Engineer Candidate**\n\n...
# 4   IT Support Specialist  Here's a sample resume for Lauren King:\n\nLau...
#
#   Decision                                Reason_for_decision  \
# 0   reject                  Lack of enthusiasm or motivation.
# 1   reject    Lacked leadership skills for a senior position.
# 2   reject  Needs improvement in machine learning algorithms.
# 3   reject  The candidate lacked sufficient expertise in k...
# 4   select              Strong technical skills in AI and ML.
#
#                                      Job_Description
# 0  Here is a job description for a Data Engineer:...
# 1  We're hiring a Database Administrator to devel...
# 2  Join our fast-growing team and help us scale o...
# 3  Looking for a skilled Software Engineer with a...
# 4  Be part of a passionate team at the forefront ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Role                 1000 non-null   object
#  1   Resume               1000 non-null   object
#  2   Decision             1000 non-null   object
#  3   Reason_for_decision  1000 non-null   object
#  4   Job_Description      1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB
# None

# %%
bge_scores = []
openai_scores = []

for index, row in sampled_df.iterrows():
    resume_text = str(row['Resume']) if pd.notna(row['Resume']) else ""
    job_text = str(row['Job_Description']) if pd.notna(row['Job_Description']) else ""

    # Calculate BGE similarity with error handling
    try:
        print(f"Calculating BGE similarity for row {index}")
        bge_score = calculate_bge_similarity(resume_text, job_text)
        print(f"BGE similarity for row {index}: {bge_score}")
    except Exception as e:
        print(f"Error calculating BGE similarity for row {index}: {e}")
        bge_score = None # or np.nan

    bge_scores.append(bge_score)

    # Calculate OpenAI similarity with error handling
    try:
        # Check if API key is set before calling the function
        if openai.api_key is None:
            print(f"Skipping OpenAI similarity calculation for row {index} because API key is not set.")
            openai_score = None
        else:
            print(f"Calculating OpenAI similarity for row {index}")
            openai_score = calculate_openai_similarity(resume_text, job_text)
            print(f"OpenAI similarity for row {index}: {openai_score}")
    except Exception as e:
        print(f"Error calculating OpenAI similarity for row {index}: {e}")
        openai_score = None # or np.nan

    openai_scores.append(openai_score)

print("Score calculation complete.")
# Out:
# Calculating BGE similarity for row 0
# BGE similarity for row 0: 0.688313364982605
# Calculating OpenAI similarity for row 0
# OpenAI similarity for row 0: 0.6665256834471475
# Calculating BGE similarity for row 1
# BGE similarity for row 1: 0.6440492868423462
# Calculating OpenAI similarity for row 1
# OpenAI similarity for row 1: 0.4304944558833671
# Calculating BGE similarity for row 2
# BGE similarity for row 2: 0.6475348472595215
# Calculating OpenAI similarity for row 2
# OpenAI similarity for row 2: 0.5265663025480486
# Calculating BGE similarity for row 3
# BGE similarity for row 3: 0.647560715675354
# Calculating OpenAI similarity for row 3
# OpenAI similarity for row 3: 0.5287259579597844
# Calculating BGE similarity for row 4
# BGE similarity for row 4: 0.5631677508354187
# Calculating OpenAI similarity for row 4
# OpenAI similarity for row 4: 0.3744969984247195
# Calculating BGE similarity for row 5
# BGE similarity for row 5: 0.6059319376945496
# Calculating OpenAI similarity for row 5
# OpenAI similarity for row 5: 0.42263386073659237
# Calculating BGE similarity for row 6
# BGE similarity for row 6: 0.6408621072769165
# Calculating OpenAI similarity for row 6
# OpenAI similarity for row 6: 0.40119943032067146
# Calculating BGE similarity for row 7
# BGE similarity for row 7: 0.5590536594390869
# Calculating OpenAI similarity for row 7
# OpenAI similarity for row 7: 0.3885279689870221
# Calculating BGE similarity for row 8
# BGE similarity for row 8: 0.6682948470115662
# Calculating OpenAI similarity for row 8
# OpenAI similarity for row 8: 0.5060211482501018
# Calculating BGE similarity for row 9
# BGE similarity for row 9: 0.6347119212150574
# Calculating OpenAI similarity for row 9
# OpenAI similarity for row 9: 0.5618597678353452
# Calculating BGE similarity for row 10
# BGE similarity for row 10: 0.6337094306945801
# Calculating OpenAI similarity for row 10
# OpenAI similarity for row 10: 0.47962473395004024
# Calculating BGE similarity for row 11
# BGE similarity for row 11: 0.6101095676422119
# Calculating OpenAI similarity for row 11
# OpenAI similarity for row 11: 0.4079129584443139
# Calculating BGE similarity for row 12
# BGE similarity for row 12: 0.6028661131858826
# Calculating OpenAI similarity for row 12
# OpenAI similarity for row 12: 0.46286407544660063
# Calculating BGE similarity for row 13
# BGE similarity for row 13: 0.675389289855957
# Calculating OpenAI similarity for row 13
# OpenAI similarity for row 13: 0.644847787462715
# Calculating BGE similarity for row 14
# BGE similarity for row 14: 0.6085258722305298
# Calculating OpenAI similarity for row 14
# OpenAI similarity for row 14: 0.45409534132730445
# Calculating BGE similarity for row 15
# BGE similarity for row 15: 0.6220906972885132
# Calculating OpenAI similarity for row 15
# OpenAI similarity for row 15: 0.40020599385965
# Calculating BGE similarity for row 16
# BGE similarity for row 16: 0.6225695610046387
# Calculating OpenAI similarity for row 16
# OpenAI similarity for row 16: 0.4222497300158494
# Calculating BGE similarity for row 17
# BGE similarity for row 17: 0.6175318360328674
# Calculating OpenAI similarity for row 17
# OpenAI similarity for row 17: 0.5422857701538291
# Calculating BGE similarity for row 18
# BGE similarity for row 18: 0.6052684187889099
# Calculating OpenAI similarity for row 18
# OpenAI similarity for row 18: 0.3991892084296444
# Calculating BGE similarity for row 19
# BGE similarity for row 19: 0.6300128102302551
# Calculating OpenAI similarity for row 19
# OpenAI similarity for row 19: 0.43572622868752736
# Calculating BGE similarity for row 20
# BGE similarity for row 20: 0.6116369962692261
# Calculating OpenAI similarity for row 20
# OpenAI similarity for row 20: 0.47106705038204216
# Calculating BGE similarity for row 21
# BGE similarity for row 21: 0.6220768094062805
# Calculating OpenAI similarity for row 21
# OpenAI similarity for row 21: 0.3943574904564021
# Calculating BGE similarity for row 22
# BGE similarity for row 22: 0.6043765544891357
# Calculating OpenAI similarity for row 22
# OpenAI similarity for row 22: 0.41802899383676045
# Calculating BGE similarity for row 23
# BGE similarity for row 23: 0.6060775518417358
# Calculating OpenAI similarity for row 23
# OpenAI similarity for row 23: 0.407986186053107
# Calculating BGE similarity for row 24
# BGE similarity for row 24: 0.6410834193229675
# Calculating OpenAI similarity for row 24
# OpenAI similarity for row 24: 0.45883583773615183
# Calculating BGE similarity for row 25
# BGE similarity for row 25: 0.6469979286193848
# Calculating OpenAI similarity for row 25
# OpenAI similarity for row 25: 0.4939516775670308
# Calculating BGE similarity for row 26
# BGE similarity for row 26: 0.6240215301513672
# Calculating OpenAI similarity for row 26
# OpenAI similarity for row 26: 0.39241770682772176
# Calculating BGE similarity for row 27
# BGE similarity for row 27: 0.6215186715126038
# Calculating OpenAI similarity for row 27
# OpenAI similarity for row 27: 0.4455656315315534
# Calculating BGE similarity for row 28
# BGE similarity for row 28: 0.6340959072113037
# Calculating OpenAI similarity for row 28
# OpenAI similarity for row 28: 0.3976020672950536
# Calculating BGE similarity for row 29
# BGE similarity for row 29: 0.6115735173225403
# Calculating OpenAI similarity for row 29
# OpenAI similarity for row 29: 0.38685567999033016
# Calculating BGE similarity for row 30
# BGE similarity for row 30: 0.6906833648681641
# Calculating OpenAI similarity for row 30
# OpenAI similarity for row 30: 0.6292609865138044
# Calculating BGE similarity for row 31
# BGE similarity for row 31: 0.6274163722991943
# Calculating OpenAI similarity for row 31
# OpenAI similarity for row 31: 0.3795396798931639
# Calculating BGE similarity for row 32
# BGE similarity for row 32: 0.5732677578926086
# Calculating OpenAI similarity for row 32
# OpenAI similarity for row 32: 0.34274239665122014
# Calculating BGE similarity for row 33
# BGE similarity for row 33: 0.6181978583335876
# Calculating OpenAI similarity for row 33
# OpenAI similarity for row 33: 0.45930468155663423
# Calculating BGE similarity for row 34
# BGE similarity for row 34: 0.6137201189994812
# Calculating OpenAI similarity for row 34
# OpenAI similarity for row 34: 0.5110800339960024
# Calculating BGE similarity for row 35
# BGE similarity for row 35: 0.6709927916526794
# Calculating OpenAI similarity for row 35
# OpenAI similarity for row 35: 0.5795791114322227
# Calculating BGE similarity for row 36
# BGE similarity for row 36: 0.5814303159713745
# Calculating OpenAI similarity for row 36
# OpenAI similarity for row 36: 0.4347172950505875
# Calculating BGE similarity for row 37
# BGE similarity for row 37: 0.638340413570404
# Calculating OpenAI similarity for row 37
# OpenAI similarity for row 37: 0.567710596532211
# Calculating BGE similarity for row 38
# BGE similarity for row 38: 0.632365345954895
# Calculating OpenAI similarity for row 38
# OpenAI similarity for row 38: 0.4471893885841435
# Calculating BGE similarity for row 39
# BGE similarity for row 39: 0.7103462815284729
# Calculating OpenAI similarity for row 39
# OpenAI similarity for row 39: 0.731204353153387
# Calculating BGE similarity for row 40
# BGE similarity for row 40: 0.548388659954071
# Calculating OpenAI similarity for row 40
# OpenAI similarity for row 40: 0.2466292882969641
# Calculating BGE similarity for row 41
# BGE similarity for row 41: 0.6140298247337341
# Calculating OpenAI similarity for row 41
# OpenAI similarity for row 41: 0.4508465369364877
# Calculating BGE similarity for row 42
# BGE similarity for row 42: 0.6397116184234619
# Calculating OpenAI similarity for row 42
# OpenAI similarity for row 42: 0.49227539678315185
# Calculating BGE similarity for row 43
# BGE similarity for row 43: 0.6578059792518616
# Calculating OpenAI similarity for row 43
# OpenAI similarity for row 43: 0.4100382054104139
# Calculating BGE similarity for row 44
# BGE similarity for row 44: 0.5799024701118469
# Calculating OpenAI similarity for row 44
# OpenAI similarity for row 44: 0.5146869738202398
# Calculating BGE similarity for row 45
# BGE similarity for row 45: 0.5824664831161499
# Calculating OpenAI similarity for row 45
# OpenAI similarity for row 45: 0.41311552992738093
# Calculating BGE similarity for row 46
# BGE similarity for row 46: 0.6302344799041748
# Calculating OpenAI similarity for row 46
# OpenAI similarity for row 46: 0.49406649643526096
# Calculating BGE similarity for row 47
# BGE similarity for row 47: 0.6572009921073914
# Calculating OpenAI similarity for row 47
# OpenAI similarity for row 47: 0.467069255199862
# Calculating BGE similarity for row 48
# BGE similarity for row 48: 0.6328223347663879
# Calculating OpenAI similarity for row 48
# OpenAI similarity for row 48: 0.40076261779672206
# Calculating BGE similarity for row 49
# BGE similarity for row 49: 0.6261658072471619
# Calculating OpenAI similarity for row 49
# OpenAI similarity for row 49: 0.404248012994514
# Calculating BGE similarity for row 50
# BGE similarity for row 50: 0.5603480339050293
# Calculating OpenAI similarity for row 50
# OpenAI similarity for row 50: 0.478442808521493
# Calculating BGE similarity for row 51
# BGE similarity for row 51: 0.6420391798019409
# Calculating OpenAI similarity for row 51
# OpenAI similarity for row 51: 0.4762410714114472
# Calculating BGE similarity for row 52
# BGE similarity for row 52: 0.6016305685043335
# Calculating OpenAI similarity for row 52
# OpenAI similarity for row 52: 0.3065517296374694
# Calculating BGE similarity for row 53
# BGE similarity for row 53: 0.6658791303634644
# Calculating OpenAI similarity for row 53
# OpenAI similarity for row 53: 0.5430166373386993
# Calculating BGE similarity for row 54
# BGE similarity for row 54: 0.6392605304718018
# Calculating OpenAI similarity for row 54
# OpenAI similarity for row 54: 0.5625021366741164
# Calculating BGE similarity for row 55
# BGE similarity for row 55: 0.626777708530426
# Calculating OpenAI similarity for row 55
# OpenAI similarity for row 55: 0.40891993299888246
# Calculating BGE similarity for row 56
# BGE similarity for row 56: 0.6873682737350464
# Calculating OpenAI similarity for row 56
# OpenAI similarity for row 56: 0.6172862285393053
# Calculating BGE similarity for row 57
# BGE similarity for row 57: 0.6343713402748108
# Calculating OpenAI similarity for row 57
# OpenAI similarity for row 57: 0.3827631164617431
# Calculating BGE similarity for row 58
# BGE similarity for row 58: 0.671127200126648
# Calculating OpenAI similarity for row 58
# OpenAI similarity for row 58: 0.511009621040505
# Calculating BGE similarity for row 59
# BGE similarity for row 59: 0.5786395072937012
# Calculating OpenAI similarity for row 59
# OpenAI similarity for row 59: 0.2620592681210011
# Calculating BGE similarity for row 60
# BGE similarity for row 60: 0.6243994832038879
# Calculating OpenAI similarity for row 60
# OpenAI similarity for row 60: 0.43220066104362354
# Calculating BGE similarity for row 61
# BGE similarity for row 61: 0.625530481338501
# Calculating OpenAI similarity for row 61
# OpenAI similarity for row 61: 0.45500415972238323
# Calculating BGE similarity for row 62
# BGE similarity for row 62: 0.6228533983230591
# Calculating OpenAI similarity for row 62
# OpenAI similarity for row 62: 0.4761082793361463
# Calculating BGE similarity for row 63
# BGE similarity for row 63: 0.5608593225479126
# Calculating OpenAI similarity for row 63
# OpenAI similarity for row 63: 0.2554152597237764
# Calculating BGE similarity for row 64
# BGE similarity for row 64: 0.6392776966094971
# Calculating OpenAI similarity for row 64
# OpenAI similarity for row 64: 0.5108694012776185
# Calculating BGE similarity for row 65
# BGE similarity for row 65: 0.5546103715896606
# Calculating OpenAI similarity for row 65
# OpenAI similarity for row 65: 0.40495356137023625
# Calculating BGE similarity for row 66
# BGE similarity for row 66: 0.6302955150604248
# Calculating OpenAI similarity for row 66
# OpenAI similarity for row 66: 0.5703775714088652
# Calculating BGE similarity for row 67
# BGE similarity for row 67: 0.655323326587677
# Calculating OpenAI similarity for row 67
# OpenAI similarity for row 67: 0.5140052826320586
# Calculating BGE similarity for row 68
# BGE similarity for row 68: 0.6143629550933838
# Calculating OpenAI similarity for row 68
# OpenAI similarity for row 68: 0.4639952285163754
# Calculating BGE similarity for row 69
# BGE similarity for row 69: 0.6078685522079468
# Calculating OpenAI similarity for row 69
# OpenAI similarity for row 69: 0.44765722730998375
# Calculating BGE similarity for row 70
# BGE similarity for row 70: 0.5670300126075745
# Calculating OpenAI similarity for row 70
# OpenAI similarity for row 70: 0.24926167839720914
# Calculating BGE similarity for row 71
# BGE similarity for row 71: 0.5608336925506592
# Calculating OpenAI similarity for row 71
# OpenAI similarity for row 71: 0.3103754679715422
# Calculating BGE similarity for row 72
# BGE similarity for row 72: 0.5694440007209778
# Calculating OpenAI similarity for row 72
# OpenAI similarity for row 72: 0.3976992100736599
# Calculating BGE similarity for row 73
# BGE similarity for row 73: 0.6032429337501526
# Calculating OpenAI similarity for row 73
# OpenAI similarity for row 73: 0.5212352055540054
# Calculating BGE similarity for row 74
# BGE similarity for row 74: 0.6287900805473328
# Calculating OpenAI similarity for row 74
# OpenAI similarity for row 74: 0.4543545552810217
# Calculating BGE similarity for row 75
# BGE similarity for row 75: 0.6352382302284241
# Calculating OpenAI similarity for row 75
# OpenAI similarity for row 75: 0.4832882338724022
# Calculating BGE similarity for row 76
# BGE similarity for row 76: 0.5664951205253601
# Calculating OpenAI similarity for row 76
# OpenAI similarity for row 76: 0.3678371503452816
# Calculating BGE similarity for row 77
# BGE similarity for row 77: 0.6409378051757812
# Calculating OpenAI similarity for row 77
# OpenAI similarity for row 77: 0.5737853806606735
# Calculating BGE similarity for row 78
# BGE similarity for row 78: 0.6368744373321533
# Calculating OpenAI similarity for row 78
# OpenAI similarity for row 78: 0.5749228757736339
# Calculating BGE similarity for row 79
# BGE similarity for row 79: 0.6499544978141785
# Calculating OpenAI similarity for row 79
# OpenAI similarity for row 79: 0.42745060095646836
# Calculating BGE similarity for row 80
# BGE similarity for row 80: 0.5921280980110168
# Calculating OpenAI similarity for row 80
# OpenAI similarity for row 80: 0.4031092875051318
# Calculating BGE similarity for row 81
# BGE similarity for row 81: 0.62567138671875
# Calculating OpenAI similarity for row 81
# OpenAI similarity for row 81: 0.47943016778239517
# Calculating BGE similarity for row 82
# BGE similarity for row 82: 0.6504673957824707
# Calculating OpenAI similarity for row 82
# OpenAI similarity for row 82: 0.47137929930835687
# Calculating BGE similarity for row 83
# BGE similarity for row 83: 0.6284874081611633
# Calculating OpenAI similarity for row 83
# OpenAI similarity for row 83: 0.515417701403823
# Calculating BGE similarity for row 84
# BGE similarity for row 84: 0.6209303736686707
# Calculating OpenAI similarity for row 84
# OpenAI similarity for row 84: 0.46852504113578275
# Calculating BGE similarity for row 85
# BGE similarity for row 85: 0.5567560791969299
# Calculating OpenAI similarity for row 85
# OpenAI similarity for row 85: 0.2673429805808535
# Calculating BGE similarity for row 86
# BGE similarity for row 86: 0.5784180164337158
# Calculating OpenAI similarity for row 86
# OpenAI similarity for row 86: 0.3932582014317911
# Calculating BGE similarity for row 87
# BGE similarity for row 87: 0.6075195670127869
# Calculating OpenAI similarity for row 87
# OpenAI similarity for row 87: 0.42667112019326026
# Calculating BGE similarity for row 88
# BGE similarity for row 88: 0.6236014366149902
# Calculating OpenAI similarity for row 88
# OpenAI similarity for row 88: 0.5311925332317828
# Calculating BGE similarity for row 89
# BGE similarity for row 89: 0.6462065577507019
# Calculating OpenAI similarity for row 89
# OpenAI similarity for row 89: 0.4495479343548712
# Calculating BGE similarity for row 90
# BGE similarity for row 90: 0.6109859347343445
# Calculating OpenAI similarity for row 90
# OpenAI similarity for row 90: 0.45927775330114645
# Calculating BGE similarity for row 91
# BGE similarity for row 91: 0.6464259624481201
# Calculating OpenAI similarity for row 91
# OpenAI similarity for row 91: 0.5411648790540015
# Calculating BGE similarity for row 92
# BGE similarity for row 92: 0.6348679661750793
# Calculating OpenAI similarity for row 92
# OpenAI similarity for row 92: 0.4674915235100307
# Calculating BGE similarity for row 93
# BGE similarity for row 93: 0.5605016350746155
# Calculating OpenAI similarity for row 93
# OpenAI similarity for row 93: 0.2854781352875826
# Calculating BGE similarity for row 94
# BGE similarity for row 94: 0.6280177235603333
# Calculating OpenAI similarity for row 94
# OpenAI similarity for row 94: 0.41153410146423125
# Calculating BGE similarity for row 95
# BGE similarity for row 95: 0.6173191666603088
# Calculating OpenAI similarity for row 95
# OpenAI similarity for row 95: 0.48790441547595886
# Calculating BGE similarity for row 96
# BGE similarity for row 96: 0.5330631136894226
# Calculating OpenAI similarity for row 96
# OpenAI similarity for row 96: 0.38411325604358926
# Calculating BGE similarity for row 97
# BGE similarity for row 97: 0.6465324759483337
# Calculating OpenAI similarity for row 97
# OpenAI similarity for row 97: 0.45252305936517984
# Calculating BGE similarity for row 98
# BGE similarity for row 98: 0.5830800533294678
# Calculating OpenAI similarity for row 98
# OpenAI similarity for row 98: 0.4660366225827568
# Calculating BGE similarity for row 99
# BGE similarity for row 99: 0.6880533695220947
# Calculating OpenAI similarity for row 99
# OpenAI similarity for row 99: 0.6244904716504407
# Calculating BGE similarity for row 100
# BGE similarity for row 100: 0.6197718381881714
# Calculating OpenAI similarity for row 100
# OpenAI similarity for row 100: 0.5401920102978691
# Calculating BGE similarity for row 101
# BGE similarity for row 101: 0.6101682186126709
# Calculating OpenAI similarity for row 101
# OpenAI similarity for row 101: 0.43514320752768015
# Calculating BGE similarity for row 102
# BGE similarity for row 102: 0.5919873714447021
# Calculating OpenAI similarity for row 102
# OpenAI similarity for row 102: 0.41098801342280733
# Calculating BGE similarity for row 103
# BGE similarity for row 103: 0.6739252209663391
# Calculating OpenAI similarity for row 103
# OpenAI similarity for row 103: 0.5962488675388983
# Calculating BGE similarity for row 104
# BGE similarity for row 104: 0.6322541236877441
# Calculating OpenAI similarity for row 104
# OpenAI similarity for row 104: 0.4815358528899839
# Calculating BGE similarity for row 105
# BGE similarity for row 105: 0.6107710599899292
# Calculating OpenAI similarity for row 105
# OpenAI similarity for row 105: 0.4464285922814886
# Calculating BGE similarity for row 106
# BGE similarity for row 106: 0.6587113738059998
# Calculating OpenAI similarity for row 106
# OpenAI similarity for row 106: 0.5040878907377033
# Calculating BGE similarity for row 107
# BGE similarity for row 107: 0.6353856325149536
# Calculating OpenAI similarity for row 107
# OpenAI similarity for row 107: 0.48252716639691046
# Calculating BGE similarity for row 108
# BGE similarity for row 108: 0.55577152967453
# Calculating OpenAI similarity for row 108
# OpenAI similarity for row 108: 0.48624182967074686
# Calculating BGE similarity for row 109
# BGE similarity for row 109: 0.6574686169624329
# Calculating OpenAI similarity for row 109
# OpenAI similarity for row 109: 0.5127219159049979
# Calculating BGE similarity for row 110
# BGE similarity for row 110: 0.6499835252761841
# Calculating OpenAI similarity for row 110
# OpenAI similarity for row 110: 0.6131332148829406
# Calculating BGE similarity for row 111
# BGE similarity for row 111: 0.613578200340271
# Calculating OpenAI similarity for row 111
# OpenAI similarity for row 111: 0.43053234061450874
# Calculating BGE similarity for row 112
# BGE similarity for row 112: 0.6389045119285583
# Calculating OpenAI similarity for row 112
# OpenAI similarity for row 112: 0.4704010498014285
# Calculating BGE similarity for row 113
# BGE similarity for row 113: 0.6347519755363464
# Calculating OpenAI similarity for row 113
# OpenAI similarity for row 113: 0.45225861970170395
# Calculating BGE similarity for row 114
# BGE similarity for row 114: 0.6232796311378479
# Calculating OpenAI similarity for row 114
# OpenAI similarity for row 114: 0.4052915340707831
# Calculating BGE similarity for row 115
# BGE similarity for row 115: 0.6603156924247742
# Calculating OpenAI similarity for row 115
# OpenAI similarity for row 115: 0.500786731699363
# Calculating BGE similarity for row 116
# BGE similarity for row 116: 0.6315329670906067
# Calculating OpenAI similarity for row 116
# OpenAI similarity for row 116: 0.5521136414753822
# Calculating BGE similarity for row 117
# BGE similarity for row 117: 0.5972375869750977
# Calculating OpenAI similarity for row 117
# OpenAI similarity for row 117: 0.3396141773378784
# Calculating BGE similarity for row 118
# BGE similarity for row 118: 0.6474514603614807
# Calculating OpenAI similarity for row 118
# OpenAI similarity for row 118: 0.4742137590130925
# Calculating BGE similarity for row 119
# BGE similarity for row 119: 0.5809038877487183
# Calculating OpenAI similarity for row 119
# OpenAI similarity for row 119: 0.27529427135104517
# Calculating BGE similarity for row 120
# BGE similarity for row 120: 0.5921134352684021
# Calculating OpenAI similarity for row 120
# OpenAI similarity for row 120: 0.4290364666623467
# Calculating BGE similarity for row 121
# BGE similarity for row 121: 0.6493240594863892
# Calculating OpenAI similarity for row 121
# OpenAI similarity for row 121: 0.46906008923766085
# Calculating BGE similarity for row 122
# BGE similarity for row 122: 0.5944136381149292
# Calculating OpenAI similarity for row 122
# OpenAI similarity for row 122: 0.40640765474841084
# Calculating BGE similarity for row 123
# BGE similarity for row 123: 0.6018719673156738
# Calculating OpenAI similarity for row 123
# OpenAI similarity for row 123: 0.4800820300149016
# Calculating BGE similarity for row 124
# BGE similarity for row 124: 0.6469295024871826
# Calculating OpenAI similarity for row 124
# OpenAI similarity for row 124: 0.4803320928605051
# Calculating BGE similarity for row 125
# BGE similarity for row 125: 0.6265372037887573
# Calculating OpenAI similarity for row 125
# OpenAI similarity for row 125: 0.5002819493493426
# Calculating BGE similarity for row 126
# BGE similarity for row 126: 0.5565044283866882
# Calculating OpenAI similarity for row 126
# OpenAI similarity for row 126: 0.3799231975440275
# Calculating BGE similarity for row 127
# BGE similarity for row 127: 0.5766628384590149
# Calculating OpenAI similarity for row 127
# OpenAI similarity for row 127: 0.4471136855469213
# Calculating BGE similarity for row 128
# BGE similarity for row 128: 0.6555032134056091
# Calculating OpenAI similarity for row 128
# OpenAI similarity for row 128: 0.5183626100625391
# Calculating BGE similarity for row 129
# BGE similarity for row 129: 0.589816153049469
# Calculating OpenAI similarity for row 129
# OpenAI similarity for row 129: 0.42751457198385284
# Calculating BGE similarity for row 130
# BGE similarity for row 130: 0.6298664212226868
# Calculating OpenAI similarity for row 130
# OpenAI similarity for row 130: 0.436757307295938
# Calculating BGE similarity for row 131
# BGE similarity for row 131: 0.6674228310585022
# Calculating OpenAI similarity for row 131
# OpenAI similarity for row 131: 0.4646677189678668
# Calculating BGE similarity for row 132
# BGE similarity for row 132: 0.6305736899375916
# Calculating OpenAI similarity for row 132
# OpenAI similarity for row 132: 0.492303525808629
# Calculating BGE similarity for row 133
# BGE similarity for row 133: 0.5480741262435913
# Calculating OpenAI similarity for row 133
# OpenAI similarity for row 133: 0.48424852937951507
# Calculating BGE similarity for row 134
# BGE similarity for row 134: 0.5555785894393921
# Calculating OpenAI similarity for row 134
# OpenAI similarity for row 134: 0.48982776305050957
# Calculating BGE similarity for row 135
# BGE similarity for row 135: 0.6321744918823242
# Calculating OpenAI similarity for row 135
# OpenAI similarity for row 135: 0.48198441673672193
# Calculating BGE similarity for row 136
# BGE similarity for row 136: 0.6439105272293091
# Calculating OpenAI similarity for row 136
# OpenAI similarity for row 136: 0.4759415468119708
# Calculating BGE similarity for row 137
# BGE similarity for row 137: 0.544675886631012
# Calculating OpenAI similarity for row 137
# OpenAI similarity for row 137: 0.3758491762800356
# Calculating BGE similarity for row 138
# BGE similarity for row 138: 0.6626764535903931
# Calculating OpenAI similarity for row 138
# OpenAI similarity for row 138: 0.5506594845463539
# Calculating BGE similarity for row 139
# BGE similarity for row 139: 0.6205288171768188
# Calculating OpenAI similarity for row 139
# OpenAI similarity for row 139: 0.47472070907114544
# Calculating BGE similarity for row 140
# BGE similarity for row 140: 0.6954824924468994
# Calculating OpenAI similarity for row 140
# OpenAI similarity for row 140: 0.6539256843866934
# Calculating BGE similarity for row 141
# BGE similarity for row 141: 0.6115595102310181
# Calculating OpenAI similarity for row 141
# OpenAI similarity for row 141: 0.42992491194343485
# Calculating BGE similarity for row 142
# BGE similarity for row 142: 0.5715197324752808
# Calculating OpenAI similarity for row 142
# OpenAI similarity for row 142: 0.43878499732619336
# Calculating BGE similarity for row 143
# BGE similarity for row 143: 0.6257010698318481
# Calculating OpenAI similarity for row 143
# OpenAI similarity for row 143: 0.414107848985617
# Calculating BGE similarity for row 144
# BGE similarity for row 144: 0.6317376494407654
# Calculating OpenAI similarity for row 144
# OpenAI similarity for row 144: 0.4321152928076495
# Calculating BGE similarity for row 145
# BGE similarity for row 145: 0.6449615955352783
# Calculating OpenAI similarity for row 145
# OpenAI similarity for row 145: 0.48543413336391694
# Calculating BGE similarity for row 146
# BGE similarity for row 146: 0.6290484070777893
# Calculating OpenAI similarity for row 146
# OpenAI similarity for row 146: 0.3610408926360665
# Calculating BGE similarity for row 147
# BGE similarity for row 147: 0.5769556164741516
# Calculating OpenAI similarity for row 147
# OpenAI similarity for row 147: 0.2882678460234881
# Calculating BGE similarity for row 148
# BGE similarity for row 148: 0.622863233089447
# Calculating OpenAI similarity for row 148
# OpenAI similarity for row 148: 0.354756303840222
# Calculating BGE similarity for row 149
# BGE similarity for row 149: 0.6319704055786133
# Calculating OpenAI similarity for row 149
# OpenAI similarity for row 149: 0.4247624112060606
# Calculating BGE similarity for row 150
# BGE similarity for row 150: 0.6510617733001709
# Calculating OpenAI similarity for row 150
# OpenAI similarity for row 150: 0.44270404242277456
# Calculating BGE similarity for row 151
# BGE similarity for row 151: 0.6069741249084473
# Calculating OpenAI similarity for row 151
# OpenAI similarity for row 151: 0.5166029481084361
# Calculating BGE similarity for row 152
# BGE similarity for row 152: 0.5729894042015076
# Calculating OpenAI similarity for row 152
# OpenAI similarity for row 152: 0.42032188243396923
# Calculating BGE similarity for row 153
# BGE similarity for row 153: 0.6908299922943115
# Calculating OpenAI similarity for row 153
# OpenAI similarity for row 153: 0.684430708325066
# Calculating BGE similarity for row 154
# BGE similarity for row 154: 0.647246778011322
# Calculating OpenAI similarity for row 154
# OpenAI similarity for row 154: 0.4878103536423926
# Calculating BGE similarity for row 155
# BGE similarity for row 155: 0.6281251907348633
# Calculating OpenAI similarity for row 155
# OpenAI similarity for row 155: 0.5246022836319985
# Calculating BGE similarity for row 156
# BGE similarity for row 156: 0.6303831338882446
# Calculating OpenAI similarity for row 156
# OpenAI similarity for row 156: 0.4349905810743433
# Calculating BGE similarity for row 157
# BGE similarity for row 157: 0.6198490858078003
# Calculating OpenAI similarity for row 157
# OpenAI similarity for row 157: 0.5038241367264972
# Calculating BGE similarity for row 158
# BGE similarity for row 158: 0.5955571532249451
# Calculating OpenAI similarity for row 158
# OpenAI similarity for row 158: 0.38243489986215856
# Calculating BGE similarity for row 159
# BGE similarity for row 159: 0.6471226215362549
# Calculating OpenAI similarity for row 159
# OpenAI similarity for row 159: 0.43791080867137866
# Calculating BGE similarity for row 160
# BGE similarity for row 160: 0.5826180577278137
# Calculating OpenAI similarity for row 160
# OpenAI similarity for row 160: 0.4427456918832097
# Calculating BGE similarity for row 161
# BGE similarity for row 161: 0.6350294351577759
# Calculating OpenAI similarity for row 161
# OpenAI similarity for row 161: 0.5089599727746845
# Calculating BGE similarity for row 162
# BGE similarity for row 162: 0.6184934377670288
# Calculating OpenAI similarity for row 162
# OpenAI similarity for row 162: 0.4396167503578689
# Calculating BGE similarity for row 163
# BGE similarity for row 163: 0.6123380661010742
# Calculating OpenAI similarity for row 163
# OpenAI similarity for row 163: 0.471240857741742
# Calculating BGE similarity for row 164
# BGE similarity for row 164: 0.5723245739936829
# Calculating OpenAI similarity for row 164
# OpenAI similarity for row 164: 0.40126306953089136
# Calculating BGE similarity for row 165
# BGE similarity for row 165: 0.6097744703292847
# Calculating OpenAI similarity for row 165
# OpenAI similarity for row 165: 0.4333122546814792
# Calculating BGE similarity for row 166
# BGE similarity for row 166: 0.6154018044471741
# Calculating OpenAI similarity for row 166
# OpenAI similarity for row 166: 0.4180023433539118
# Calculating BGE similarity for row 167
# BGE similarity for row 167: 0.6584304571151733
# Calculating OpenAI similarity for row 167
# OpenAI similarity for row 167: 0.5510667772703165
# Calculating BGE similarity for row 168
# BGE similarity for row 168: 0.6208271384239197
# Calculating OpenAI similarity for row 168
# OpenAI similarity for row 168: 0.4272682516177853
# Calculating BGE similarity for row 169
# BGE similarity for row 169: 0.7083863615989685
# Calculating OpenAI similarity for row 169
# OpenAI similarity for row 169: 0.582732825274298
# Calculating BGE similarity for row 170
# BGE similarity for row 170: 0.6166073083877563
# Calculating OpenAI similarity for row 170
# OpenAI similarity for row 170: 0.4721556699665552
# Calculating BGE similarity for row 171
# BGE similarity for row 171: 0.6362819075584412
# Calculating OpenAI similarity for row 171
# OpenAI similarity for row 171: 0.5847866014565987
# Calculating BGE similarity for row 172
# BGE similarity for row 172: 0.5621079802513123
# Calculating OpenAI similarity for row 172
# OpenAI similarity for row 172: 0.4575054535003791
# Calculating BGE similarity for row 173
# BGE similarity for row 173: 0.6520043611526489
# Calculating OpenAI similarity for row 173
# OpenAI similarity for row 173: 0.5226879954926834
# Calculating BGE similarity for row 174
# BGE similarity for row 174: 0.6167885065078735
# Calculating OpenAI similarity for row 174
# OpenAI similarity for row 174: 0.4159477859699599
# Calculating BGE similarity for row 175
# BGE similarity for row 175: 0.6437370181083679
# Calculating OpenAI similarity for row 175
# OpenAI similarity for row 175: 0.42568729869085187
# Calculating BGE similarity for row 176
# BGE similarity for row 176: 0.636188805103302
# Calculating OpenAI similarity for row 176
# OpenAI similarity for row 176: 0.5086617671478788
# Calculating BGE similarity for row 177
# BGE similarity for row 177: 0.5423674583435059
# Calculating OpenAI similarity for row 177
# OpenAI similarity for row 177: 0.4585226821345106
# Calculating BGE similarity for row 178
# BGE similarity for row 178: 0.5436896085739136
# Calculating OpenAI similarity for row 178
# OpenAI similarity for row 178: 0.3751713689279232
# Calculating BGE similarity for row 179
# BGE similarity for row 179: 0.5877100229263306
# Calculating OpenAI similarity for row 179
# OpenAI similarity for row 179: 0.45194822867936435
# Calculating BGE similarity for row 180
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1762302916.py in <cell line: 0>()
#       9     try:
#      10         print(f"Calculating BGE similarity for row {index}")
# ---> 11         bge_score = calculate_bge_similarity(resume_text, job_text)
#      12         print(f"BGE similarity for row {index}: {bge_score}")
#      13     except Exception as e:
#
# /tmp/ipython-input-2992215620.py in calculate_bge_similarity(resume_text, job_text)
#      47             # Get embeddings using mean pooling
#      48             resume_outputs = model(**resume_inputs)
# ---> 49             job_outputs = model(**job_inputs)
#      50
#      51             # Mean pooling
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    2896             with self._enable_peft_forward_hooks(**kwargs):
#    2897                 kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 2898                 return self.base_model(
#    2899                     input_ids=input_ids,
#    2900                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py in forward(self, *args, **kwargs)
#     220
#     221     def forward(self, *args: Any, **kwargs: Any):
# --> 222         return self.model.forward(*args, **kwargs)
#     223
#     224     def _pre_injection_hook(self, model: nn.Module, config: PeftConfig, adapter_name: str) -> None:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     997         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     998
# --> 999         encoder_outputs = self.encoder(
#    1000             embedding_output,
#    1001             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     647             layer_head_mask = head_mask[i] if head_mask is not None else None
#     648
# --> 649             layer_outputs = layer_module(
#     650                 hidden_states,
#     651                 attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      92
#      93             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94         return super().__call__(*args, **kwargs)
#      95
#      96
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/deprecation.py in wrapped_func(*args, **kwargs)
#     170                 warnings.warn(message, FutureWarning, stacklevel=2)
#     171
# --> 172             return func(*args, **kwargs)
#     173
#     174         return wrapped_func
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, output_attentions, cache_position)
#     555         cache_position: Optional[torch.Tensor] = None,
#     556     ) -> tuple[torch.Tensor]:
# --> 557         self_attention_outputs = self.attention(
#     558             hidden_states,
#     559             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/deprecation.py in wrapped_func(*args, **kwargs)
#     170                 warnings.warn(message, FutureWarning, stacklevel=2)
#     171
# --> 172             return func(*args, **kwargs)
#     173
#     174         return wrapped_func
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, past_key_values, output_attentions, cache_position)
#     485         cache_position: Optional[torch.Tensor] = None,
#     486     ) -> tuple[torch.Tensor]:
# --> 487         self_outputs = self.self(
#     488             hidden_states,
#     489             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/deprecation.py in wrapped_func(*args, **kwargs)
#     170                 warnings.warn(message, FutureWarning, stacklevel=2)
#     171
# --> 172             return func(*args, **kwargs)
#     173
#     174         return wrapped_func
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, past_key_values, output_attentions, cache_position)
#     389             )
#     390             value_layer = (
# --> 391                 self.value(current_states)
#     392                 .view(bsz, -1, self.num_attention_heads, self.attention_head_size)
#     393                 .transpose(1, 2)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/peft/tuners/lora/layer.py in forward(self, x, *args, **kwargs)
#     755             result = self.base_layer(x, *args, **kwargs)
#     756         else:
# --> 757             result = self.base_layer(x, *args, **kwargs)
#     758             torch_result_dtype = result.dtype
#     759
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# Add the scores as new columns to the sampled DataFrame
sampled_df['bge_similarity'] = bge_scores
sampled_df['openai_similarity'] = openai_scores

# Classify based on a threshold of 0.5
sampled_df['bge_prediction'] = sampled_df['bge_similarity'].apply(lambda x: 'select' if x > 0.5 else 'reject')
sampled_df['openai_prediction'] = sampled_df['openai_similarity'].apply(lambda x: 'select' if x > 0.5 else 'reject')

# Display the comparative table with original decision and predictions
print("Comparative Table of Similarity Scores and Predictions:")
display(sampled_df[['Role', 'Resume', 'Job_Description', 'Decision', 'bge_similarity', 'bge_prediction', 'openai_similarity', 'openai_prediction']])

# %%
from sklearn.metrics import classification_report, accuracy_score

# Convert 'Decision' column to numerical labels if needed for some metrics (optional)
# sampled_df['Decision_numeric'] = sampled_df['Decision'].apply(lambda x: 1 if x == 'select' else 0)
# sampled_df['bge_prediction_numeric'] = sampled_df['bge_prediction'].apply(lambda x: 1 if x == 'select' else 0)
# sampled_df['openai_prediction_numeric'] = sampled_df['openai_prediction'].apply(lambda x: 1 if x == 'select' else 0)


# Compare performance for BGE predictions
print("Performance Comparison for BGE Predictions:")
print(classification_report(sampled_df['Decision'], sampled_df['bge_prediction']))
print(f"Accuracy: {accuracy_score(sampled_df['Decision'], sampled_df['bge_prediction']):.4f}")

print("\n" + "="*50 + "\n")

# Compare performance for OpenAI predictions
print("Performance Comparison for OpenAI Predictions:")
print(classification_report(sampled_df['Decision'], sampled_df['openai_prediction']))
print(f"Accuracy: {accuracy_score(sampled_df['Decision'], sampled_df['openai_prediction']):.4f}")
