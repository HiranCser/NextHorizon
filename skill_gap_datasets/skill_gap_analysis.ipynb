# %%
# !pip uninstall tensorflow tensorflow-gpu keras

# %%
# If installed via conda
conda remove tensorflow keras --yes

# %%
"""
End-to-end Semantic Skill Gap Analysis

Steps:
1. Generate synthetic dataset: 1000 rows with required_skills, candidate_skills, expected_gap
2. Load dataset from CSV
3. Use sentence-transformer embeddings to infer gaps (predicted_gap)
4. Compare predicted_gap vs expected_gap to compute precision, recall, F1
"""

import os
import random
import json
from typing import List, Dict, Any

import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics import precision_score, recall_score, f1_score



# ============================================================
# 2. Utility functions for parsing and embeddings
# ============================================================

def to_list(skill_str: str) -> List[str]:
    """
    Convert comma-separated skills string to list of trimmed skills.
    """
    if not isinstance(skill_str, str):
        return []
    return [s.strip() for s in skill_str.split(",") if s.strip()]


def normalize_skill_text(skill: str) -> str:
    """
    Basic normalization: lowercase and strip. You can extend this.
    """
    return skill.strip().lower()


def compute_embeddings(
    model: SentenceTransformer,
    skills: List[str]
) -> np.ndarray:
    """
    Compute normalized embeddings for a list of skill phrases.
    """
    if not skills:
        return np.zeros((0, model.get_sentence_embedding_dimension()), dtype=np.float32)

    norm_skills = [normalize_skill_text(s) for s in skills]
    emb = model.encode(norm_skills, normalize_embeddings=True)
    return np.array(emb, dtype=np.float32)


def compute_gap_for_row(
    required: List[str],
    candidate: List[str],
    model: SentenceTransformer,
    partial_threshold: float = 0.55
) -> List[str]:
    """
    For a single row:
    - required: list of required skills
    - candidate: list of candidate skills
    Uses sentence embeddings + cosine similarity.
    Treats skills with max similarity < partial_threshold as gaps.
    Returns the list of required skills considered gaps.
    """
    if not required:
        return []

    req_emb = compute_embeddings(model, required)
    cand_emb = compute_embeddings(model, candidate)

    if cand_emb.shape[0] == 0:
        # No candidate skills: all required are gaps
        return list(required)

    predicted_gap = []

    # For each required skill, find max similarity with candidate skills
    # cosine similarity = dot product (because embeddings are normalized)
    sim_matrix = np.matmul(req_emb, cand_emb.T)  # [num_req, num_cand]

    for i, r in enumerate(required):
        sims = sim_matrix[i]
        max_sim = float(np.max(sims))  # best match
        if max_sim < partial_threshold:
            predicted_gap.append(r)

    return predicted_gap


# ============================================================
# 3. Evaluation: precision, recall, F1
# ============================================================

def evaluate_gap_detection(df: pd.DataFrame) -> Dict[str, float]:
    """
    Evaluate predicted gaps vs expected gaps across all rows.

    We treat each (row, required_skill) as a binary classification:
    - label 1 if in expected_gap_list
    - prediction 1 if in predicted_gap

    Returns global precision, recall, F1.
    """
    y_true = []
    y_pred = []

    for _, row in df.iterrows():
        required = row["required_list"]
        true_gap = set(row["expected_gap_list"])
        pred_gap = set(row["predicted_gap"])

        for skill in required:
            y_true.append(1 if skill in true_gap else 0)
            y_pred.append(1 if skill in pred_gap else 0)

    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    return {"precision": precision, "recall": recall, "f1": f1}


# ============================================================
# 4. Main script
# ============================================================

def main():
    random.seed(42)

    csv_path = "clustered_skill_gap_dataset_2000.csv"

    # Step 2: load dataset
    df = pd.read_csv(csv_path)
    print("Loaded dataset with shape:", df.shape)

    # Step 3: parse lists from comma-separated strings
    df["required_list"] = df["required_skills"].apply(to_list)
    df["candidate_list"] = df["candidate_skills"].apply(to_list)
    df["expected_gap_list"] = df["expected_gap"].apply(to_list)

    # Step 4: load embedding model once
    model_name = "sentence-transformers/all-MiniLM-L6-v2"
    print(f"Loading embedding model: {model_name}")
    model = SentenceTransformer(model_name)

    # Step 5: compute predicted gap for each row
    partial_threshold = 0.55  # you can tune this
    print(f"Computing predicted gaps with partial_threshold={partial_threshold}...")
    df["predicted_gap"] = df.apply(
        lambda row: compute_gap_for_row(
            row["required_list"],
            row["candidate_list"],
            model=model,
            partial_threshold=partial_threshold
        ),
        axis=1
    )

    # Step 6: evaluate precision, recall, F1
    metrics = evaluate_gap_detection(df)

    print("\n=== Global Skill Gap Detection Metrics ===")
    print(f"Precision: {metrics['precision']:.4f}")
    print(f"Recall   : {metrics['recall']:.4f}")
    print(f"F1-score : {metrics['f1']:.4f}")

    # Step 7: show a few example rows
    print("\n=== Sample Rows (first 20) ===")
    for i in range(20):
        row = df.iloc[i]
        print(f"\nRow {i+1}:")
        print("Required skills : ", row['required_list'])
        print("Candidate skills: ", row['candidate_list'])
        print("Expected gap    : ", row['expected_gap_list'])
        print("Predicted gap   : ", row['predicted_gap'])

    # Optional: save predictions to a new CSV
    out_path = "clustered_skill_gap_dataset_2000_Result.csv"
    df.to_csv(out_path, index=False)
    print(f"\nSaved dataset with predictions to: {out_path}")


if __name__ == "__main__":
    main()
# Out:
# Found existing dataset: clustered_skill_gap_dataset_2000.csv
# Loaded dataset with shape: (2000, 3)
# Loading embedding model: sentence-transformers/all-MiniLM-L6-v2
# Computing predicted gaps with partial_threshold=0.55...
#
# === Global Skill Gap Detection Metrics ===
# Precision: 0.8964
# Recall   : 0.9508
# F1-score : 0.9228
#
# === Sample Rows (first 5) ===
#
# Row 1:
# Required skills :  ['Go', 'B2B Sales', 'Marketing Analytics', 'SEM', 'Linux', 'Kubernetes']
# Candidate skills:  ['Adaptability', 'Diagnosis', 'Digital Marketing', 'Go', 'Kubernetes', 'Linux', 'Marketing Analytics', 'PHP', 'SEM', 'Teamwork']
# Expected gap    :  ['B2B Sales']
# Predicted gap   :  ['B2B Sales']
#
# Row 2:
# Required skills :  ['Patient Examination', 'Creativity', 'B2C Sales', 'Java', 'Deep Learning', 'Arbitration', 'Accounting']
# Candidate skills:  ['Accounting', 'Arbitration', 'B2C Sales', 'Communication', 'Creativity', 'Deep Learning', 'HR', 'Java', 'Kotlin', 'Patient Examination']
# Expected gap    :  []
# Predicted gap   :  []
#
# Row 3:
# Required skills :  ['Certified Public Accountant', 'Node.js', 'Agile', 'CRM', 'IFRS', 'Critical Thinking']
# Candidate skills:  ['Agile', 'CRM', 'Certified Public Accountant', 'Contract Drafting', 'Node.js']
# Expected gap    :  ['IFRS', 'Critical Thinking']
# Predicted gap   :  ['IFRS', 'Critical Thinking']
#
# Row 4:
# Required skills :  ['Internal Medicine', 'GAAP', 'NLP', 'Chartered Accountant', 'Audit', 'Digital Marketing', 'Lead Generation', 'Angular']
# Candidate skills:  ['Angular', 'Audit', 'Brand Strategy', 'Chartered Accountant', 'GAAP', 'Internal Medicine', 'NLP', 'Prospecting']
# Expected gap    :  ['Digital Marketing']
# Predicted gap   :  ['Digital Marketing', 'Lead Generation']
#
# Row 5:
# Required skills :  ['Budgeting', 'Litigation', 'Lead Generation', 'ASP.NET Core', 'Online Marketing', 'Teamwork']
# Candidate skills:  ['Leadership', 'Litigation', 'Performance Marketing', 'Presentation Skills', 'Prospecting', 'Teamwork', 'ASP.NET']
# Expected gap    :  ['Budgeting', 'ASP.NET Core']
# Predicted gap   :  ['Budgeting', 'Lead Generation']
#
# Row 6:
# Required skills :  ['Adaptability', 'Mediation', 'Litigation', 'IFRS', 'SEO', 'Linux', 'Training and Development', 'Talent Acquisition']
# Candidate skills:  ['Account Executive', 'Adaptability', 'C#', 'Communication', 'Creativity', 'IFRS', 'Linux', 'Litigation', 'Mediation', 'SEM', 'Talent Acquisition', 'Training and Development']
# Expected gap    :  []
# Predicted gap   :  ['SEO']
#
# Row 7:
# Required skills :  ['Strategic Planning', 'Lead Generation', 'Accounting', 'AWS', 'CRM', 'Physician']
# Candidate skills:  ['AWS', 'CRM', 'Certified Public Accountant', 'Corporate Finance', 'Lead Generation', 'Physician', 'Strategic Planning']
# Expected gap    :  []
# Predicted gap   :  []
#
# Row 8:
# Required skills :  ['PyTorch', 'Machine Learning', 'CA', 'NLP', 'Stakeholder Management', 'Product Management', 'Python', 'Valuation', 'Recruitment', 'JavaScript']
# Candidate skills:  ['Creativity', 'ETL', 'Employee Engagement', 'Git', 'Machine Learning', 'Negotiation', 'Product Management', 'PyTorch', 'Python', 'Recruitment', 'Stakeholder Management', 'Valuation']
# Expected gap    :  ['CA', 'NLP', 'JavaScript']
# Predicted gap   :  ['CA', 'NLP', 'JavaScript']
#
# Row 9:
# Required skills :  ['Arbitration', 'Online Marketing', 'Stakeholder Management', 'Power BI', 'Corporate Finance', 'Litigation', 'CA', 'Medical Practitioner', 'Logistics', 'Surgery']
# Candidate skills:  ['Angular', 'Arbitration', 'CA', 'Corporate Finance', 'Doctor', 'Litigation', 'Logistics', 'Marketing Analytics', 'Online Marketing', 'Power BI', 'Scrum', 'Stakeholder Management', 'Surgery']
# Expected gap    :  []
# Predicted gap   :  []
#
# Row 10:
# Required skills :  ['Human Resources', 'Online Marketing', 'Stakeholder Management', 'CI/CD', 'Problem Solving', 'Critical Thinking', 'Clinical Research', 'Marketing Analytics']
# Candidate skills:  ['.NET Core', 'CI/CD', 'Clinical Research', 'Critical Thinking', 'HR', 'Marketing Analytics', 'Online Marketing', 'Problem Solving', 'Stakeholder Management']
# Expected gap    :  []
# Predicted gap   :  []
#
# Row 11:
# Required skills :  ['Derivatives', 'Containerization', 'Email Marketing', 'TensorFlow', 'Hadoop', 'Strategic Planning', 'Patient Examination', 'Linux', 'Arbitration']
# Candidate skills:  ['Arbitration', 'Containerization', 'Derivatives', 'Linux', 'Patient Examination', 'Spring Boot', 'TensorFlow']
# Expected gap    :  ['Email Marketing', 'Hadoop', 'Strategic Planning']
# Predicted gap   :  ['Email Marketing', 'Hadoop', 'Strategic Planning']
#
# Row 12:
# Required skills :  ['Computer Vision', 'Criminal Law', 'Human Resources', 'HR', 'Online Marketing', 'Litigation', '.NET Core']
# Candidate skills:  ['Computer Vision', 'Corporate Finance', 'Criminal Law', 'Deep Learning', 'Digital Marketing', 'Human Resources', 'Litigation', 'Logistics', 'PyTorch', 'Social Media Marketing']
# Expected gap    :  ['.NET Core']
# Predicted gap   :  ['.NET Core']
#
# Row 13:
# Required skills :  ['Time Management', 'Stakeholder Management', '.NET Core', 'Budgeting', '.NET', 'Kotlin']
# Candidate skills:  ['Budgeting', 'Email Marketing', 'Kotlin', 'Node.js', 'Stakeholder Management', 'Time Management']
# Expected gap    :  ['.NET Core', '.NET']
# Predicted gap   :  ['.NET Core', '.NET']
#
# Row 14:
# Required skills :  ['Google Cloud', 'Teamwork', 'Email Marketing', 'Time Management', 'Negotiation Skills', 'NoSQL', 'Node.js', 'Compliance', 'Adaptability']
# Candidate skills:  ['Adaptability', 'C#', 'Compliance', 'Email Marketing', 'GCP', 'Negotiation Skills', 'NoSQL', 'Node.js', 'Time Management']
# Expected gap    :  ['Teamwork']
# Predicted gap   :  ['Teamwork']
#
# Row 15:
# Required skills :  ['Leadership', 'Docker', 'Angular', 'Strategic Planning', 'Online Marketing', 'Employee Engagement', 'Account Executive', 'CI/CD', 'Taxation']
# Candidate skills:  ['Angular', 'CI/CD', 'DevOps', 'Employee Engagement', 'Sales', 'Strategic Planning', 'Taxation']
# Expected gap    :  ['Leadership', 'Docker', 'Online Marketing']
# Predicted gap   :  ['Leadership', 'Docker', 'Online Marketing', 'Account Executive']
#
# Row 16:
# Required skills :  ['Azure', 'Containerization', 'Agile', 'Machine Learning', 'Prospecting', 'Negotiation', 'Digital Marketing', 'Accounting']
# Candidate skills:  ['Accounting', 'Agile', 'Azure', 'CRM', 'Data Warehousing', 'Jenkins', 'Kubernetes', 'Machine Learning', 'Negotiation', 'Online Marketing']
# Expected gap    :  ['Prospecting']
# Predicted gap   :  ['Containerization', 'Prospecting']
#
# Row 17:
# Required skills :  ['Agile', 'Mediation', 'Communication', 'C#.Net', 'AWS', 'Vue', 'MLOps', 'Team Leadership', 'SQL']
# Candidate skills:  ['AWS', 'C#', 'Communication', 'Google Cloud', 'Lead Generation', 'MLOps', 'Mediation']
# Expected gap    :  ['Agile', 'Vue', 'Team Leadership', 'SQL']
# Predicted gap   :  ['Agile', 'Vue', 'Team Leadership', 'SQL']
#
# Row 18:
# Required skills :  ['Communication', 'Criminal Law', 'Machine Learning', 'Content Marketing', 'NLP', 'Data Warehousing', 'Civil Law', 'Go']
# Candidate skills:  ['Civil Law', 'Communication', 'Corporate Law', 'Deep Learning', 'Go']
# Expected gap    :  ['Criminal Law', 'Content Marketing', 'NLP', 'Data Warehousing']
# Predicted gap   :  ['Content Marketing', 'NLP', 'Data Warehousing']
#
# Row 19:
# Required skills :  ['Radiology', 'SEO', 'Power BI', 'Pediatrics', 'Taxation', 'Investment Analysis']
# Candidate skills:  ['Closing Deals', 'Investment Analysis', 'Pediatrics', 'Power BI', 'Taxation']
# Expected gap    :  ['Radiology', 'SEO']
# Predicted gap   :  ['Radiology', 'SEO']
#
# Row 20:
# Required skills :  ['Training and Development', 'Litigation', 'Strategic Planning', 'Risk Management', 'PHP', 'Azure', 'Business Development', 'Data Warehousing']
# Candidate skills:  ['Azure', 'Business Development', 'Criminal Law', 'PHP', 'Risk Management', 'Strategic Planning', 'Training and Development']
# Expected gap    :  ['Litigation', 'Data Warehousing']
# Predicted gap   :  ['Litigation', 'Data Warehousing']
#
# Saved dataset with predictions to: clustered_skill_gap_dataset_2000_Result.csv
